# %% [markdown]
# # Assignment 1: CRF sequence tagging for Movie Queries
#
# This coursework involves optimizing the performance of a **Conditional Random Field (CRF) sequence tagger** for movie trivia questions and answers data, which consist of instances of data of word sequences with the target classes/labels for each word in a **BIO (Beginning, Inside, Outside)** tagging format.
#
# This assignment involves reading in, pre-processing, training and developing your tagger on the training data from *trivia10k13train.bio.txt*, and finally testing your tagger on the data *trivia10k13test.bio.txt*, attempting to get the best performing tagger across the different labels in your development process. Parts of these steps have been done for you already. You are going to optimize the performance of the tagger by improving its feature extraction function on the word sequences, incorporating POS tagging first, then the final exercise is to optimize the performance by all legal means neccessary (except looking at the test data). Run and follow the code below and then attempt the questions.
#
# **NOTEBOOK/CODE SUBMISSION: PLEASE SUBMIT IN NOTEBOOK FORM IF YOU CAN RATHER THAN IN A PYTHON FILE, MAKING YOUR CODE ADDITIONS TO THIS TEMPLATE FILE. SUBMISSION MUST BE IN PYTHON 3.7+ AND YOU MUST HAVE RUN THE CODE RUNNING FROM TOP TO BOTTOM BEFORE SUBMISSION.**
#
# **WRITTEN REPORT SUBMISSION: YOU MUST INCLUDE A 2-PAGE MAX LENGTH REPORT SUMMARIZING HOW YOU WENT ABOUT ACHIEVING EACH QUESTION, TO BE SUBMITTED WITH YOUR CODE. PLEASE WRITE SUCCINCTLY AND CLEARLY, IN THE STYLE OF A SCIENTIFIC NLP CONFERENCE PAPER. AUTOMATIC PLAGIARISM DETECTION WILL BE RUN ON THESE FILES.**

# %%
# !pip install python-crfsuite
# Out:
# Requirement already satisfied: python-crfsuite in /usr/local/lib/python3.7/dist-packages (0.9.7)

# %%
import os
import sys

from copy import deepcopy
from collections import Counter
from nltk.tag import CRFTagger

from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report

from matplotlib import pyplot as plt
import numpy as np

import re
import unicodedata

# %%
def get_raw_data_from_bio_file(fpath):
    """A simple function to read in from a one-word-per-line BIO
    (Beginning, Inside, Outside) tagged corpus, tab separated
    and each example sentence/text separated with a blank line.
    The data is already tokenized in a simple way.
    e.g.:
    
    B-Actor	steve
    I-Actor	mcqueen
    O	provided
    O	a
    B-Plot	thrilling
    I-Plot	motorcycle
    I-Plot	chase
    I-Plot	in
    I-Plot	this
    B-Opinion	greatest
    I-Opinion	of
    I-Opinion	all
    B-Plot	ww
    I-Plot	2
    I-Plot	prison
    I-Plot	escape
    I-Plot	movies
    
    returns a list of lists of tuples of (word, tag) tuples
    """
    f = open(fpath)
    data = []  # the data, a list of lists of (word, tag) tuples
    current_sent = []  # data for current sentence/example
    for line in f:
        if line == "\n":  # each instance has a blank line separating it from next one
            # solution
            data.append(current_sent)
            current_sent = []
            continue
        line_data = line.strip("\n").split("\t")
        current_sent.append((line_data[1], line_data[0]))
    f.close()
    return data

# %%
raw_training_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt")

# %%
# have a look at the first example
print(raw_training_data[0])
# Out:
# [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'), ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'), ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'), ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'), ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'), ('escape', 'I-Plot'), ('movies', 'I-Plot')]

# %%
print(len(raw_training_data), "instances")
print(sum([len(sent) for sent in raw_training_data]), "words")
# Out:
# 7816 instances
# 158823 words

# %%
def preProcess(example):
    """Function takes in list of (word, bio-tag) pairs, e.g.:
        [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'),
        ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'),
        ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'),
        ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'),
        ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'),
        ('escape', 'I-Plot'), ('movies', 'I-Plot')]
        
    returns new (token, bio-tag) pairs with preprocessing applied to the words"""

    preprocessed_example = example  # trivial- no preprocessing
    return preprocessed_example

# %%
training_data = [preProcess(example) for example in raw_training_data]

# %%
# check the effect of pre-processing
print(training_data[0])
# Out:
# [('steve', 'B-Actor'), ('mcqueen', 'I-Actor'), ('provided', 'O'), ('a', 'O'), ('thrilling', 'B-Plot'), ('motorcycle', 'I-Plot'), ('chase', 'I-Plot'), ('in', 'I-Plot'), ('this', 'I-Plot'), ('greatest', 'B-Opinion'), ('of', 'I-Opinion'), ('all', 'I-Opinion'), ('ww', 'B-Plot'), ('2', 'I-Plot'), ('prison', 'I-Plot'), ('escape', 'I-Plot'), ('movies', 'I-Plot')]

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits


# This is the 'out-of-the-box' get_features function from the nltk CRF tagger
def get_features(tokens, idx):
    """
    Extract basic features about this word including
         - Current Word
         - Is Capitalized ?
         - Has Punctuation ?
         - Has Number ?
         - Suffixes up to length 3
    Note that : we might include feature over previous word, next word ect.

    :return : a list which contains the features
    :rtype : list(str)

    """
    token = tokens[idx]
    feature_list = []

    if not token:
        return feature_list
    
    # Capitalization
    if token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, token) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in token):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 3
    if len(token) > 1:
        feature_list.append("SUF_" + token[-1:])
    if len(token) > 2:
        feature_list.append("SUF_" + token[-2:])
    if len(token) > 3:
        feature_list.append("SUF_" + token[-3:])
        
    feature_list.append("WORD_" + token)
    #print(feature_list)
    return feature_list

# %%
# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features)  # initialize tagger with get_features function

print("training tagger...")
ct.train(training_data, TAGGER_PATH)
print("done")
# Out:
# training tagger...
# done

# %%
# let's see how it does in testing on sentences
def print_tags(sentence):
    # a method to print out the sequence with its tags
    tokens = sentence.split()
    tags = [p[1] for p in ct.tag(tokens)]
    for token, tag in zip(tokens, tags):
        print(f'{token:12s}{tag}')

# %%
# an example from the corpus
example = "steve mcqueen provided a thrilling motorcycle chase in this greatest of all ww 2 prison escape movies"
print_tags(example)
# Out:
# steve       B-Actor
# mcqueen     I-Actor
# provided    O
# a           B-Plot
# thrilling   I-Plot
# motorcycle  I-Plot
# chase       I-Plot
# in          I-Plot
# this        I-Plot
# greatest    I-Plot
# of          I-Plot
# all         I-Plot
# ww          I-Plot
# 2           I-Plot
# prison      I-Plot
# escape      I-Plot
# movies      I-Plot

# %%
# a novel, unseen example we've just made up
print_tags("batman is the main character in batman begins")
# Out:
# batman      O
# is          O
# the         O
# main        O
# character   O
# in          O
# batman      B-Character_Name
# begins      I-Character_Name

# %%
# another example
print_tags("the sound of music")
# Out:
# the         O
# sound       O
# of          O
# music       O

# %%
# load tagger from saved file
ct = CRFTagger(feature_func=get_features)  # initialize tagger
ct.set_model_file(TAGGER_PATH)  # load model from file

# prepare the test data:
raw_test_data = get_raw_data_from_bio_file("trivia10k13test.bio.txt") 
test_data = [preProcess(example) for example in raw_test_data]
print(len(test_data), "instances")
print(sum([len(sent) for sent in test_data]), "words")
# Out:
# 1953 instances
# 39035 words

# %%
print("testing tagger...")
preds = []
y_test = []
for sent in test_data:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# testing tagger...
# done

# %%
# Output the classification report (which you should save each time for comparing your models)
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))  # print out accurate macro score
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.86      0.88      0.87      1274
#          B-Award       0.72      0.62      0.67        66
# B-Character_Name       0.81      0.24      0.37       283
#       B-Director       0.84      0.72      0.78       425
#          B-Genre       0.83      0.76      0.79       789
#        B-Opinion       0.49      0.30      0.37       195
#         B-Origin       0.52      0.38      0.44       190
#           B-Plot       0.49      0.47      0.48      1577
#          B-Quote       0.75      0.26      0.38        47
#   B-Relationship       0.80      0.53      0.64       171
#     B-Soundtrack       0.00      0.00      0.00         8
#           B-Year       0.94      0.97      0.96       661
#          I-Actor       0.86      0.89      0.87      1553
#          I-Award       0.74      0.69      0.72       147
# I-Character_Name       0.84      0.29      0.43       227
#       I-Director       0.89      0.74      0.81       411
#          I-Genre       0.77      0.75      0.76       544
#        I-Opinion       0.13      0.08      0.10       143
#         I-Origin       0.66      0.68      0.67       808
#           I-Plot       0.82      0.94      0.88     14661
#          I-Quote       0.75      0.55      0.63       349
#   I-Relationship       0.54      0.50      0.52       289
#     I-Soundtrack       0.00      0.00      0.00        30
#           I-Year       0.58      0.68      0.62        44
#                O       0.88      0.81      0.84     14143
#
#         accuracy                           0.82     39035
#        macro avg       0.66      0.55      0.58     39035
#     weighted avg       0.82      0.82      0.82     39035
#
# (0.6600804113759744, 0.5491509331431237, 0.5837735950008314, None)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def confusion_matrix_heatmap(y_test, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(y_test))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(y_test, preds, labels = labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!

# %%
confusion_matrix_heatmap(y_test, preds)

# %%
# Let's see what the CRF learned by looking at the internal transition/feature weights....

# %%
def print_transition_weights(transitions):
    """Sort the transitions between states/labels from highest to
    lowest strengths and print out."""
    ranked_transitions = [x for x in sorted(transitions,
                                               key=lambda x:x[1], reverse=True)]
    for (label_from, label_to), weight in ranked_transitions:
        print("%0.6f %-8s -> %s" % (weight, label_from, label_to))

# %%
print_transition_weights(ct._tagger.info().transitions.items())
# Out:
# 8.724577 B-Actor  -> I-Actor
# 8.339819 B-Plot   -> I-Plot
# 8.056264 B-Director -> I-Director
# 7.844567 B-Origin -> I-Origin
# 7.724763 I-Plot   -> I-Plot
# 7.553570 I-Quote  -> I-Quote
# 7.397641 B-Character_Name -> I-Character_Name
# 7.342680 I-Origin -> I-Origin
# 7.263004 B-Relationship -> I-Relationship
# 7.140895 B-Quote  -> I-Quote
# 7.013351 I-Relationship -> I-Relationship
# 6.867795 I-Soundtrack -> I-Soundtrack
# 6.788047 I-Opinion -> I-Opinion
# 6.732937 B-Genre  -> I-Genre
# 6.693016 B-Soundtrack -> I-Soundtrack
# 6.578020 B-Award  -> I-Award
# 6.435503 B-Opinion -> I-Opinion
# 6.422268 I-Award  -> I-Award
# 6.355522 I-Genre  -> I-Genre
# 6.344544 I-Actor  -> I-Actor
# 6.220084 I-Character_Name -> I-Character_Name
# 5.427243 I-Director -> I-Director
# 4.815258 I-Year   -> I-Year
# 4.083843 B-Year   -> I-Year
# 3.776230 B-Character_Name -> B-Plot
# 3.564706 O        -> O
# 3.561946 I-Character_Name -> B-Plot
# 3.277159 O        -> B-Plot
# 3.197475 B-Plot   -> B-Character_Name
# 3.085634 B-Opinion -> B-Genre
# 3.028571 O        -> B-Character_Name
# 2.933656 I-Actor  -> B-Plot
# 2.801608 O        -> B-Actor
# 2.789466 B-Year   -> B-Genre
# 2.703311 O        -> B-Genre
# 2.688974 O        -> B-Director
# 2.671602 I-Actor  -> O
# 2.656388 B-Genre  -> O
# 2.652944 I-Director -> B-Genre
# 2.568944 B-Year   -> B-Director
# 2.536615 I-Genre  -> O
# 2.489535 O        -> B-Origin
# 2.402047 O        -> B-Year
# 2.391598 O        -> B-Quote
# 2.379235 I-Director -> O
# 2.266035 I-Plot   -> B-Character_Name
# 2.264937 O        -> B-Soundtrack
# 2.264670 B-Genre  -> B-Opinion
# 2.256324 O        -> B-Relationship
# 2.254577 O        -> B-Opinion
# 2.125957 O        -> B-Award
# 2.124727 B-Opinion -> O
# 2.112588 B-Opinion -> B-Origin
# 1.999203 B-Genre  -> B-Relationship
# 1.935954 B-Relationship -> O
# 1.933975 B-Genre  -> B-Plot
# 1.925689 I-Genre  -> B-Plot
# 1.908743 B-Genre  -> B-Director
# 1.896769 B-Director -> O
# 1.881905 B-Opinion -> B-Director
# 1.881289 B-Opinion -> B-Plot
# 1.870445 B-Director -> B-Genre
# 1.838565 I-Opinion -> B-Genre
# 1.749642 I-Character_Name -> O
# 1.732026 I-Genre  -> B-Relationship
# 1.655631 B-Character_Name -> O
# 1.645543 B-Genre  -> B-Origin
# 1.621884 I-Director -> B-Plot
# 1.567110 B-Year   -> B-Opinion
# 1.553945 B-Year   -> O
# 1.521597 B-Actor  -> B-Plot
# 1.517728 I-Year   -> B-Plot
# 1.504053 I-Genre  -> B-Opinion
# 1.408978 B-Origin -> B-Genre
# 1.402039 B-Director -> B-Opinion
# 1.377873 I-Year   -> O
# 1.377147 I-Year   -> B-Genre
# 1.357419 I-Director -> B-Relationship
# 1.343089 I-Origin -> B-Plot
# 1.321119 B-Opinion -> B-Year
# 1.299869 B-Genre  -> B-Year
# 1.286719 I-Origin -> O
# 1.227420 I-Award  -> O
# 1.173765 B-Plot   -> B-Actor
# 1.156633 B-Relationship -> B-Plot
# 1.119334 I-Relationship -> B-Character_Name
# 1.106086 B-Origin -> O
# 1.100669 B-Year   -> B-Plot
# 1.089345 I-Relationship -> O
# 1.079299 I-Opinion -> O
# 1.059741 I-Opinion -> B-Plot
# 1.045824 I-Director -> B-Opinion
# 0.976076 B-Award  -> O
# 0.903757 B-Relationship -> B-Genre
# 0.901938 I-Genre  -> B-Origin
# 0.892659 B-Origin -> B-Plot
# 0.885346 B-Actor  -> O
# 0.885015 I-Relationship -> B-Origin
# 0.849393 B-Origin -> B-Opinion
# 0.847797 I-Opinion -> B-Relationship
# 0.807176 B-Plot   -> O
# 0.802860 I-Actor  -> B-Genre
# 0.792987 B-Director -> B-Relationship
# 0.771990 B-Opinion -> B-Relationship
# 0.769475 I-Actor  -> B-Opinion
# 0.706510 B-Year   -> B-Award
# 0.692615 B-Year   -> B-Relationship
# 0.691633 I-Relationship -> B-Director
# 0.633147 B-Opinion -> B-Actor
# 0.624714 B-Genre  -> B-Actor
# 0.624503 I-Opinion -> B-Origin
# 0.599950 B-Year   -> B-Origin
# 0.585734 I-Relationship -> B-Plot
# 0.574281 B-Relationship -> B-Character_Name
# 0.547366 B-Opinion -> B-Award
# 0.506735 I-Actor  -> B-Award
# 0.503421 I-Relationship -> B-Genre
# 0.453589 B-Genre  -> B-Award
# 0.448925 B-Director -> B-Origin
# 0.440438 I-Award  -> B-Relationship
# 0.435858 I-Origin -> B-Relationship
# 0.435680 I-Year   -> B-Opinion
# 0.413610 I-Genre  -> B-Director
# 0.405284 I-Director -> B-Origin
# 0.405246 I-Award  -> B-Origin
# 0.404355 I-Origin -> B-Genre
# 0.363829 I-Relationship -> B-Award
# 0.358440 B-Relationship -> B-Origin
# 0.338841 I-Director -> B-Year
# 0.315515 I-Genre  -> B-Character_Name
# 0.290381 I-Award  -> B-Soundtrack
# 0.288924 I-Character_Name -> B-Quote
# 0.274159 I-Quote  -> B-Quote
# 0.273046 I-Quote  -> O
# 0.263367 I-Genre  -> B-Year
# 0.256112 I-Origin -> B-Award
# 0.255884 B-Year   -> B-Actor
# 0.243914 I-Soundtrack -> B-Origin
# 0.241557 I-Actor  -> B-Soundtrack
# 0.235216 I-Director -> B-Award
# 0.231574 I-Award  -> B-Genre
# 0.212944 I-Actor  -> B-Origin
# 0.211671 I-Genre  -> B-Award
# 0.193719 B-Award  -> B-Year
# 0.179626 I-Plot   -> B-Actor
# 0.147023 I-Quote  -> B-Character_Name
# 0.146808 B-Director -> B-Character_Name
# 0.122678 B-Relationship -> B-Actor
# 0.120992 B-Plot   -> B-Opinion
# 0.119743 I-Soundtrack -> O
# 0.115748 I-Plot   -> O
# 0.114850 B-Director -> B-Year
# 0.107716 I-Year   -> B-Director
# 0.107224 B-Relationship -> B-Opinion
# 0.089420 B-Quote  -> B-Plot
# 0.081085 I-Award  -> B-Director
# 0.069106 I-Character_Name -> B-Relationship
# 0.062763 B-Actor  -> B-Opinion
# 0.055499 I-Plot   -> B-Origin
# 0.050366 B-Opinion -> B-Character_Name
# 0.040041 I-Opinion -> B-Director
# 0.038592 B-Relationship -> B-Director
# 0.013984 I-Award  -> B-Year
# -0.002773 I-Award  -> B-Opinion
# -0.004780 B-Director -> B-Plot
# -0.031879 I-Opinion -> B-Year
# -0.036028 I-Character_Name -> B-Opinion
# -0.077104 B-Plot   -> B-Genre
# -0.127190 I-Actor  -> B-Quote
# -0.138012 I-Relationship -> B-Actor
# -0.138013 B-Plot   -> B-Origin
# -0.172105 B-Actor  -> B-Genre
# -0.172217 I-Origin -> B-Character_Name
# -0.183180 I-Award  -> B-Actor
# -0.201694 I-Origin -> B-Year
# -0.209000 B-Plot   -> B-Relationship
# -0.249461 I-Award  -> B-Plot
# -0.278808 I-Genre  -> B-Actor
# -0.297170 I-Plot   -> B-Quote
# -0.306423 I-Opinion -> B-Actor
# -0.316763 I-Origin -> B-Opinion
# -0.322569 I-Actor  -> B-Relationship
# -0.323387 I-Origin -> B-Director
# -0.395816 B-Character_Name -> B-Actor
# -0.417628 B-Year   -> B-Character_Name
# -0.422868 B-Soundtrack -> O
# -0.451729 I-Relationship -> B-Opinion
# -0.507677 I-Actor  -> B-Character_Name
# -0.550461 I-Director -> B-Actor
# -0.554579 I-Character_Name -> B-Actor
# -0.650196 B-Plot   -> B-Year
# -0.722560 I-Origin -> B-Actor
# -0.744784 I-Plot   -> B-Soundtrack
# -0.759258 B-Quote  -> O
# -0.780913 I-Plot   -> B-Award
# -1.001337 I-Plot   -> B-Genre
# -1.038678 I-Plot   -> B-Relationship
# -1.309274 I-Plot   -> B-Opinion
# -1.545497 I-Plot   -> B-Director
# -1.923530 I-Plot   -> B-Year

# %%
def print_most_predictive_state_features(state_features,
                                         excluded_classes=["O"],
                                         top_k=None):
    """Takes in the dict of state_features from a python crf-suite tagger,
    orders them in terms of how predictive they are of different classes.
    We assume we are not interested in O labels."""
    if not top_k:
        top_k = len(state_features)  # assume we want to print all of them
    ranked_state_features = [x for x in sorted(state_features, key=lambda x:x[1], reverse=True) \
         if x[0][1] not in excluded_classes][:top_k]
    for (attr, label), weight in ranked_state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))

# %%
print_most_predictive_state_features(ct._tagger.info().state_features.items())
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.013258 I-Plot   WORD_polluted
# 0.013211 I-Plot   WORD_expedition
# 0.013197 B-Character_Name SUF_red
# 0.013182 B-Plot   SUF_rns
# 0.013164 I-Plot   SUF_fee
# 0.013164 I-Plot   WORD_coffee
# 0.013141 I-Plot   SUF_edo
# 0.013129 I-Plot   WORD_behalf
# 0.013113 B-Plot   WORD_documents
# 0.013078 I-Plot   WORD_farmboy
# 0.013059 I-Actor  SUF_fia
# 0.013046 I-Plot   WORD_materials
# 0.013036 I-Plot   WORD_naked
# 0.013034 I-Plot   WORD_attic
# 0.013004 I-Plot   WORD_gravely
# 0.012983 I-Award  SUF_ous
# 0.012973 I-Plot   WORD_idealism
# 0.012969 B-Quote  SUF_ed
# 0.012968 I-Plot   WORD_tanked
# 0.012964 I-Plot   WORD_expense
# 0.012921 I-Plot   SUF_iya
# 0.012921 I-Plot   WORD_wadiya
# 0.012919 I-Plot   WORD_agency
# 0.012881 I-Plot   SUF_urt
# 0.012880 I-Plot   WORD_gig
# 0.012871 I-Plot   WORD_orchestrated
# 0.012843 I-Plot   WORD_suspension
# 0.012835 B-Character_Name WORD_sugar
# 0.012830 I-Plot   WORD_fend
# 0.012828 I-Plot   WORD_recounts
# 0.012805 I-Plot   WORD_solely
# 0.012792 I-Plot   WORD_fishnet
# 0.012788 I-Plot   WORD_saucer
# 0.012783 I-Plot   WORD_supermutants
# 0.012780 I-Plot   WORD_offensive
# 0.012775 I-Plot   WORD_mugging
# 0.012756 I-Plot   WORD_shakespearean
# 0.012743 I-Plot   SUF_des
# 0.012733 I-Plot   WORD_strugges
# 0.012717 I-Plot   WORD_onstage
# 0.012716 I-Plot   WORD_drops
# 0.012716 I-Plot   WORD_simulated
# 0.012713 I-Origin WORD_con
# 0.012703 I-Plot   SUF_eat
# 0.012682 I-Plot   WORD_plants
# 0.012674 I-Plot   WORD_feathered
# 0.012669 I-Plot   WORD_filth
# 0.012660 B-Director SUF_der
# 0.012646 I-Plot   WORD_crooked
# 0.012645 I-Plot   WORD_corruption
# 0.012631 I-Plot   WORD_formed
# 0.012615 I-Plot   WORD_eleven
# 0.012600 I-Plot   WORD_shaggy
# 0.012579 I-Plot   WORD_claiming
# 0.012577 I-Plot   WORD_tennis
# 0.012576 I-Plot   WORD_beer
# 0.012569 I-Plot   WORD_miniature
# 0.012551 I-Plot   WORD_swing
# 0.012545 I-Plot   WORD_allegedly
# 0.012533 B-Award  SUF_l
# 0.012532 I-Plot   WORD_laser
# 0.012523 I-Plot   WORD_graduation
# 0.012521 I-Origin SUF_ral
# 0.012520 I-Plot   SUF_tay
# 0.012520 I-Plot   WORD_stay
# 0.012518 I-Plot   WORD_webs
# 0.012498 I-Plot   WORD_brains
# 0.012460 I-Plot   WORD_text
# 0.012437 I-Plot   WORD_impostor
# 0.012431 I-Plot   WORD_orangutans
# 0.012413 I-Plot   WORD_thwart
# 0.012398 I-Plot   WORD_domineering
# 0.012390 I-Plot   SUF_mom
# 0.012390 I-Plot   WORD_stepmom
# 0.012386 I-Plot   WORD_tycoons
# 0.012370 I-Plot   SUF_hly
# 0.012327 I-Actor  SUF_am
# 0.012324 I-Plot   WORD_wiped
# 0.012322 I-Plot   WORD_succession
# 0.012305 I-Character_Name SUF_ott
# 0.012295 I-Plot   WORD_oppression
# 0.012292 I-Plot   WORD_collect
# 0.012272 I-Plot   WORD_percentage
# 0.012271 I-Plot   WORD_lands
# 0.012252 I-Plot   WORD_barden
# 0.012247 I-Plot   WORD_ireland
# 0.012211 I-Plot   WORD_goods
# 0.012191 I-Plot   WORD_imperials
# 0.012185 I-Plot   WORD_murderers
# 0.012159 I-Plot   WORD_chair
# 0.012150 I-Plot   WORD_mercury
# 0.012143 I-Plot   WORD_kicking
# 0.012140 I-Genre  WORD_post
# 0.012132 I-Plot   WORD_bankers
# 0.012115 I-Plot   WORD_steed
# 0.012082 B-Actor  WORD_humfrey
# 0.012055 I-Plot   WORD_spartan
# 0.012024 I-Plot   WORD_woodsboro
# 0.012009 I-Plot   WORD_visitor
# 0.012006 I-Plot   WORD_visitors
# 0.012001 I-Plot   WORD_advantage
# 0.011970 I-Plot   SUF_eik
# 0.011970 I-Plot   WORD_sheik
# 0.011949 I-Plot   WORD_packs
# 0.011941 I-Plot   WORD_sanity
# 0.011936 I-Plot   WORD_washes
# 0.011930 I-Actor  SUF_ott
# 0.011924 I-Plot   WORD_partying
# 0.011897 I-Plot   WORD_modified
# 0.011864 I-Plot   WORD_flattery
# 0.011857 I-Plot   WORD_aspires
# 0.011856 I-Plot   WORD_ordeal
# 0.011842 I-Plot   WORD_illusions
# 0.011827 I-Plot   WORD_overshadowed
# 0.011788 I-Plot   WORD_reaper
# 0.011787 I-Plot   WORD_gopher
# 0.011767 I-Plot   WORD_vanquish
# 0.011761 I-Plot   WORD_survives
# 0.011761 I-Plot   WORD_cabinet
# 0.011719 I-Plot   WORD_plaid
# 0.011718 I-Plot   WORD_biology
# 0.011694 I-Plot   WORD_recovers
# 0.011684 I-Plot   WORD_afterwards
# 0.011668 I-Plot   WORD_undermine
# 0.011627 I-Plot   WORD_blunders
# 0.011622 I-Origin WORD_70
# 0.011619 I-Plot   WORD_hinders
# 0.011609 I-Opinion WORD_filmed
# 0.011592 I-Genre  SUF_bli
# 0.011592 I-Genre  WORD_ghibli
# 0.011586 I-Plot   SUF_cky
# 0.011577 I-Plot   SUF_tha
# 0.011577 I-Plot   WORD_martha
# 0.011566 I-Plot   WORD_maguical
# 0.011542 I-Plot   WORD_dons
# 0.011529 I-Plot   WORD_platform
# 0.011527 I-Plot   WORD_ma
# 0.011510 I-Plot   WORD_disappearances
# 0.011491 I-Plot   WORD_wonder
# 0.011471 I-Plot   WORD_reef
# 0.011447 I-Plot   WORD_fransisco
# 0.011423 I-Actor  WORD_herman
# 0.011406 I-Plot   WORD_pursuits
# 0.011402 I-Plot   WORD_patient
# 0.011396 B-Plot   SUF_ost
# 0.011371 I-Plot   WORD_buttons
# 0.011323 I-Plot   WORD_coaxed
# 0.011317 I-Plot   WORD_deposed
# 0.011316 I-Plot   WORD_silverware
# 0.011313 I-Plot   WORD_smuggle
# 0.011307 I-Origin WORD_its
# 0.011304 I-Plot   WORD_foolishly
# 0.011284 I-Plot   WORD_unbeatable
# 0.011267 I-Plot   WORD_vice
# 0.011263 I-Plot   WORD_believing
# 0.011259 I-Plot   WORD_ideals
# 0.011258 I-Plot   WORD_crawls
# 0.011253 I-Plot   WORD_wage
# 0.011237 I-Plot   WORD_hats
# 0.011227 I-Plot   WORD_ahead
# 0.011194 I-Plot   SUF_apy
# 0.011183 I-Plot   WORD_treks
# 0.011182 I-Plot   WORD_persians
# 0.011170 I-Plot   WORD_quoting
# 0.011162 I-Plot   WORD_successes
# 0.011161 B-Plot   WORD_make
# 0.011159 I-Plot   WORD_amidst
# 0.011151 I-Plot   WORD_rigged
# 0.011138 I-Plot   WORD_expires
# 0.011138 I-Plot   WORD_philandering
# 0.011138 I-Plot   WORD_optics
# 0.011126 I-Plot   SUF_new
# 0.011123 I-Plot   WORD_chauffeur
# 0.011116 I-Plot   WORD_persuade
# 0.011115 I-Plot   WORD_weirdest
# 0.011096 B-Plot   WORD_focused
# 0.011093 I-Plot   WORD_blossoms
# 0.011087 I-Plot   WORD_crumbling
# 0.011087 I-Plot   WORD_igor
# 0.011082 I-Plot   WORD_brain
# 0.011082 I-Plot   WORD_tractor
# 0.011065 B-Director SUF_un
# 0.011062 I-Plot   WORD_honcho
# 0.011034 I-Character_Name SUF_gi
# 0.011031 I-Plot   WORD_adultery
# 0.011019 I-Plot   WORD_undergoes
# 0.011002 I-Plot   WORD_fullest
# 0.011002 I-Plot   WORD_tablets
# 0.011001 I-Plot   WORD_slaying
# 0.010994 I-Plot   WORD_overwhelmed
# 0.010967 I-Plot   WORD_secure
# 0.010965 I-Plot   WORD_kobe
# 0.010953 I-Plot   WORD_reassembles
# 0.010910 I-Plot   WORD_galactic
# 0.010903 I-Plot   WORD_godmother
# 0.010898 I-Origin SUF_gic
# 0.010897 I-Plot   WORD_praying
# 0.010887 I-Plot   WORD_undead
# 0.010881 I-Plot   WORD_cousins
# 0.010872 I-Plot   SUF_ims
# 0.010866 B-Plot   SUF_ner
# 0.010855 I-Soundtrack SUF_ion
# 0.010854 I-Plot   WORD_representative
# 0.010847 I-Plot   WORD_planets
# 0.010844 B-Relationship SUF_nt
# 0.010844 I-Plot   WORD_sum
# 0.010819 I-Plot   WORD_bury
# 0.010808 I-Plot   WORD_encountering
# 0.010801 I-Plot   WORD_recyclables
# 0.010799 I-Plot   WORD_footprints
# 0.010792 I-Plot   WORD_unimaginable
# 0.010791 I-Plot   SUF_uin
# 0.010782 I-Plot   WORD_wit
# 0.010778 I-Plot   WORD_flailing
# 0.010776 I-Plot   WORD_pours
# 0.010763 I-Plot   WORD_investors
# 0.010759 I-Plot   WORD_whether
# 0.010755 I-Plot   SUF_ocy
# 0.010755 I-Plot   WORD_idiocy
# 0.010755 I-Quote  WORD_puke
# 0.010704 I-Plot   WORD_microscopic
# 0.010690 I-Plot   WORD_backgrounds
# 0.010676 I-Plot   WORD_cowboy
# 0.010648 I-Plot   SUF_hag
# 0.010648 I-Plot   WORD_seahag
# 0.010612 I-Quote  SUF_bag
# 0.010612 I-Quote  WORD_scumbag
# 0.010565 I-Plot   WORD_unexpected
# 0.010547 I-Plot   WORD_sacrificed
# 0.010542 I-Plot   WORD_interferes
# 0.010529 I-Plot   WORD_stepdaughter
# 0.010485 I-Plot   WORD_subsequent
# 0.010481 I-Plot   WORD_ancestral
# 0.010465 I-Plot   WORD_sharing
# 0.010450 I-Plot   WORD_overland
# 0.010380 I-Plot   WORD_truckers
# 0.010379 I-Plot   WORD_uncovering
# 0.010355 I-Plot   SUF_rgs
# 0.010355 I-Plot   WORD_cyborgs
# 0.010328 I-Plot   WORD_laughs
# 0.010306 I-Plot   WORD_participate
# 0.010303 I-Plot   WORD_exiled
# 0.010298 I-Plot   WORD_playmates
# 0.010279 I-Plot   WORD_restitution
# 0.010248 I-Soundtrack SUF_ter
# 0.010247 I-Plot   WORD_buys
# 0.010244 I-Actor  WORD_michael
# 0.010244 I-Plot   WORD_backdrop
# 0.010233 I-Plot   WORD_kinds
# 0.010201 I-Plot   WORD_inhabit
# 0.010185 I-Plot   WORD_degeneres
# 0.010169 I-Plot   WORD_voilent
# 0.010168 I-Origin WORD_nathanson
# 0.010166 I-Plot   WORD_exposition
# 0.010159 I-Plot   WORD_subdivision
# 0.010156 I-Plot   WORD_receive
# 0.010087 I-Plot   WORD_purchase
# 0.010067 I-Plot   WORD_popularity
# 0.010064 I-Plot   WORD_senior
# 0.010056 I-Plot   WORD_infraction
# 0.010047 I-Plot   WORD_domestic
# 0.010037 I-Genre  SUF_gic
# 0.010034 I-Plot   WORD_hottest
# 0.010012 I-Plot   WORD_reputations
# 0.010007 I-Plot   WORD_inspires
# 0.010004 I-Plot   WORD_fascism
# 0.009996 I-Plot   WORD_reconstruct
# 0.009984 I-Origin SUF_nth
# 0.009982 I-Plot   WORD_reviving
# 0.009979 I-Plot   WORD_key
# 0.009964 I-Plot   WORD_shine
# 0.009958 I-Plot   WORD_letting
# 0.009943 I-Opinion SUF_red
# 0.009936 I-Plot   WORD_trainer
# 0.009916 I-Plot   WORD_requirements
# 0.009908 I-Plot   WORD_aide
# 0.009898 I-Plot   WORD_misfits
# 0.009874 I-Genre  SUF_se
# 0.009840 I-Plot   WORD_prosecuting
# 0.009821 I-Plot   WORD_shifting
# 0.009820 B-Actor  SUF_bel
# 0.009818 I-Plot   WORD_shady
# 0.009793 I-Plot   WORD_highschool
# 0.009790 I-Plot   WORD_besieged
# 0.009777 I-Plot   WORD_communicated
# 0.009767 I-Plot   WORD_idiodic
# 0.009724 I-Plot   WORD_duping
# 0.009722 I-Plot   WORD_infected
# 0.009678 I-Plot   WORD_rehab
# 0.009676 I-Plot   WORD_minds
# 0.009672 I-Plot   WORD_connects
# 0.009666 I-Plot   WORD_scaring
# 0.009651 I-Plot   WORD_unpopular
# 0.009632 I-Plot   SUF_hod
# 0.009632 I-Plot   WORD_method
# 0.009616 I-Plot   WORD_tends
# 0.009605 I-Plot   WORD_chic
# 0.009595 I-Plot   WORD_targets
# 0.009590 I-Plot   WORD_plutonium
# 0.009581 I-Plot   WORD_advocating
# 0.009562 I-Plot   WORD_fill
# 0.009557 I-Plot   WORD_unimpressionable
# 0.009555 I-Plot   WORD_founds
# 0.009553 I-Plot   WORD_confront
# 0.009548 I-Plot   WORD_reardon
# 0.009537 I-Plot   WORD_secluded
# 0.009534 I-Plot   WORD_swamp
# 0.009533 I-Plot   WORD_forcing
# 0.009531 I-Plot   WORD_intervention
# 0.009520 I-Plot   WORD_spend
# 0.009511 I-Plot   WORD_raiding
# 0.009501 I-Plot   WORD_beneath
# 0.009495 I-Plot   WORD_historically
# 0.009467 I-Plot   WORD_raises
# 0.009464 I-Plot   WORD_deceiving
# 0.009454 I-Plot   WORD_unbelievable
# 0.009453 I-Plot   WORD_deformity
# 0.009452 I-Plot   WORD_increases
# 0.009432 I-Plot   WORD_humiliating
# 0.009430 I-Plot   SUF_oob
# 0.009430 I-Plot   WORD_boob
# 0.009424 I-Plot   WORD_responsibility
# 0.009411 I-Plot   WORD_ax
# 0.009396 I-Plot   WORD_tying
# 0.009396 I-Plot   WORD_averts
# 0.009396 I-Plot   WORD_incapable
# 0.009391 I-Plot   WORD_advance
# 0.009389 I-Plot   WORD_towns
# 0.009383 I-Plot   WORD_mixing
# 0.009357 I-Plot   WORD_trafficking
# 0.009347 I-Plot   WORD_whil
# 0.009332 I-Plot   WORD_honoring
# 0.009298 I-Plot   WORD_fortuitous
# 0.009298 I-Plot   WORD_rancher
# 0.009295 I-Plot   SUF_zor
# 0.009295 I-Plot   WORD_razor
# 0.009294 I-Plot   SUF_ypt
# 0.009294 I-Plot   WORD_egypt
# 0.009293 I-Plot   WORD_mandatory
# 0.009276 I-Plot   WORD_pepperland
# 0.009262 B-Plot   WORD_writer
# 0.009260 I-Plot   WORD_signalling
# 0.009232 I-Plot   WORD_arguing
# 0.009227 I-Plot   WORD_philly
# 0.009190 I-Plot   SUF_ngs
# 0.009189 I-Plot   WORD_holed
# 0.009169 I-Plot   WORD_liver
# 0.009143 I-Plot   WORD_carter
# 0.009139 I-Plot   WORD_smoldering
# 0.009124 I-Plot   WORD_resulting
# 0.009078 I-Plot   WORD_intimate
# 0.009076 I-Plot   SUF_lar
# 0.009055 I-Plot   WORD_liberate
# 0.009045 I-Plot   SUF_eda
# 0.009045 I-Plot   WORD_andromeda
# 0.009032 I-Plot   WORD_harms
# 0.009023 I-Plot   WORD_exacted
# 0.009005 I-Plot   WORD_asking
# 0.009000 I-Plot   WORD_losers
# 0.008996 I-Plot   WORD_wasted
# 0.008989 I-Opinion SUF_ge
# 0.008975 I-Plot   WORD_charges
# 0.008961 I-Plot   WORD_athletic
# 0.008959 I-Actor  WORD_lennon
# 0.008957 I-Plot   WORD_stupedest
# 0.008937 I-Plot   WORD_loyal
# 0.008935 I-Plot   WORD_rescuing
# 0.008924 I-Plot   WORD_rapes
# 0.008920 I-Plot   WORD_chooses
# 0.008894 I-Plot   WORD_generate
# 0.008886 I-Plot   WORD_gaming
# 0.008876 I-Plot   WORD_prophecy
# 0.008866 I-Plot   WORD_sending
# 0.008865 I-Plot   WORD_boredom
# 0.008849 I-Plot   SUF_aso
# 0.008849 I-Plot   WORD_laso
# 0.008845 I-Plot   WORD_wrecking
# 0.008841 I-Genre  WORD_special
# 0.008814 I-Plot   WORD_affected
# 0.008812 I-Plot   WORD_seeks
# 0.008784 I-Plot   WORD_fierce
# 0.008772 I-Plot   WORD_poker
# 0.008745 I-Origin WORD_morpurgo
# 0.008725 I-Plot   WORD_villianous
# 0.008702 I-Plot   WORD_worship
# 0.008698 I-Plot   WORD_abolisher
# 0.008689 I-Plot   WORD_ingredients
# 0.008689 I-Plot   WORD_electricity
# 0.008679 I-Plot   WORD_spark
# 0.008668 I-Plot   WORD_settled
# 0.008646 I-Relationship WORD_t
# 0.008645 I-Plot   WORD_infatuated
# 0.008638 I-Plot   WORD_journeys
# 0.008617 I-Plot   WORD_enroll
# 0.008606 I-Plot   WORD_intolerable
# 0.008602 I-Actor  WORD_val
# 0.008585 I-Plot   WORD_enjoys
# 0.008578 I-Plot   WORD_starvation
# 0.008578 I-Plot   WORD_ornaments
# 0.008576 I-Plot   WORD_quickly
# 0.008546 I-Plot   WORD_strained
# 0.008545 I-Plot   WORD_alliance
# 0.008541 I-Plot   WORD_crawling
# 0.008534 I-Plot   SUF_joy
# 0.008534 I-Plot   WORD_enjoy
# 0.008520 I-Plot   WORD_punks
# 0.008511 I-Plot   WORD_lusts
# 0.008493 I-Plot   WORD_defenders
# 0.008481 I-Plot   WORD_subway
# 0.008465 I-Plot   WORD_material
# 0.008458 I-Plot   SUF_ht
# 0.008458 I-Plot   SUF_ght
# 0.008437 I-Plot   WORD_goddess
# 0.008410 I-Plot   WORD_overtaken
# 0.008408 I-Plot   WORD_methods
# 0.008394 I-Plot   WORD_regarding
# 0.008373 I-Plot   WORD_eras
# 0.008361 I-Plot   WORD_searing
# 0.008359 I-Plot   WORD_pickpockets
# 0.008355 I-Plot   WORD_midgets
# 0.008320 I-Plot   WORD_july
# 0.008301 I-Plot   WORD_nightmares
# 0.008285 I-Plot   WORD_notice
# 0.008274 I-Plot   WORD_dedicated
# 0.008270 I-Plot   WORD_stepfamily
# 0.008266 I-Plot   WORD_bedevere
# 0.008224 I-Plot   WORD_reinventing
# 0.008211 I-Plot   WORD_scouting
# 0.008200 B-Director SUF_ce
# 0.008197 I-Plot   WORD_proper
# 0.008194 I-Plot   WORD_refused
# 0.008176 I-Plot   WORD_wealth
# 0.008142 I-Plot   WORD_sharecroppers
# 0.008137 I-Plot   WORD_archery
# 0.008130 I-Plot   WORD_bladed
# 0.008123 I-Plot   WORD_fighters
# 0.008113 I-Plot   WORD_erased
# 0.008103 I-Plot   WORD_virtue
# 0.008094 I-Plot   WORD_enduring
# 0.008081 I-Plot   WORD_sparkled
# 0.008077 I-Plot   WORD_shuts
# 0.008075 I-Plot   WORD_achieve
# 0.008071 I-Plot   WORD_chimps
# 0.008071 I-Plot   WORD_biting
# 0.008065 I-Plot   WORD_artistic
# 0.008045 I-Plot   WORD_alzheimer
# 0.008042 I-Plot   WORD_hosted
# 0.008035 I-Plot   WORD_settler
# 0.008019 I-Plot   WORD_reforms
# 0.008017 B-Plot   WORD_learns
# 0.008016 I-Plot   WORD_cost
# 0.008007 I-Plot   WORD_assignments
# 0.008004 I-Plot   WORD_pretended
# 0.007995 I-Plot   WORD_epa
# 0.007925 I-Plot   WORD_defection
# 0.007907 I-Plot   WORD_extinction
# 0.007877 B-Character_Name SUF_ter
# 0.007877 I-Plot   WORD_unexplainable
# 0.007869 I-Character_Name WORD_n
# 0.007869 I-Plot   WORD_simultaneously
# 0.007866 I-Plot   WORD_emerged
# 0.007864 I-Plot   WORD_colorado
# 0.007857 I-Plot   WORD_warehouse
# 0.007852 I-Plot   WORD_potential
# 0.007851 I-Plot   WORD_unreciprocated
# 0.007828 I-Plot   WORD_hitting
# 0.007812 I-Plot   WORD_witnesses
# 0.007804 I-Plot   WORD_destinies
# 0.007803 I-Plot   WORD_heartless
# 0.007798 I-Plot   WORD_heavily
# 0.007793 I-Plot   WORD_recourse
# 0.007791 I-Plot   WORD_avoid
# 0.007760 I-Plot   WORD_homemade
# 0.007743 I-Plot   WORD_slackers
# 0.007720 I-Actor  WORD_linda
# 0.007719 I-Plot   WORD_spinster
# 0.007708 I-Plot   WORD_ashore
# 0.007708 I-Plot   WORD_bribes
# 0.007691 I-Plot   WORD_rapacious
# 0.007686 I-Plot   WORD_tout
# 0.007681 I-Plot   WORD_purebreds
# 0.007661 I-Origin SUF_net
# 0.007652 I-Plot   WORD_payments
# 0.007642 I-Plot   WORD_actively
# 0.007617 I-Plot   WORD_respective
# 0.007616 I-Plot   WORD_dissolves
# 0.007595 I-Plot   WORD_caged
# 0.007575 I-Plot   WORD_nightmare
# 0.007565 I-Plot   SUF_coy
# 0.007563 I-Plot   WORD_interment
# 0.007557 I-Plot   WORD_worldwide
# 0.007550 I-Plot   WORD_combining
# 0.007547 B-Actor  WORD_carrie
# 0.007543 I-Plot   WORD_arouses
# 0.007524 I-Plot   WORD_camps
# 0.007513 I-Plot   WORD_moderate
# 0.007510 I-Plot   WORD_trucks
# 0.007480 I-Plot   WORD_muggles
# 0.007480 I-Plot   WORD_strike
# 0.007462 I-Plot   WORD_polynesians
# 0.007450 I-Plot   WORD_traumatic
# 0.007417 I-Plot   WORD_upcoming
# 0.007415 I-Plot   WORD_confide
# 0.007409 I-Plot   WORD_envelope
# 0.007399 I-Plot   WORD_sought
# 0.007397 I-Plot   WORD_feeds
# 0.007368 I-Plot   WORD_essentially
# 0.007356 I-Plot   WORD_defeats
# 0.007342 I-Origin SUF_erg
# 0.007322 I-Plot   WORD_contracts
# 0.007310 I-Plot   WORD_playground
# 0.007303 I-Quote  WORD_born
# 0.007275 I-Plot   WORD_lifeboat
# 0.007266 I-Plot   WORD_seniors
# 0.007265 I-Plot   WORD_patiently
# 0.007242 I-Plot   WORD_clashes
# 0.007214 I-Plot   WORD_celebrates
# 0.007174 I-Plot   WORD_reunited
# 0.007158 I-Plot   WORD_overwhelming
# 0.007154 I-Plot   WORD_epidemic
# 0.007153 I-Genre  SUF_ate
# 0.007149 I-Plot   SUF_wct
# 0.007149 I-Plot   WORD_inswct
# 0.007148 I-Plot   WORD_suceed
# 0.007132 I-Plot   WORD_acquainted
# 0.007131 I-Plot   WORD_developing
# 0.007121 I-Plot   WORD_chests
# 0.007110 I-Plot   WORD_disobeys
# 0.007108 I-Plot   WORD_dynasty
# 0.007107 I-Plot   WORD_clandestine
# 0.007081 I-Origin SUF_inn
# 0.007081 I-Plot   WORD_competitive
# 0.007055 I-Plot   WORD_assailants
# 0.007040 I-Plot   WORD_illness
# 0.007019 I-Plot   WORD_subservient
# 0.007009 I-Plot   WORD_supplement
# 0.007004 I-Plot   WORD_processing
# 0.007004 I-Plot   WORD_midwestern
# 0.006983 I-Plot   WORD_aeronautical
# 0.006964 I-Plot   WORD_hurdles
# 0.006952 I-Plot   WORD_evade
# 0.006944 I-Plot   WORD_wiggles
# 0.006936 I-Plot   WORD_aggressions
# 0.006931 I-Plot   WORD_promotion
# 0.006921 I-Plot   WORD_piss
# 0.006920 I-Plot   WORD_idiotic
# 0.006886 I-Actor  SUF_die
# 0.006862 B-Plot   SUF_fic
# 0.006862 I-Plot   WORD_stole
# 0.006854 I-Plot   WORD_base
# 0.006844 I-Plot   WORD_resemble
# 0.006843 I-Origin SUF_own
# 0.006838 I-Plot   WORD_lied
# 0.006817 I-Plot   WORD_mocking
# 0.006814 I-Plot   WORD_proves
# 0.006810 I-Plot   WORD_dilapidated
# 0.006807 I-Plot   WORD_await
# 0.006800 I-Plot   WORD_buy
# 0.006765 B-Actor  WORD_olympia
# 0.006763 I-Plot   WORD_endangers
# 0.006763 I-Plot   WORD_foil
# 0.006762 I-Plot   WORD_countless
# 0.006750 I-Origin WORD_mash
# 0.006711 I-Plot   WORD_disobeying
# 0.006703 I-Plot   WORD_skeptic
# 0.006697 I-Plot   WORD_slaughter
# 0.006695 I-Plot   WORD_menacing
# 0.006686 I-Plot   WORD_conflicted
# 0.006682 I-Plot   WORD_sown
# 0.006678 I-Plot   WORD_biography
# 0.006670 I-Plot   WORD_inability
# 0.006660 I-Plot   WORD_seaside
# 0.006647 I-Plot   WORD_temptations
# 0.006636 B-Actor  SUF_or
# 0.006630 I-Plot   WORD_loreans
# 0.006626 I-Plot   WORD_scavengers
# 0.006624 I-Plot   WORD_integrated
# 0.006606 I-Plot   WORD_designer
# 0.006604 I-Plot   WORD_putting
# 0.006592 I-Plot   WORD_promise
# 0.006581 I-Plot   WORD_cogs
# 0.006557 I-Plot   WORD_portland
# 0.006548 I-Plot   WORD_replicas
# 0.006542 I-Plot   WORD_sitting
# 0.006538 I-Plot   SUF_ib
# 0.006538 I-Plot   SUF_rib
# 0.006538 I-Plot   WORD_crib
# 0.006530 I-Plot   WORD_knew
# 0.006514 I-Plot   WORD_comically
# 0.006487 I-Plot   WORD_judge
# 0.006470 I-Plot   WORD_oust
# 0.006467 I-Plot   WORD_husband
# 0.006467 I-Plot   WORD_therapy
# 0.006446 I-Plot   WORD_thousand
# 0.006433 I-Plot   SUF_zza
# 0.006433 I-Plot   WORD_pizza
# 0.006430 I-Plot   WORD_unfortunately
# 0.006426 I-Plot   WORD_opportunity
# 0.006414 I-Plot   WORD_forth
# 0.006410 I-Plot   WORD_unrecognizable
# 0.006409 I-Plot   WORD_harness
# 0.006394 I-Plot   WORD_slayed
# 0.006366 I-Plot   WORD_freed
# 0.006354 I-Actor  SUF_can
# 0.006342 I-Plot   WORD_fit
# 0.006336 I-Plot   WORD_wartime
# 0.006336 I-Plot   WORD_remaining
# 0.006330 I-Plot   WORD_promote
# 0.006329 B-Character_Name SUF_ack
# 0.006294 I-Plot   WORD_stresses
# 0.006291 I-Plot   WORD_emotionless
# 0.006284 I-Plot   WORD_grad
# 0.006269 I-Plot   WORD_tutelage
# 0.006259 I-Plot   WORD_closely
# 0.006253 I-Origin SUF_8
# 0.006248 I-Plot   WORD_intertwining
# 0.006240 I-Plot   WORD_godfather
# 0.006240 I-Plot   WORD_druggies
# 0.006237 I-Plot   WORD_occupying
# 0.006228 I-Plot   WORD_separates
# 0.006227 I-Plot   WORD_innocence
# 0.006217 I-Plot   WORD_disposing
# 0.006212 I-Plot   WORD_defraud
# 0.006200 I-Plot   WORD_dazzles
# 0.006200 I-Plot   WORD_cooperation
# 0.006189 I-Plot   WORD_ambush
# 0.006185 I-Plot   WORD_rat
# 0.006183 I-Plot   WORD_furter
# 0.006181 I-Plot   WORD_woke
# 0.006174 I-Plot   WORD_sacred
# 0.006173 I-Plot   WORD_lever
# 0.006142 I-Plot   WORD_facial
# 0.006131 I-Plot   WORD_stubborn
# 0.006124 I-Plot   WORD_shifter
# 0.006122 I-Plot   WORD_districts
# 0.006101 I-Plot   WORD_rush
# 0.006100 I-Plot   WORD_mermaids
# 0.006088 I-Plot   WORD_knocks
# 0.006071 B-Plot   HAS_NUM
# 0.006058 I-Plot   WORD_rode
# 0.006033 I-Origin SUF_ls
# 0.006018 I-Plot   WORD_solace
# 0.006015 I-Plot   WORD_represents
# 0.006014 I-Plot   WORD_rehabilitative
# 0.006013 I-Plot   WORD_rigs
# 0.006005 I-Plot   SUF_gns
# 0.006005 I-Plot   WORD_resigns
# 0.005998 I-Plot   WORD_encouraged
# 0.005970 I-Plot   WORD_maintaining
# 0.005959 I-Plot   WORD_violations
# 0.005950 I-Plot   WORD_borrowing
# 0.005944 I-Plot   WORD_pennsylvania
# 0.005934 I-Plot   WORD_resistance
# 0.005926 I-Plot   WORD_hazardous
# 0.005911 I-Plot   WORD_spill
# 0.005899 I-Plot   WORD_mutual
# 0.005895 I-Plot   WORD_weirdness
# 0.005880 I-Plot   WORD_herd
# 0.005867 I-Plot   WORD_ponders
# 0.005826 B-Soundtrack WORD_a
# 0.005815 I-Actor  WORD_dolly
# 0.005794 I-Plot   WORD_hearts
# 0.005792 I-Plot   WORD_passing
# 0.005788 I-Plot   WORD_rejuvenate
# 0.005763 I-Plot   WORD_contain
# 0.005756 I-Plot   WORD_mining
# 0.005754 I-Plot   WORD_homeland
# 0.005725 I-Director SUF_r
# 0.005721 I-Plot   WORD_cricket
# 0.005707 I-Plot   WORD_analysis
# 0.005693 I-Plot   WORD_helmets
# 0.005691 I-Plot   WORD_conceive
# 0.005662 I-Plot   WORD_aunts
# 0.005655 I-Plot   WORD_dominate
# 0.005646 I-Plot   WORD_giants
# 0.005623 I-Plot   WORD_worth
# 0.005599 I-Plot   WORD_slovak
# 0.005594 I-Plot   WORD_undying
# 0.005592 I-Plot   WORD_lifter
# 0.005583 I-Plot   WORD_development
# 0.005564 I-Plot   WORD_psychedelic
# 0.005560 I-Plot   WORD_sole
# 0.005560 I-Plot   WORD_striped
# 0.005559 I-Plot   WORD_reactor
# 0.005548 I-Plot   WORD_closure
# 0.005544 I-Plot   WORD_grifter
# 0.005540 I-Plot   WORD_waits
# 0.005540 I-Plot   WORD_tosses
# 0.005517 I-Plot   WORD_oppressive
# 0.005516 I-Plot   WORD_bilk
# 0.005515 I-Plot   WORD_submerged
# 0.005513 I-Plot   SUF_esa
# 0.005510 I-Plot   WORD_clans
# 0.005508 I-Plot   WORD_erase
# 0.005495 I-Plot   WORD_taste
# 0.005492 I-Plot   WORD_invite
# 0.005488 I-Relationship WORD_popular
# 0.005487 I-Plot   WORD_sewed
# 0.005483 I-Plot   WORD_rebuilding
# 0.005481 I-Plot   WORD_egged
# 0.005471 B-Plot   WORD_brothers
# 0.005465 I-Plot   WORD_sylvania
# 0.005461 B-Actor  SUF_pia
# 0.005451 I-Plot   WORD_compromise
# 0.005440 I-Plot   WORD_smooches
# 0.005436 I-Plot   SUF_pty
# 0.005436 I-Plot   WORD_empty
# 0.005431 I-Plot   WORD_babysitting
# 0.005422 I-Plot   WORD_blinded
# 0.005402 I-Plot   WORD_pact
# 0.005401 I-Plot   WORD_throws
# 0.005401 I-Plot   WORD_exposing
# 0.005396 B-Plot   SUF_ely
# 0.005379 I-Plot   WORD_hoods
# 0.005375 I-Plot   WORD_ids
# 0.005335 I-Plot   WORD_exists
# 0.005333 I-Plot   WORD_overprotective
# 0.005323 I-Plot   WORD_enables
# 0.005309 I-Plot   WORD_pose
# 0.005276 I-Plot   WORD_paratrooper
# 0.005273 I-Award  WORD_th
# 0.005269 B-Plot   SUF_ble
# 0.005265 I-Plot   WORD_eliminated
# 0.005199 I-Plot   WORD_idiots
# 0.005197 I-Plot   WORD_faked
# 0.005143 I-Plot   WORD_respects
# 0.005142 I-Plot   WORD_upend
# 0.005134 I-Origin SUF_rke
# 0.005128 I-Plot   WORD_invetrofertilization
# 0.005126 I-Plot   WORD_dreaming
# 0.005123 I-Plot   WORD_obnoxious
# 0.005121 I-Plot   WORD_slime
# 0.005112 I-Plot   WORD_cruising
# 0.005070 I-Plot   WORD_undeserved
# 0.005067 I-Plot   WORD_tough
# 0.005066 I-Plot   SUF_erm
# 0.005062 I-Plot   WORD_cultivates
# 0.005049 I-Plot   WORD_throwing
# 0.005044 I-Plot   WORD_cocoons
# 0.005032 I-Plot   WORD_homestead
# 0.005032 I-Plot   WORD_coaching
# 0.005012 I-Plot   SUF_eb
# 0.005012 I-Plot   WORD_web
# 0.005011 I-Plot   SUF_ru
# 0.004992 I-Plot   WORD_insert
# 0.004979 I-Plot   WORD_stops
# 0.004960 I-Plot   WORD_boost
# 0.004952 I-Plot   WORD_harmless
# 0.004944 I-Plot   WORD_togeather
# 0.004906 I-Plot   WORD_raucous
# 0.004896 I-Plot   WORD_colossal
# 0.004894 B-Relationship SUF_us
# 0.004888 I-Plot   WORD_propose
# 0.004884 I-Plot   SUF_ee
# 0.004864 I-Plot   WORD_continent
# 0.004850 I-Plot   WORD_corral
# 0.004838 I-Plot   WORD_disinherited
# 0.004828 B-Year   SUF_27
# 0.004826 I-Plot   WORD_cheated
# 0.004820 I-Plot   WORD_valueless
# 0.004816 I-Plot   WORD_cultures
# 0.004805 I-Plot   SUF_fes
# 0.004805 I-Plot   WORD_wifes
# 0.004789 I-Plot   WORD_pageant
# 0.004766 I-Plot   WORD_ravaged
# 0.004759 I-Plot   WORD_pure
# 0.004758 I-Plot   WORD_transfers
# 0.004734 I-Plot   WORD_evacuate
# 0.004732 I-Plot   WORD_youngest
# 0.004730 I-Plot   WORD_infiltrate
# 0.004727 I-Plot   WORD_chemotherapy
# 0.004726 I-Plot   WORD_removes
# 0.004724 I-Plot   WORD_unbeknownst
# 0.004720 I-Plot   WORD_despise
# 0.004718 I-Plot   WORD_hid
# 0.004716 I-Plot   WORD_galahad
# 0.004714 I-Plot   WORD_costs
# 0.004696 I-Plot   WORD_conspire
# 0.004688 I-Plot   WORD_blessed
# 0.004687 I-Plot   WORD_ventures
# 0.004685 I-Director SUF_row
# 0.004657 I-Plot   WORD_shed
# 0.004643 I-Plot   WORD_uninhabited
# 0.004642 I-Plot   WORD_wrapped
# 0.004625 I-Plot   WORD_signature
# 0.004605 I-Plot   WORD_endanger
# 0.004599 I-Plot   WORD_cases
# 0.004596 I-Plot   WORD_renew
# 0.004571 I-Plot   WORD_slumber
# 0.004562 I-Plot   WORD_gains
# 0.004560 I-Plot   SUF_oop
# 0.004560 I-Plot   WORD_troop
# 0.004539 I-Plot   WORD_invaded
# 0.004530 I-Plot   WORD_hilariously
# 0.004530 I-Plot   WORD_elemental
# 0.004501 I-Plot   WORD_racers
# 0.004490 I-Plot   WORD_locales
# 0.004482 I-Origin WORD_autobiographical
# 0.004475 I-Plot   SUF_lit
# 0.004475 I-Plot   WORD_split
# 0.004459 I-Plot   WORD_rope
# 0.004454 I-Plot   WORD_endure
# 0.004452 I-Origin WORD_semi
# 0.004449 I-Plot   SUF_may
# 0.004449 I-Plot   WORD_dismay
# 0.004430 I-Plot   WORD_hijacked
# 0.004415 I-Character_Name SUF_im
# 0.004413 I-Plot   WORD_trusted
# 0.004410 I-Plot   WORD_egyptian
# 0.004404 I-Plot   WORD_pranking
# 0.004388 I-Plot   WORD_overdose
# 0.004385 I-Plot   WORD_hedonistic
# 0.004379 I-Plot   WORD_opts
# 0.004369 I-Plot   WORD_caper
# 0.004367 I-Plot   WORD_brightens
# 0.004361 I-Plot   WORD_fraud
# 0.004360 I-Plot   WORD_tipping
# 0.004351 I-Plot   SUF_ipe
# 0.004351 I-Plot   WORD_ripe
# 0.004351 I-Plot   WORD_loyalties
# 0.004345 I-Plot   WORD_flies
# 0.004333 I-Relationship SUF_it
# 0.004328 I-Plot   SUF_xe
# 0.004328 I-Plot   WORD_axe
# 0.004320 I-Plot   WORD_locking
# 0.004319 I-Plot   WORD_renounce
# 0.004317 I-Plot   WORD_glamorized
# 0.004312 I-Plot   WORD_jinxes
# 0.004294 I-Plot   WORD_eliminates
# 0.004289 I-Plot   WORD_obtain
# 0.004265 I-Plot   WORD_thrift
# 0.004261 I-Plot   WORD_steamboat
# 0.004231 B-Award  SUF_a
# 0.004205 I-Plot   WORD_ace
# 0.004203 I-Plot   WORD_bandit
# 0.004198 I-Plot   WORD_heading
# 0.004193 I-Plot   WORD_casket
# 0.004179 I-Plot   WORD_curb
# 0.004163 B-Opinion SUF_ld
# 0.004161 I-Plot   WORD_happening
# 0.004137 I-Plot   WORD_rhode
# 0.004086 I-Plot   WORD_wildness
# 0.004082 I-Plot   WORD_divided
# 0.004073 I-Plot   WORD_unusual
# 0.004072 I-Plot   WORD_integrate
# 0.004043 I-Plot   WORD_delema
# 0.004032 I-Plot   WORD_successfully
# 0.004024 I-Plot   WORD_lush
# 0.004021 I-Plot   WORD_plaguing
# 0.004002 I-Plot   WORD_tours
# 0.003995 I-Plot   WORD_cobwebs
# 0.003991 I-Plot   WORD_statistical
# 0.003988 I-Plot   WORD_picked
# 0.003987 I-Plot   WORD_alternative
# 0.003977 I-Plot   WORD_residents
# 0.003940 I-Origin SUF_ura
# 0.003940 I-Plot   WORD_donation
# 0.003898 I-Plot   WORD_landscape
# 0.003890 I-Plot   WORD_glimpse
# 0.003872 I-Actor  SUF_oll
# 0.003822 I-Plot   WORD_explore
# 0.003808 I-Plot   WORD_gowns
# 0.003808 I-Plot   WORD_seize
# 0.003804 I-Plot   WORD_vow
# 0.003801 I-Plot   WORD_warning
# 0.003801 I-Plot   WORD_crate
# 0.003772 I-Plot   WORD_emptiness
# 0.003769 I-Plot   WORD_murderess
# 0.003760 I-Plot   WORD_invents
# 0.003753 I-Plot   WORD_plunder
# 0.003729 I-Plot   WORD_impress
# 0.003728 I-Plot   WORD_cfo
# 0.003724 B-Character_Name SUF_ain
# 0.003724 I-Plot   WORD_assassinating
# 0.003721 I-Plot   WORD_warhead
# 0.003713 I-Plot   WORD_cowhand
# 0.003707 I-Plot   WORD_statistics
# 0.003700 I-Plot   WORD_deteriorate
# 0.003697 I-Plot   WORD_posse
# 0.003693 I-Plot   WORD_correct
# 0.003690 I-Plot   SUF_tia
# 0.003690 I-Plot   WORD_militia
# 0.003669 I-Plot   SUF_ud
# 0.003665 I-Plot   WORD_unaware
# 0.003661 I-Plot   WORD_copies
# 0.003659 I-Plot   WORD_dates
# 0.003654 I-Plot   WORD_landed
# 0.003643 I-Plot   WORD_deliverer
# 0.003635 I-Plot   WORD_extends
# 0.003625 I-Plot   WORD_guilt
# 0.003624 I-Plot   WORD_outwits
# 0.003620 I-Plot   WORD_stroll
# 0.003607 I-Plot   WORD_dramas
# 0.003598 I-Plot   WORD_terrors
# 0.003596 I-Plot   WORD_approval
# 0.003593 I-Plot   WORD_amount
# 0.003593 I-Plot   WORD_damage
# 0.003580 I-Plot   SUF_wim
# 0.003580 I-Plot   WORD_swim
# 0.003575 I-Plot   WORD_intended
# 0.003558 I-Plot   WORD_rips
# 0.003555 I-Plot   WORD_affluent
# 0.003552 I-Plot   SUF_gma
# 0.003552 I-Plot   WORD_stigma
# 0.003549 I-Plot   WORD_hoards
# 0.003546 I-Plot   WORD_fitting
# 0.003544 I-Plot   WORD_sentenced
# 0.003482 I-Plot   WORD_embellished
# 0.003440 I-Plot   WORD_hooked
# 0.003433 I-Plot   WORD_noticeable
# 0.003432 I-Plot   WORD_proprietor
# 0.003424 I-Plot   WORD_consumerist
# 0.003415 I-Plot   WORD_rifle
# 0.003394 I-Plot   WORD_volunteer
# 0.003367 I-Plot   WORD_comrades
# 0.003341 I-Plot   WORD_guns
# 0.003335 I-Plot   WORD_attain
# 0.003316 I-Plot   WORD_ranger
# 0.003299 I-Plot   WORD_blatant
# 0.003296 I-Plot   WORD_member
# 0.003290 I-Plot   WORD_spying
# 0.003287 I-Plot   WORD_represent
# 0.003273 I-Plot   WORD_replicating
# 0.003271 I-Plot   WORD_steep
# 0.003265 I-Plot   WORD_connect
# 0.003262 I-Quote  SUF_ath
# 0.003259 I-Plot   WORD_reverse
# 0.003230 I-Plot   WORD_rife
# 0.003216 I-Plot   WORD_streak
# 0.003208 I-Plot   WORD_peasant
# 0.003208 I-Plot   WORD_curls
# 0.003204 I-Plot   WORD_steamliner
# 0.003189 I-Plot   WORD_boundaries
# 0.003189 I-Plot   WORD_hep
# 0.003188 I-Plot   WORD_administrative
# 0.003183 I-Plot   WORD_supports
# 0.003181 I-Plot   WORD_careless
# 0.003145 I-Plot   WORD_cockatoo
# 0.003145 I-Plot   WORD_finals
# 0.003143 I-Plot   WORD_harm
# 0.003141 I-Plot   WORD_tongue
# 0.003125 I-Plot   WORD_repair
# 0.003119 I-Plot   WORD_born
# 0.003112 I-Plot   WORD_ratched
# 0.003106 I-Plot   WORD_incident
# 0.003078 I-Plot   WORD_expand
# 0.003062 I-Plot   WORD_admit
# 0.003059 I-Plot   WORD_spaghetti
# 0.003044 I-Plot   WORD_seeing
# 0.003039 I-Plot   SUF_ond
# 0.003029 I-Actor  WORD_ron
# 0.002939 I-Plot   WORD_chop
# 0.002932 I-Plot   WORD_matters
# 0.002930 I-Plot   WORD_appreciation
# 0.002928 I-Plot   WORD_suicidal
# 0.002916 I-Plot   WORD_pursuing
# 0.002908 I-Plot   WORD_lycanthrope
# 0.002903 I-Plot   WORD_firearms
# 0.002884 I-Plot   WORD_beds
# 0.002879 I-Plot   WORD_reinvent
# 0.002874 I-Plot   WORD_wished
# 0.002872 I-Plot   WORD_protesters
# 0.002851 I-Plot   WORD_maintain
# 0.002845 I-Plot   WORD_form
# 0.002827 I-Plot   WORD_druglords
# 0.002821 I-Plot   WORD_caregivers
# 0.002817 I-Plot   WORD_unreliable
# 0.002801 I-Plot   WORD_malicious
# 0.002800 I-Plot   WORD_resorts
# 0.002786 I-Plot   WORD_allowed
# 0.002782 I-Plot   WORD_jill
# 0.002774 I-Plot   WORD_malevolent
# 0.002752 I-Plot   WORD_exhibits
# 0.002749 I-Plot   WORD_improve
# 0.002736 I-Plot   WORD_regardless
# 0.002732 I-Relationship SUF_0
# 0.002691 I-Plot   WORD_raise
# 0.002684 I-Plot   WORD_laziness
# 0.002667 I-Plot   WORD_higher
# 0.002665 I-Plot   WORD_capacitors
# 0.002665 I-Plot   WORD_steak
# 0.002663 I-Plot   WORD_blown
# 0.002638 I-Relationship WORD_serie
# 0.002632 I-Actor  WORD_mel
# 0.002618 I-Plot   SUF_hia
# 0.002559 I-Plot   SUF_bt
# 0.002559 I-Plot   SUF_ebt
# 0.002559 I-Plot   WORD_debt
# 0.002559 I-Plot   WORD_greenpeace
# 0.002542 I-Plot   WORD_agreement
# 0.002540 I-Plot   WORD_accuses
# 0.002535 I-Opinion SUF_ay
# 0.002530 I-Plot   WORD_counterespionage
# 0.002526 I-Plot   WORD_galvanizing
# 0.002490 I-Origin WORD_title
# 0.002487 I-Plot   WORD_graduates
# 0.002481 I-Plot   SUF_lux
# 0.002481 I-Plot   WORD_flux
# 0.002479 I-Plot   WORD_oppose
# 0.002430 I-Plot   WORD_valuable
# 0.002430 I-Plot   WORD_unresolved
# 0.002429 I-Plot   WORD_libyans
# 0.002417 I-Plot   WORD_studies
# 0.002387 I-Plot   WORD_insinuate
# 0.002379 B-Actor  WORD_maria
# 0.002373 I-Plot   WORD_napped
# 0.002371 I-Plot   WORD_converse
# 0.002356 B-Origin HAS_NUM
# 0.002354 I-Plot   WORD_reject
# 0.002349 I-Plot   SUF_vp
# 0.002349 I-Plot   WORD_mvp
# 0.002327 I-Plot   WORD_cards
# 0.002319 I-Plot   WORD_allowing
# 0.002308 I-Plot   WORD_slavers
# 0.002296 I-Plot   WORD_outposts
# 0.002281 I-Plot   WORD_convent
# 0.002265 I-Plot   WORD_madeup
# 0.002256 I-Plot   WORD_escort
# 0.002236 I-Plot   WORD_nuisance
# 0.002185 I-Plot   WORD_grips
# 0.002177 I-Genre  SUF_ti
# 0.002171 I-Plot   WORD_nicer
# 0.002157 I-Plot   WORD_urinate
# 0.002114 I-Plot   SUF_irk
# 0.002114 I-Plot   WORD_kirk
# 0.002105 I-Plot   WORD_doldrums
# 0.002087 I-Plot   WORD_relies
# 0.002063 I-Plot   WORD_succumbs
# 0.002062 I-Plot   WORD_grip
# 0.002041 I-Plot   WORD_turbulent
# 0.002001 I-Plot   WORD_presidents
# 0.001978 I-Plot   WORD_ranch
# 0.001935 I-Actor  WORD_jason
# 0.001927 I-Plot   WORD_outrageous
# 0.001927 I-Plot   WORD_arrive
# 0.001913 I-Character_Name SUF_ine
# 0.001888 I-Plot   WORD_endeavors
# 0.001748 I-Plot   WORD_slain
# 0.001714 I-Quote  WORD_ai
# 0.001694 I-Plot   WORD_ironic
# 0.001628 I-Plot   WORD_claimant
# 0.001553 I-Relationship SUF_vil
# 0.001547 I-Plot   SUF_ona
# 0.001521 I-Plot   WORD_instruct
# 0.001448 I-Plot   WORD_regiment
# 0.001400 I-Plot   WORD_usual
# 0.001363 I-Plot   WORD_supervisors
# 0.001347 I-Plot   SUF_got
# 0.001282 I-Actor  WORD_joe
# 0.001248 I-Plot   WORD_charms
# 0.001143 B-Character_Name SUF_c
# 0.001137 I-Origin SUF_ul
# 0.001130 I-Plot   WORD_wide
# 0.001116 I-Relationship WORD_sci
# 0.001080 I-Plot   WORD_sinful
# 0.001051 I-Plot   SUF_eef
# 0.000898 I-Opinion SUF_ene
# 0.000826 B-Actor  WORD_dean
# 0.000814 I-Plot   WORD_glass
# 0.000706 I-Award  SUF_ong
# 0.000654 B-Director SUF_dy
# 0.000622 I-Plot   WORD_raft
# 0.000515 I-Soundtrack SUF_ge
# 0.000510 I-Plot   SUF_up
# 0.000502 I-Actor  SUF_non
# 0.000431 I-Character_Name WORD_of
# 0.000371 I-Relationship SUF_s
# 0.000371 B-Plot   WORD_slow
# 0.000314 I-Plot   SUF_ux
# 0.000295 I-Plot   WORD_lesson
# 0.000293 I-Plot   WORD_robe
# 0.000221 I-Plot   WORD_arrival
# 0.000091 B-Plot   SUF_lm
# 0.000086 I-Origin WORD_chris
# 0.000072 I-Director WORD_black
# -0.000072 I-Quote  SUF_nto
# -0.000151 I-Actor  SUF_ees
# -0.000222 B-Year   SUF_59
# -0.000222 B-Year   SUF_959
# -0.000222 B-Year   WORD_1959
# -0.000229 I-Plot   WORD_regular
# -0.000239 I-Plot   WORD_harvard
# -0.000302 I-Plot   SUF_ek
# -0.000317 I-Actor  SUF_ary
# -0.000387 I-Actor  SUF_ert
# -0.000402 I-Plot   WORD_early
# -0.000419 I-Origin WORD_melville
# -0.000466 I-Relationship SUF_cal
# -0.000471 B-Plot   WORD_only
# -0.000583 B-Director SUF_hel
# -0.000653 I-Actor  WORD_dorothy
# -0.000743 I-Plot   SUF_pon
# -0.000748 I-Origin WORD_scottish
# -0.000831 I-Quote  SUF_to
# -0.000848 B-Origin SUF_ven
# -0.000874 I-Plot   WORD_tied
# -0.000930 I-Plot   WORD_path
# -0.000949 I-Plot   WORD_felon
# -0.001138 I-Plot   SUF_50
# -0.001146 I-Origin WORD_red
# -0.001171 I-Relationship SUF_try
# -0.001171 I-Plot   WORD_explosive
# -0.001248 I-Plot   WORD_sports
# -0.001396 I-Plot   SUF_lp
# -0.001448 I-Plot   WORD_pows
# -0.001656 I-Character_Name SUF_ch
# -0.001662 I-Actor  SUF_dre
# -0.001668 I-Actor  WORD_leighton
# -0.001731 B-Character_Name SUF_eve
# -0.001731 B-Plot   SUF_ney
# -0.001763 B-Actor  SUF_ty
# -0.001821 B-Plot   SUF_gly
# -0.001912 I-Award  SUF_ic
# -0.002077 I-Plot   SUF_udy
# -0.002187 I-Plot   WORD_filibustering
# -0.002250 I-Plot   WORD_deliver
# -0.002274 I-Plot   WORD_wake
# -0.002301 I-Plot   SUF_raw
# -0.002309 I-Plot   WORD_numerous
# -0.002315 I-Plot   WORD_combines
# -0.002396 I-Origin SUF_mac
# -0.002396 I-Origin WORD_cormac
# -0.002441 I-Actor  SUF_int
# -0.002547 I-Plot   SUF_01
# -0.002547 I-Plot   SUF_001
# -0.002601 I-Opinion WORD_holiday
# -0.002682 I-Plot   WORD_question
# -0.002916 B-Opinion SUF_all
# -0.002987 I-Plot   WORD_east
# -0.003008 B-Origin SUF_y
# -0.003148 I-Plot   SUF_gth
# -0.003202 I-Plot   SUF_iig
# -0.003202 I-Plot   WORD_wiig
# -0.003278 I-Origin SUF_rg
# -0.003341 I-Origin SUF_py
# -0.003406 I-Character_Name SUF_ood
# -0.003505 I-Origin WORD_david
# -0.003597 I-Actor  SUF_cks
# -0.003606 I-Origin SUF_ler
# -0.003620 I-Plot   SUF_ky
# -0.003651 I-Plot   WORD_counterculture
# -0.003714 B-Plot   WORD_guys
# -0.003743 I-Origin SUF_ive
# -0.003748 I-Plot   WORD_made
# -0.003804 I-Relationship SUF_cy
# -0.004018 B-Plot   WORD_searching
# -0.004174 I-Relationship SUF_vel
# -0.004210 I-Plot   SUF_ior
# -0.004241 I-Plot   SUF_vak
# -0.004254 I-Plot   SUF_sor
# -0.004415 I-Plot   SUF_omb
# -0.004415 I-Plot   WORD_bomb
# -0.004586 B-Character_Name SUF_res
# -0.004597 I-Director SUF_et
# -0.004616 B-Genre  SUF_py
# -0.004811 I-Plot   WORD_stone
# -0.004956 I-Plot   WORD_catching
# -0.005031 I-Plot   WORD_girlfriends
# -0.005034 I-Plot   WORD_6
# -0.005040 B-Plot   WORD_son
# -0.005145 I-Origin SUF_ac
# -0.005157 I-Plot   WORD_premise
# -0.005204 I-Plot   SUF_ote
# -0.005220 I-Actor  WORD_charlie
# -0.005286 B-Plot   WORD_showing
# -0.005361 I-Origin SUF_vid
# -0.005395 I-Origin SUF_ky
# -0.005399 I-Plot   SUF_ri
# -0.005441 I-Plot   WORD_working
# -0.005454 I-Opinion SUF_ary
# -0.005528 I-Plot   WORD_disfigured
# -0.005535 I-Relationship SUF_les
# -0.005550 B-Plot   WORD_lost
# -0.005712 I-Origin SUF_l
# -0.005747 I-Plot   WORD_climbing
# -0.005754 B-Plot   SUF_ess
# -0.005842 I-Plot   WORD_something
# -0.005846 I-Plot   WORD_ape
# -0.005871 I-Plot   WORD_edwards
# -0.005900 B-Genre  SUF_ert
# -0.005966 B-Plot   SUF_ill
# -0.005967 B-Plot   WORD_epic
# -0.005973 I-Character_Name SUF_ho
# -0.006003 I-Plot   WORD_scientist
# -0.006118 I-Plot   WORD_initially
# -0.006211 I-Plot   WORD_abraham
# -0.006245 I-Plot   WORD_classical
# -0.006292 B-Plot   WORD_african
# -0.006418 I-Relationship SUF_d
# -0.006484 B-Plot   SUF_hur
# -0.006528 B-Plot   SUF_ese
# -0.006574 B-Genre  WORD_stoner
# -0.006574 B-Character_Name SUF_il
# -0.006621 I-Plot   SUF_ow
# -0.006648 I-Plot   WORD_fly
# -0.006759 B-Plot   SUF_ven
# -0.006799 B-Plot   SUF_air
# -0.006827 I-Relationship WORD_teenage
# -0.007039 B-Opinion SUF_re
# -0.007060 B-Opinion WORD_a
# -0.007158 I-Origin SUF_lue
# -0.007310 I-Actor  WORD_bigelow
# -0.007357 I-Actor  WORD_claire
# -0.007366 I-Plot   WORD_jonathan
# -0.007380 I-Plot   WORD_guide
# -0.007460 I-Genre  SUF_sh
# -0.007505 I-Plot   SUF_tti
# -0.007603 B-Genre  SUF_ra
# -0.007626 I-Plot   WORD_explores
# -0.007666 I-Plot   WORD_simians
# -0.007686 I-Plot   WORD_media
# -0.007716 I-Plot   SUF_obe
# -0.007764 B-Genre  WORD_time
# -0.007833 B-Plot   SUF_uys
# -0.007995 I-Plot   WORD_actions
# -0.008002 I-Plot   WORD_opposite
# -0.008017 I-Plot   WORD_overweight
# -0.008025 I-Plot   WORD_justice
# -0.008026 I-Actor  WORD_dustin
# -0.008037 I-Plot   WORD_housewife
# -0.008121 I-Plot   WORD_jewelry
# -0.008247 I-Quote  WORD_ca
# -0.008506 I-Plot   WORD_origin
# -0.008520 B-Origin SUF_ian
# -0.008581 B-Actor  SUF_ess
# -0.008596 I-Plot   WORD_psychotic
# -0.008601 I-Opinion SUF_od
# -0.008669 I-Plot   WORD_main
# -0.008696 I-Plot   WORD_do
# -0.008712 I-Opinion WORD_movies
# -0.008740 I-Plot   WORD_amnesia
# -0.008869 B-Plot   WORD_robots
# -0.008963 I-Plot   WORD_edgar
# -0.008971 I-Plot   WORD_decided
# -0.008975 I-Actor  WORD_has
# -0.009000 I-Plot   WORD_departed
# -0.009020 I-Plot   WORD_78
# -0.009057 I-Plot   WORD_rocker
# -0.009184 B-Opinion SUF_ale
# -0.009246 I-Actor  WORD_mickey
# -0.009247 B-Actor  SUF_ing
# -0.009324 I-Plot   WORD_mans
# -0.009341 B-Character_Name SUF_d
# -0.009442 B-Origin SUF_ee
# -0.009615 I-Plot   WORD_silent
# -0.009680 I-Plot   WORD_broker
# -0.009751 I-Plot   SUF_ig
# -0.009760 B-Actor  WORD_buddy
# -0.009934 I-Actor  SUF_rd
# -0.010072 I-Character_Name SUF_am
# -0.010126 B-Plot   SUF_der
# -0.010200 B-Genre  SUF_ee
# -0.010271 I-Plot   WORD_rebel
# -0.010301 I-Opinion WORD_car
# -0.010344 I-Quote  WORD_private
# -0.010476 I-Relationship SUF_ood
# -0.010499 I-Quote  WORD_fat
# -0.010504 I-Plot   WORD_heaven
# -0.010521 I-Plot   SUF_984
# -0.010521 I-Plot   WORD_1984
# -0.010604 B-Actor  WORD_ice
# -0.010632 B-Actor  SUF_key
# -0.010717 B-Plot   SUF_rg
# -0.010751 I-Plot   SUF_ift
# -0.010850 I-Plot   WORD_offered
# -0.010887 I-Origin SUF_ece
# -0.010905 I-Plot   WORD_lose
# -0.010991 I-Genre  SUF_nal
# -0.011005 I-Plot   WORD_emma
# -0.011018 I-Relationship SUF_ly
# -0.011041 I-Character_Name SUF_ead
# -0.011108 I-Award  SUF_te
# -0.011195 I-Actor  SUF_red
# -0.011321 I-Relationship SUF_ma
# -0.011407 I-Plot   WORD_disco
# -0.011449 I-Plot   WORD_siam
# -0.011609 B-Director SUF_ve
# -0.011614 I-Plot   SUF_yc
# -0.011614 I-Plot   WORD_nyc
# -0.011662 I-Plot   WORD_greek
# -0.011697 I-Plot   WORD_explored
# -0.011710 B-Opinion SUF_hy
# -0.011774 I-Actor  SUF_0
# -0.012012 I-Plot   SUF_ull
# -0.012014 I-Plot   WORD_breaking
# -0.012053 I-Plot   SUF_via
# -0.012367 B-Plot   SUF_ark
# -0.012396 I-Plot   WORD_weary
# -0.012511 B-Relationship WORD_of
# -0.012714 B-Plot   WORD_races
# -0.012783 I-Origin WORD_most
# -0.012812 I-Plot   WORD_paradise
# -0.012858 B-Plot   WORD_being
# -0.012884 I-Origin SUF_92
# -0.012884 I-Origin SUF_992
# -0.012884 I-Origin WORD_1992
# -0.013015 I-Plot   WORD_sentence
# -0.013130 I-Plot   WORD_organized
# -0.013167 B-Plot   SUF_ony
# -0.013187 I-Plot   WORD_jaw
# -0.013236 I-Character_Name SUF_ens
# -0.013240 I-Plot   WORD_identical
# -0.013249 I-Origin SUF_lt
# -0.013283 I-Plot   WORD_pet
# -0.013389 I-Relationship WORD_not
# -0.013407 I-Plot   WORD_dynamic
# -0.013597 I-Quote  SUF_ung
# -0.013686 B-Plot   SUF_ip
# -0.013870 I-Origin WORD_w
# -0.013982 I-Actor  SUF_nce
# -0.014030 I-Plot   SUF_dry
# -0.014045 I-Actor  SUF_wyn
# -0.014045 I-Actor  WORD_goldwyn
# -0.014065 I-Plot   WORD_bow
# -0.014091 I-Plot   WORD_reputation
# -0.014110 I-Plot   SUF_alo
# -0.014146 I-Plot   WORD_republic
# -0.014158 I-Plot   SUF_son
# -0.014161 I-Plot   WORD_respectively
# -0.014280 I-Origin SUF_03
# -0.014280 I-Origin SUF_003
# -0.014280 I-Origin WORD_2003
# -0.014355 I-Award  SUF_n
# -0.014453 I-Plot   WORD_breaks
# -0.014465 I-Origin SUF_law
# -0.014515 I-Plot   WORD_mix
# -0.014614 I-Origin WORD_arthur
# -0.014834 I-Plot   SUF_jor
# -0.014834 I-Plot   WORD_major
# -0.015015 I-Quote  SUF_vil
# -0.015028 I-Origin SUF_emi
# -0.015054 I-Plot   WORD_foot
# -0.015078 I-Origin WORD_stephen
# -0.015170 I-Plot   WORD_prestigious
# -0.015236 I-Plot   WORD_spectacular
# -0.015320 I-Plot   WORD_however
# -0.015387 I-Relationship SUF_lar
# -0.015418 B-Award  SUF_s
# -0.015424 I-Plot   WORD_receives
# -0.015453 I-Origin SUF_hur
# -0.015539 I-Quote  SUF_or
# -0.015549 B-Relationship SUF_ee
# -0.015635 B-Plot   WORD_cast
# -0.015656 I-Plot   SUF_dre
# -0.015695 B-Plot   SUF_ads
# -0.015755 I-Quote  SUF_k
# -0.015758 B-Actor  WORD_van
# -0.015880 I-Plot   SUF_erd
# -0.015907 B-Character_Name SUF_ay
# -0.015940 B-Plot   WORD_finds
# -0.016100 B-Award  SUF_t
# -0.016105 I-Actor  WORD_george
# -0.016143 I-Relationship SUF_al
# -0.016241 I-Plot   WORD_fresh
# -0.016296 I-Quote  WORD_piece
# -0.016299 I-Plot   WORD_dakota
# -0.016373 B-Plot   WORD_spinning
# -0.016540 B-Plot   WORD_mad
# -0.016560 B-Plot   WORD_was
# -0.016888 I-Plot   WORD_witches
# -0.016892 B-Actor  SUF_ose
# -0.016908 B-Plot   SUF_ips
# -0.016978 B-Character_Name SUF_vil
# -0.016996 I-Origin SUF_ous
# -0.017011 I-Plot   WORD_entertainment
# -0.017039 I-Plot   WORD_giving
# -0.017051 I-Actor  SUF_rs
# -0.017061 I-Character_Name SUF_oy
# -0.017116 B-Director SUF_ger
# -0.017151 B-Plot   WORD_lesbian
# -0.017172 B-Actor  WORD_anton
# -0.017211 B-Plot   SUF_ter
# -0.017228 I-Origin SUF_rth
# -0.017296 I-Plot   SUF_ls
# -0.017469 I-Origin WORD_jim
# -0.017476 I-Soundtrack SUF_le
# -0.017535 B-Actor  SUF_rly
# -0.017592 I-Actor  WORD_cunningham
# -0.017667 I-Plot   WORD_avoiding
# -0.017809 I-Origin WORD_van
# -0.017872 I-Director SUF_lly
# -0.017893 I-Plot   WORD_rico
# -0.017911 I-Quote  WORD_shoot
# -0.017916 I-Quote  WORD_make
# -0.018012 B-Character_Name SUF_ree
# -0.018040 I-Relationship WORD_ludlum
# -0.018368 I-Plot   WORD_cut
# -0.018381 B-Quote  SUF_ly
# -0.018464 B-Plot   SUF_it
# -0.018552 I-Character_Name SUF_ese
# -0.018570 B-Director SUF_ary
# -0.018600 I-Plot   WORD_stalks
# -0.018660 I-Plot   WORD_pittsburgh
# -0.018786 I-Plot   WORD_side
# -0.018938 I-Plot   WORD_speaks
# -0.018973 I-Plot   WORD_marked
# -0.018993 B-Director WORD_new
# -0.019054 I-Plot   WORD_creator
# -0.019113 I-Actor  WORD_nicole
# -0.019204 I-Actor  SUF_tra
# -0.019218 B-Character_Name SUF_nt
# -0.019367 I-Genre  SUF_rks
# -0.019381 I-Plot   WORD_wits
# -0.019451 I-Actor  WORD_greene
# -0.019560 I-Actor  SUF_ael
# -0.019613 B-Plot   SUF_eld
# -0.019746 B-Director SUF_ain
# -0.019754 I-Actor  WORD_mitchell
# -0.019756 I-Plot   WORD_returns
# -0.019825 B-Plot   SUF_uce
# -0.019840 B-Origin SUF_ar
# -0.019909 I-Plot   WORD_details
# -0.019930 I-Plot   WORD_legion
# -0.020195 I-Actor  SUF_gs
# -0.020202 I-Opinion SUF_ted
# -0.020319 I-Plot   WORD_questions
# -0.020390 I-Quote  WORD_will
# -0.020457 I-Quote  SUF_ion
# -0.020464 I-Plot   WORD_macy
# -0.020477 I-Plot   WORD_intergalactic
# -0.020499 B-Soundtrack SUF_e
# -0.020501 I-Plot   WORD_laugh
# -0.020520 I-Plot   SUF_ebs
# -0.020553 I-Plot   SUF_lex
# -0.020800 I-Actor  WORD_sylvester
# -0.020809 I-Plot   SUF_lop
# -0.020856 I-Plot   WORD_bathroom
# -0.020939 I-Plot   WORD_had
# -0.021003 I-Plot   WORD_chilling
# -0.021075 B-Plot   SUF_ce
# -0.021089 I-Plot   WORD_opens
# -0.021244 B-Plot   WORD_animal
# -0.021246 I-Director WORD_martin
# -0.021440 I-Plot   SUF_had
# -0.021480 I-Plot   WORD_finding
# -0.021554 B-Plot   SUF_hia
# -0.021627 I-Origin SUF_ta
# -0.021663 B-Character_Name SUF_h
# -0.021694 I-Genre  WORD_biographical
# -0.021723 I-Origin WORD_smith
# -0.021787 I-Plot   WORD_worked
# -0.021798 B-Plot   WORD_french
# -0.021799 I-Genre  SUF_ual
# -0.021815 I-Opinion SUF_is
# -0.021831 I-Origin SUF_lis
# -0.021848 B-Plot   WORD_inspired
# -0.021863 I-Genre  SUF_le
# -0.021916 I-Actor  SUF_ric
# -0.021952 I-Origin SUF_nd
# -0.021968 I-Quote  SUF_e
# -0.022068 I-Plot   SUF_ix
# -0.022079 I-Origin WORD_movies
# -0.022118 B-Plot   WORD_original
# -0.022185 I-Plot   SUF_gst
# -0.022185 I-Plot   WORD_amongst
# -0.022219 I-Plot   WORD_reunite
# -0.022462 I-Actor  WORD_ashton
# -0.022496 I-Plot   WORD_greed
# -0.022504 I-Plot   SUF_hs
# -0.022508 I-Origin SUF_tan
# -0.022522 I-Plot   SUF_gly
# -0.022545 I-Plot   SUF_ren
# -0.022594 I-Origin WORD_elizabeth
# -0.022742 I-Plot   WORD_cult
# -0.022975 I-Plot   WORD_collection
# -0.023005 I-Opinion SUF_ie
# -0.023226 B-Character_Name SUF_ent
# -0.023330 I-Opinion SUF_ry
# -0.023411 I-Plot   WORD_robs
# -0.023425 I-Plot   WORD_shooting
# -0.023569 I-Plot   WORD_official
# -0.023580 I-Plot   WORD_scoot
# -0.023622 I-Plot   SUF_til
# -0.023622 I-Plot   WORD_until
# -0.023695 I-Plot   WORD_wives
# -0.023741 I-Plot   WORD_location
# -0.023772 I-Plot   WORD_ewoks
# -0.023836 I-Plot   WORD_tell
# -0.023908 I-Actor  WORD_nicholas
# -0.023989 I-Character_Name SUF_ost
# -0.024375 I-Plot   WORD_switch
# -0.024423 B-Actor  SUF_ve
# -0.024442 I-Plot   WORD_talked
# -0.024453 I-Relationship WORD_fi
# -0.024732 B-Relationship SUF_ck
# -0.024789 I-Plot   WORD_chest
# -0.024869 I-Plot   WORD_craft
# -0.024879 I-Character_Name SUF_ll
# -0.024949 I-Quote  SUF_ons
# -0.025085 I-Character_Name SUF_erg
# -0.025117 I-Relationship WORD_at
# -0.025177 B-Character_Name SUF_bie
# -0.025421 I-Plot   WORD_jumping
# -0.025532 I-Origin SUF_rgo
# -0.025534 I-Plot   WORD_massive
# -0.025554 B-Plot   WORD_leading
# -0.025689 I-Plot   WORD_marty
# -0.025875 I-Plot   WORD_apple
# -0.025896 I-Actor  SUF_ida
# -0.025908 I-Plot   WORD_sequel
# -0.025936 B-Plot   SUF_rn
# -0.025942 I-Relationship SUF_ci
# -0.025999 B-Plot   SUF_als
# -0.026014 B-Plot   SUF_cks
# -0.026151 I-Opinion SUF_id
# -0.026310 I-Origin SUF_rl
# -0.026479 B-Genre  SUF_th
# -0.026545 I-Plot   WORD_production
# -0.026721 I-Origin SUF_st
# -0.026776 I-Relationship SUF_ses
# -0.026790 I-Quote  WORD_trying
# -0.026817 B-Actor  SUF_pie
# -0.026875 I-Plot   WORD_asian
# -0.026986 I-Opinion WORD_well
# -0.027105 B-Plot   WORD_over
# -0.027109 I-Plot   SUF_con
# -0.027146 B-Origin SUF_ory
# -0.027248 I-Plot   SUF_mic
# -0.027352 B-Origin SUF_d
# -0.027426 I-Plot   WORD_fab
# -0.027508 I-Plot   WORD_steps
# -0.027637 B-Relationship SUF_a
# -0.027666 I-Origin SUF_ces
# -0.027694 I-Quote  WORD_known
# -0.027841 I-Plot   WORD_larger
# -0.027874 I-Origin WORD_suzanne
# -0.027907 I-Plot   WORD_pregnant
# -0.027908 I-Plot   WORD_trains
# -0.027944 I-Character_Name WORD_show
# -0.027945 I-Relationship SUF_rs
# -0.027987 I-Plot   WORD_nobody
# -0.028282 I-Origin WORD_oil
# -0.028397 I-Plot   WORD_some
# -0.028419 I-Plot   SUF_lad
# -0.028419 I-Plot   WORD_clad
# -0.028539 I-Actor  SUF_nk
# -0.028553 I-Plot   WORD_destroy
# -0.028831 I-Plot   SUF_gia
# -0.028831 I-Plot   WORD_georgia
# -0.028885 I-Quote  SUF_im
# -0.028962 I-Origin SUF_up
# -0.029013 B-Relationship SUF_ted
# -0.029083 B-Actor  SUF_t
# -0.029163 I-Plot   WORD_kristen
# -0.029316 I-Plot   WORD_uncle
# -0.029345 I-Plot   WORD_berlin
# -0.029409 I-Plot   WORD_won
# -0.029445 I-Origin SUF_nny
# -0.029469 B-Character_Name SUF_ake
# -0.029562 B-Plot   SUF_ues
# -0.029658 I-Plot   SUF_pes
# -0.029661 I-Relationship SUF_ase
# -0.029723 I-Plot   WORD_agreed
# -0.029880 I-Actor  SUF_ark
# -0.030057 I-Origin SUF_ren
# -0.030066 B-Origin SUF_his
# -0.030066 B-Origin WORD_this
# -0.030108 I-Plot   SUF_ot
# -0.030139 I-Origin SUF_ann
# -0.030161 B-Plot   SUF_eed
# -0.030268 I-Quote  WORD_got
# -0.030406 I-Plot   WORD_camelot
# -0.030455 I-Plot   SUF_ge
# -0.030477 I-Origin WORD_teen
# -0.030480 I-Plot   WORD_pair
# -0.030508 I-Plot   WORD_change
# -0.030639 I-Plot   WORD_institute
# -0.030805 B-Genre  SUF_li
# -0.030855 B-Character_Name SUF_m
# -0.030958 I-Origin SUF_n
# -0.031016 I-Character_Name SUF_ans
# -0.031101 B-Plot   WORD_name
# -0.031108 B-Character_Name SUF_ta
# -0.031241 I-Plot   SUF_oom
# -0.031283 I-Plot   WORD_cannibalistic
# -0.031370 B-Quote  SUF_ing
# -0.031387 B-Relationship SUF_rs
# ...
# -0.431489 I-Plot   WORD_voiced
# -0.431951 I-Plot   SUF_sic
# -0.432068 I-Plot   SUF_ddy
# -0.432742 I-Plot   WORD_dorothy
# -0.433303 I-Actor  SUF_u
# -0.435361 I-Plot   SUF_ept
# -0.436059 B-Opinion SUF_o
# -0.437044 I-Plot   WORD_longs
# -0.437511 B-Genre  SUF_in
# -0.437516 I-Plot   SUF_3
# -0.437546 B-Plot   SUF_ton
# -0.437769 B-Actor  SUF_ous
# -0.437982 I-Plot   WORD_word
# -0.438637 I-Plot   WORD_speaking
# -0.439251 I-Actor  SUF_il
# -0.439343 I-Opinion SUF_se
# -0.439494 I-Plot   WORD_adversity
# -0.440969 I-Plot   WORD_your
# -0.441284 I-Plot   WORD_scar
# -0.444108 I-Plot   SUF_han
# -0.444229 I-Plot   SUF_lle
# -0.444284 I-Plot   WORD_threats
# -0.444392 B-Director SUF_ng
# -0.444533 I-Plot   WORD_memorable
# -0.444731 I-Actor  WORD_t
# -0.445084 I-Plot   SUF_ke
# -0.445938 I-Plot   SUF_ara
# -0.447012 I-Quote  SUF_d
# -0.447765 I-Plot   WORD_considered
# -0.448155 I-Plot   HAS_NUM
# -0.448687 I-Plot   WORD_lot
# -0.448719 I-Plot   WORD_5
# -0.449599 I-Plot   SUF_rge
# -0.449790 B-Actor  SUF_rs
# -0.450685 I-Plot   WORD_focused
# -0.450876 I-Plot   WORD_b
# -0.450986 I-Plot   SUF_row
# -0.451708 I-Plot   SUF_itt
# -0.453967 B-Plot   SUF_ver
# -0.454079 I-Plot   WORD_musical
# -0.454317 I-Director SUF_ke
# -0.455314 I-Plot   WORD_awards
# -0.455422 I-Plot   WORD_l
# -0.455752 I-Genre  SUF_p
# -0.456157 I-Plot   SUF_ark
# -0.456606 I-Plot   WORD_largest
# -0.456821 B-Plot   SUF_a
# -0.456924 I-Plot   WORD_most
# -0.457033 I-Plot   SUF_m
# -0.458139 B-Plot   SUF_ise
# -0.458769 I-Plot   WORD_light
# -0.458958 I-Plot   WORD_rest
# -0.458994 B-Character_Name WORD_jackie
# -0.459431 I-Origin SUF_e
# -0.459462 I-Plot   SUF_tu
# -0.459867 I-Plot   SUF_eus
# -0.460064 I-Plot   SUF_tie
# -0.461596 I-Plot   WORD_kate
# -0.462488 I-Plot   WORD_five
# -0.463265 I-Origin SUF_t
# -0.463442 I-Plot   SUF_lan
# -0.463769 I-Actor  WORD_rodriguez
# -0.463775 I-Quote  SUF_r
# -0.463903 B-Genre  WORD_music
# -0.465068 B-Plot   SUF_ick
# -0.465925 I-Actor  SUF_cer
# -0.466047 I-Plot   WORD_itself
# -0.466273 B-Year   SUF_y
# -0.466310 I-Plot   WORD_showed
# -0.466783 B-Plot   SUF_ong
# -0.467125 I-Plot   SUF_oe
# -0.467188 I-Plot   WORD_just
# -0.467432 I-Plot   WORD_live
# -0.467694 B-Quote  SUF_s
# -0.467961 I-Plot   WORD_hop
# -0.468645 I-Plot   SUF_ph
# -0.468917 I-Plot   WORD_map
# -0.469594 I-Plot   WORD_loosely
# -0.469638 B-Opinion SUF_ay
# -0.470082 I-Plot   SUF_eck
# -0.470476 B-Opinion SUF_ted
# -0.470515 I-Plot   SUF_uss
# -0.471446 I-Actor  WORD_macfarlane
# -0.471953 I-Relationship SUF_r
# -0.474663 B-Plot   SUF_id
# -0.475250 I-Plot   WORD_move
# -0.475428 I-Plot   WORD_shower
# -0.475645 I-Plot   SUF_ven
# -0.476201 I-Plot   WORD_twist
# -0.476370 I-Plot   WORD_audience
# -0.476646 I-Plot   SUF_gor
# -0.477696 I-Plot   WORD_stage
# -0.478886 I-Actor  SUF_ive
# -0.480349 I-Plot   WORD_half
# -0.480958 I-Relationship SUF_ld
# -0.481203 I-Actor  SUF_ory
# -0.481316 B-Director SUF_uel
# -0.483236 B-Actor  SUF_p
# -0.483764 I-Plot   SUF_tch
# -0.484421 I-Plot   SUF_cup
# -0.485068 I-Opinion SUF_i
# -0.486813 B-Character_Name SUF_her
# -0.487585 I-Actor  SUF_ian
# -0.487791 I-Director SUF_re
# -0.487847 I-Relationship SUF_k
# -0.488349 I-Plot   WORD_greatest
# -0.488452 I-Quote  SUF_ar
# -0.488590 I-Plot   SUF_lay
# -0.489341 I-Origin WORD_d
# -0.489854 I-Plot   SUF_k
# -0.491657 I-Plot   SUF_eal
# -0.492055 I-Plot   SUF_ops
# -0.495813 I-Plot   WORD_favorite
# -0.495944 I-Director SUF_y
# -0.497478 I-Plot   WORD_camera
# -0.498317 I-Plot   WORD_develops
# -0.498392 I-Plot   SUF_los
# -0.498446 I-Plot   WORD_lord
# -0.498718 I-Plot   SUF_tin
# -0.498918 I-Plot   WORD_mickey
# -0.499232 I-Origin SUF_r
# -0.499428 I-Plot   WORD_phrase
# -0.500907 B-Plot   WORD_real
# -0.501113 I-Plot   SUF_vid
# -0.501159 I-Plot   SUF_eld
# -0.501426 I-Origin SUF_d
# -0.501655 I-Plot   SUF_ino
# -0.502674 B-Plot   WORD_does
# -0.502703 I-Origin SUF_a
# -0.503118 B-Plot   WORD_series
# -0.503632 I-Plot   SUF_ump
# -0.503891 B-Plot   SUF_rst
# -0.505340 I-Genre  SUF_red
# -0.505880 I-Actor  SUF_uez
# -0.506184 I-Relationship WORD_set
# -0.506238 I-Plot   SUF_ne
# -0.506651 I-Plot   WORD_every
# -0.506693 B-Plot   SUF_x
# -0.507371 I-Director WORD_s
# -0.507502 I-Plot   WORD_spent
# -0.507834 B-Character_Name SUF_me
# -0.508162 I-Plot   WORD_futuristic
# -0.508483 I-Plot   WORD_brown
# -0.509895 I-Plot   WORD_role
# -0.510068 I-Plot   WORD_screen
# -0.510617 I-Plot   SUF_emy
# -0.511050 I-Plot   SUF_eo
# -0.511054 I-Director SUF_d
# -0.511473 I-Director SUF_p
# -0.511520 I-Plot   WORD_marvel
# -0.511521 I-Plot   WORD_capture
# -0.511651 I-Plot   WORD_epic
# -0.512880 I-Plot   SUF_len
# -0.513450 B-Character_Name SUF_ney
# -0.513839 I-Plot   SUF_ta
# -0.514262 I-Genre  SUF_n
# -0.515680 I-Plot   WORD_harry
# -0.515689 B-Quote  SUF_l
# -0.517016 I-Character_Name SUF_ry
# -0.517247 I-Plot   SUF_ise
# -0.518457 B-Plot   WORD_by
# -0.519241 I-Plot   SUF_za
# -0.519250 B-Opinion WORD_the
# -0.520063 I-Actor  SUF_rk
# -0.521335 I-Plot   SUF_tum
# -0.521384 I-Plot   SUF_nes
# -0.521875 B-Origin SUF_f
# -0.522786 I-Actor  SUF_ky
# -0.522842 I-Genre  WORD_adaptation
# -0.522862 I-Plot   WORD_hamlet
# -0.523226 I-Director SUF_t
# -0.523549 I-Origin WORD_hunter
# -0.524553 B-Plot   SUF_us
# -0.524725 B-Plot   SUF_ger
# -0.525110 I-Plot   WORD_feature
# -0.525825 B-Plot   SUF_rd
# -0.526247 I-Plot   SUF_ode
# -0.526936 I-Plot   WORD_steve
# -0.526936 B-Plot   SUF_med
# -0.527323 B-Quote  SUF_d
# -0.527546 B-Opinion SUF_hat
# -0.528109 I-Relationship SUF_an
# -0.528220 I-Plot   SUF_ob
# -0.528298 I-Plot   SUF_red
# -0.528644 I-Plot   SUF_iam
# -0.528994 I-Character_Name SUF_as
# -0.529741 I-Plot   WORD_water
# -0.530113 I-Plot   WORD_thomas
# -0.530441 I-Actor  SUF_or
# -0.530697 I-Plot   WORD_hal
# -0.531010 I-Plot   SUF_ey
# -0.531160 B-Quote  SUF_r
# -0.532410 I-Plot   WORD_put
# -0.534605 I-Plot   WORD_aldous
# -0.534607 B-Plot   SUF_mes
# -0.535964 I-Relationship SUF_er
# -0.536000 I-Plot   SUF_ris
# -0.536379 B-Actor  SUF_s
# -0.536975 I-Plot   WORD_h
# -0.537487 I-Actor  SUF_b
# -0.539818 I-Plot   WORD_private
# -0.539937 B-Actor  SUF_sh
# -0.540109 I-Plot   SUF_ggs
# -0.540420 I-Plot   WORD_telling
# -0.542007 I-Character_Name SUF_c
# -0.542919 I-Plot   SUF_hy
# -0.543169 I-Origin SUF_b
# -0.545227 B-Plot   SUF_ms
# -0.545320 I-Director SUF_ce
# -0.545354 I-Plot   WORD_britons
# -0.545582 I-Plot   WORD_fairytale
# -0.545656 I-Origin SUF_her
# -0.546545 I-Plot   WORD_roles
# -0.550810 I-Relationship WORD_action
# -0.551465 I-Plot   SUF_ler
# -0.551491 I-Plot   WORD_versions
# -0.551945 I-Plot   SUF_get
# -0.553611 I-Origin SUF_se
# -0.555004 I-Plot   WORD_jr
# -0.555585 I-Plot   SUF_ott
# -0.555640 I-Plot   SUF_rie
# -0.559429 I-Plot   SUF_e
# -0.560147 I-Genre  SUF_ing
# -0.561666 I-Plot   WORD_voices
# -0.562558 B-Origin SUF_er
# -0.562592 I-Plot   WORD_fans
# -0.563137 I-Year   SUF_y
# -0.564018 I-Plot   WORD_afraid
# -0.564144 I-Plot   SUF_ye
# -0.564526 I-Actor  SUF_edy
# -0.564744 I-Character_Name SUF_al
# -0.566151 I-Plot   SUF_uts
# -0.567003 B-Actor  SUF_ery
# -0.567057 I-Plot   SUF_ael
# -0.567781 I-Relationship SUF_ar
# -0.568318 I-Plot   SUF_hur
# -0.568688 I-Plot   WORD_brothers
# -0.568717 I-Plot   SUF_ams
# -0.569408 I-Plot   SUF_ese
# -0.569449 I-Plot   WORD_shakespeare
# -0.569474 I-Plot   WORD_befriend
# -0.570333 B-Plot   WORD_do
# -0.570462 I-Plot   WORD_rob
# -0.570954 I-Plot   WORD_book
# -0.571068 I-Plot   WORD_members
# -0.572073 I-Plot   WORD_fourth
# -0.572297 I-Actor  SUF_ven
# -0.574109 I-Plot   WORD_focusing
# -0.574165 I-Plot   SUF_kin
# -0.574176 B-Character_Name SUF_ry
# -0.574331 I-Origin SUF_nk
# -0.574612 I-Plot   WORD_comedy
# -0.574906 I-Plot   SUF_ul
# -0.574912 B-Director SUF_le
# -0.575396 I-Relationship SUF_ge
# -0.575403 B-Opinion SUF_he
# -0.577117 I-Opinion SUF_en
# -0.577139 I-Plot   SUF_oks
# -0.577270 I-Plot   SUF_llo
# -0.578630 I-Plot   WORD_because
# -0.579210 I-Plot   WORD_few
# -0.579478 I-Plot   WORD_x
# -0.580326 I-Plot   WORD_distant
# -0.580518 I-Director SUF_e
# -0.580728 B-Plot   WORD_were
# -0.581304 B-Origin SUF_ck
# -0.583071 I-Origin WORD_frank
# -0.585430 I-Plot   SUF_ald
# -0.586207 I-Plot   WORD_action
# -0.587396 I-Plot   WORD_portrayal
# -0.589506 I-Plot   WORD_song
# -0.589952 I-Actor  SUF_ter
# -0.590126 I-Director SUF_ed
# -0.593689 I-Plot   SUF_yle
# -0.594136 I-Plot   SUF_bal
# -0.594684 I-Plot   SUF_ony
# -0.595185 I-Actor  SUF_ew
# -0.595479 I-Actor  WORD_movie
# -0.596387 I-Quote  HAS_NUM
# -0.596870 I-Plot   SUF_d
# -0.597405 I-Plot   SUF_eed
# -0.597709 I-Plot   WORD_picture
# -0.598143 I-Director SUF_ly
# -0.598492 I-Plot   WORD_grant
# -0.599617 I-Plot   WORD_acting
# -0.600343 I-Plot   WORD_released
# -0.602335 I-Actor  SUF_ave
# -0.603573 B-Actor  WORD_bryan
# -0.604359 B-Director SUF_ion
# -0.606381 I-Plot   SUF_li
# -0.606922 I-Director SUF_ve
# -0.606971 I-Plot   SUF_nne
# -0.607642 I-Plot   SUF_ten
# -0.607758 I-Actor  SUF_o
# -0.608520 B-Plot   WORD_around
# -0.608961 I-Plot   WORD_voice
# -0.609310 I-Plot   WORD_eliot
# -0.612039 B-Actor  SUF_hen
# -0.612201 I-Director SUF_ss
# -0.613082 I-Plot   WORD_hit
# -0.613426 I-Plot   WORD_flight
# -0.614067 I-Actor  SUF_ake
# -0.614080 I-Plot   SUF_est
# -0.615869 I-Character_Name WORD_a
# -0.616914 B-Actor  SUF_ody
# -0.617142 I-Quote  SUF_as
# -0.618371 I-Plot   SUF_us
# -0.618411 I-Plot   WORD_me
# -0.618914 I-Director SUF_ng
# -0.619794 I-Actor  SUF_ho
# -0.620613 I-Genre  SUF_h
# -0.621499 B-Year   SUF_e
# -0.622443 B-Genre  SUF_ory
# -0.622884 I-Plot   SUF_go
# -0.623725 I-Plot   SUF_by
# -0.624487 I-Plot   WORD_prime
# -0.624761 I-Plot   WORD_title
# -0.624970 I-Plot   SUF_nor
# -0.626024 I-Plot   SUF_ohn
# -0.626024 I-Plot   WORD_john
# -0.627042 I-Plot   WORD_depicts
# -0.629103 I-Genre  SUF_g
# -0.629445 I-Genre  SUF_all
# -0.630288 I-Plot   WORD_third
# -0.633929 I-Plot   SUF_h
# -0.634465 I-Plot   SUF_yn
# -0.636855 I-Plot   SUF_nn
# -0.637104 B-Plot   SUF_u
# -0.637865 I-Plot   WORD_novel
# -0.639481 I-Plot   WORD_actual
# -0.639604 B-Year   SUF_s
# -0.640280 B-Year   SUF_00
# -0.640349 I-Plot   WORD_trilogy
# -0.641154 I-Plot   SUF_r
# -0.641347 I-Plot   WORD_tells
# -0.641560 I-Plot   WORD_alongside
# -0.642107 I-Plot   WORD_eastwood
# -0.642702 I-Plot   SUF_el
# -0.644084 I-Plot   WORD_budget
# -0.644606 I-Plot   SUF_nny
# -0.644887 I-Character_Name WORD_and
# -0.645156 I-Plot   SUF_eve
# -0.647566 I-Award  SUF_er
# -0.648111 I-Plot   SUF_hor
# -0.648539 I-Actor  SUF_ata
# -0.649948 I-Plot   WORD_e
# -0.649960 I-Plot   SUF_les
# -0.650119 I-Director SUF_ack
# -0.651681 I-Plot   WORD_brings
# -0.652243 I-Plot   WORD_scary
# -0.654065 I-Actor  SUF_t
# -0.655503 I-Actor  SUF_lm
# -0.657035 I-Plot   WORD_score
# -0.657237 I-Plot   WORD_frank
# -0.658554 I-Relationship SUF_ce
# -0.660991 I-Plot   WORD_part
# -0.663389 I-Quote  WORD_and
# -0.664357 I-Actor  SUF_st
# -0.665122 B-Director SUF_ll
# -0.667169 I-Actor  SUF_vie
# -0.670393 I-Quote  SUF_ne
# -0.671632 I-Plot   WORD_dante
# -0.671882 B-Plot   SUF_son
# -0.673580 I-Plot   WORD_centers
# -0.673817 I-Plot   WORD_dr
# -0.676275 I-Award  SUF_t
# -0.677377 B-Plot   SUF_on
# -0.678082 I-Plot   WORD_best
# -0.678271 I-Plot   WORD_its
# -0.681140 I-Plot   WORD_popular
# -0.682804 I-Plot   SUF_os
# -0.686103 I-Origin SUF_ly
# -0.686487 I-Director WORD_movie
# -0.687735 I-Plot   SUF_tty
# -0.688402 I-Plot   WORD_hours
# -0.689367 I-Director SUF_vie
# -0.689651 B-Actor  SUF_hey
# -0.689776 I-Actor  SUF_sh
# -0.689876 B-Actor  SUF_he
# -0.691932 I-Origin WORD_peter
# -0.697329 I-Plot   WORD_mike
# -0.698806 I-Plot   WORD_roberts
# -0.703084 B-Plot   SUF_ie
# -0.704373 I-Plot   SUF_dd
# -0.704569 I-Plot   WORD_deals
# -0.705174 I-Plot   SUF_g
# -0.705381 I-Plot   WORD_m
# -0.708697 I-Origin SUF_in
# -0.709438 I-Plot   WORD_multiple
# -0.709607 I-Actor  WORD_huston
# -0.711215 I-Plot   SUF_uce
# -0.711655 I-Plot   SUF_to
# -0.713775 I-Plot   SUF_oto
# -0.715360 I-Quote  SUF_te
# -0.717838 B-Actor  SUF_ed
# -0.717839 I-Plot   SUF_ah
# -0.718411 I-Plot   SUF_int
# -0.719376 I-Plot   WORD_stars
# -0.720928 I-Plot   WORD_rose
# -0.721093 I-Quote  SUF_en
# -0.722767 B-Actor  SUF_ar
# -0.723567 I-Year   SUF_e
# -0.723633 B-Actor  SUF_ven
# -0.724915 I-Plot   SUF_rre
# -0.727021 I-Plot   WORD_disney
# -0.728872 B-Actor  SUF_ng
# -0.729272 I-Plot   SUF_is
# -0.729891 I-Quote  SUF_ed
# -0.729962 I-Actor  SUF_c
# -0.730192 I-Origin SUF_o
# -0.731992 I-Soundtrack SUF_d
# -0.733427 I-Plot   WORD_actor
# -0.734289 I-Actor  SUF_ero
# -0.734780 B-Director WORD_the
# -0.741423 I-Relationship WORD_television
# -0.743454 B-Plot   SUF_nes
# -0.744159 B-Director SUF_us
# -0.744515 B-Director SUF_st
# -0.744633 I-Actor  SUF_p
# -0.747583 I-Opinion SUF_k
# -0.747628 I-Plot   SUF_gan
# -0.748685 B-Plot   WORD_james
# -0.752376 I-Character_Name SUF_ing
# -0.755173 I-Quote  SUF_ry
# -0.756001 I-Award  WORD_for
# -0.759985 I-Plot   WORD_i
# -0.765207 B-Actor  SUF_nd
# -0.766325 I-Plot   WORD_bates
# -0.770161 I-Plot   WORD_animated
# -0.770394 I-Relationship SUF_en
# -0.771788 I-Plot   SUF_lms
# -0.773541 I-Plot   SUF_sa
# -0.773560 I-Genre  HAS_NUM
# -0.774324 I-Character_Name SUF_ed
# -0.776013 B-Plot   SUF_les
# -0.776446 I-Actor  SUF_ent
# -0.777378 I-Actor  SUF_ad
# -0.777782 I-Plot   SUF_ois
# -0.779572 I-Actor  WORD_anderson
# -0.780890 I-Plot   WORD_cast
# -0.781034 B-Director HAS_NUM
# -0.785118 I-Plot   WORD_famously
# -0.791367 I-Actor  WORD_nelson
# -0.792793 I-Plot   WORD_playing
# -0.793346 I-Plot   WORD_portrays
# -0.795430 I-Actor  WORD_cameron
# -0.796425 I-Plot   SUF_rad
# -0.798867 I-Plot   SUF_in
# -0.800872 B-Plot   SUF_rt
# -0.801630 I-Plot   WORD_plot
# -0.801942 I-Plot   SUF_ker
# -0.805078 I-Plot   SUF_y
# -0.806314 B-Director SUF_he
# -0.806623 I-Actor  SUF_me
# -0.808733 B-Plot   SUF_is
# -0.817822 B-Actor  SUF_st
# -0.825284 I-Opinion SUF_a
# -0.826863 I-Plot   WORD_starring
# -0.832454 I-Director SUF_c
# -0.838064 I-Director WORD_animation
# -0.840000 I-Actor  WORD_who
# -0.840952 B-Genre  WORD_the
# -0.843477 I-Plot   SUF_x
# -0.850720 I-Plot   SUF_mon
# -0.852018 I-Plot   SUF_c
# -0.852060 I-Plot   WORD_lee
# -0.853212 I-Plot   SUF_on
# -0.854653 I-Plot   WORD_filming
# -0.855986 I-Plot   WORD_original
# -0.861544 B-Plot   SUF_ved
# -0.862376 I-Opinion SUF_an
# -0.862791 I-Plot   SUF_o
# -0.863717 I-Plot   WORD_sean
# -0.868793 I-Genre  SUF_o
# -0.870480 B-Plot   SUF_i
# -0.870527 I-Plot   WORD_cartoon
# -0.873039 I-Origin WORD_j
# -0.878478 I-Plot   SUF_ki
# -0.880834 I-Actor  SUF_s
# -0.881278 I-Plot   SUF_alf
# -0.885039 I-Plot   WORD_k
# -0.892152 I-Plot   SUF_eg
# -0.892645 B-Genre  SUF_he
# -0.896902 I-Actor  WORD_a
# -0.906832 I-Plot   WORD_cage
# -0.908160 I-Plot   WORD_installment
# -0.912893 I-Plot   WORD_rings
# -0.914699 I-Director SUF_al
# -0.914755 I-Plot   WORD_actors
# -0.926036 I-Quote  SUF_se
# -0.928729 I-Origin SUF_g
# -0.933527 I-Plot   WORD_r
# -0.934982 I-Relationship SUF_a
# -0.937534 I-Plot   SUF_hn
# -0.938723 I-Plot   WORD_mark
# -0.942642 I-Plot   SUF_els
# -0.944611 B-Actor  SUF_ion
# -0.947802 B-Character_Name SUF_ll
# -0.952723 I-Genre  WORD_feature
# -0.953357 I-Plot   WORD_documentary
# -0.953630 I-Plot   WORD_plays
# -0.956926 I-Plot   WORD_focuses
# -0.957651 I-Actor  HAS_NUM
# -0.960332 I-Plot   SUF_ley
# -0.988596 I-Plot   SUF_z
# -0.988667 I-Plot   SUF_ell
# -0.994085 I-Plot   SUF_ie
# -0.996436 B-Character_Name WORD_the
# -1.001511 I-Director SUF_ic
# -1.009327 I-Actor  WORD_burton
# -1.010112 B-Character_Name SUF_st
# -1.010919 I-Plot   SUF_v
# -1.011094 I-Plot   WORD_called
# -1.024717 I-Plot   SUF_ray
# -1.028364 I-Director SUF_m
# -1.028967 I-Plot   WORD_involving
# -1.030377 I-Plot   WORD_played
# -1.034939 I-Plot   SUF_rry
# -1.039551 I-Plot   SUF_fer
# -1.045418 I-Plot   SUF_a
# -1.052550 B-Director SUF_ing
# -1.061604 I-Award  WORD_including
# -1.062756 I-Plot   WORD_o
# -1.066627 I-Plot   SUF_l
# -1.067361 I-Plot   WORD_george
# -1.069435 B-Character_Name SUF_ous
# -1.072357 I-Plot   WORD_lawrence
# -1.081603 I-Actor  SUF_ing
# -1.082825 I-Plot   WORD_t
# -1.085632 I-Plot   WORD_classic
# -1.099200 I-Plot   WORD_d
# -1.100907 B-Actor  WORD_the
# -1.100943 I-Plot   WORD_robert
# -1.107882 I-Plot   WORD_fat
# -1.121959 I-Actor  SUF_ic
# -1.125778 I-Actor  SUF_lay
# -1.126354 I-Plot   WORD_features
# -1.130093 I-Plot   WORD_involves
# -1.135018 I-Plot   SUF_tt
# -1.175571 I-Plot   WORD_james
# -1.177798 B-Actor  SUF_al
# -1.184868 I-Plot   WORD_movies
# -1.195204 I-Director SUF_ion
# -1.215988 I-Plot   WORD_jack
# -1.224498 I-Plot   SUF_las
# -1.236962 I-Plot   WORD_featuring
# -1.270476 I-Plot   SUF_eth
# -1.272428 I-Actor  WORD_and
# -1.272496 I-Actor  WORD_s
# -1.277323 I-Plot   WORD_my
# -1.290023 I-Plot   SUF_ron
# -1.291064 I-Genre  SUF_t
# -1.309725 B-Actor  WORD_a
# -1.341200 I-Plot   WORD_series
# -1.349438 I-Actor  WORD_of
# -1.370159 I-Genre  SUF_s
# -1.399796 I-Actor  SUF_ar
# -1.401740 I-Plot   SUF_lo
# -1.410955 I-Plot   WORD_based
# -1.462987 I-Plot   SUF_car
# -1.466221 I-Plot   SUF_i
# -1.475871 I-Plot   SUF_yan
# -1.534486 I-Plot   SUF_u
# -1.619879 I-Actor  SUF_ed

# %% [markdown]
# # 1. Split the training data into 80% training, 20% development set (5 marks)
# Split the training data (`training_data`) into two lists: one split of the first 80% of the instances of `training_data`, which you will use for training your CRF, and the remaining 20% for testing. Once you've done this re-run the above code such that the tagger is trained on the 80% split and tested on the 20% split, and you obtain the classification report output and confusion heatmap output for the results of testing. Do not use the test data as it is above for testing/viewing results for now. Record the results by saving the classification report output as a string somewhere in the notebook for future reference as you go through.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test = train_test_split(training_data, train_size=0.8, test_size=0.2, shuffle=False, stratify=None)

# %%
# Train the CRF BIO-tag tagger
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features)  # initialize tagger with get_features function

print("training tagger...")
ct.train(x_train, TAGGER_PATH)
print("done")
# Out:
# training tagger...
# done

# %%
print("testing tagger...")
preds = []
x20 = []
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    x20.extend(sent_true)
print("done")
# Out:
# testing tagger...
# done

# %%
print(classification_report(x20, preds))
print(precision_recall_fscore_support(x20, preds, average='macro'))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.87      0.87      0.87      1231
#          B-Award       0.76      0.60      0.67        75
# B-Character_Name       0.65      0.13      0.22       212
#       B-Director       0.86      0.67      0.75       472
#          B-Genre       0.86      0.78      0.82       805
#        B-Opinion       0.47      0.23      0.30       160
#         B-Origin       0.58      0.44      0.50       159
#           B-Plot       0.49      0.46      0.47      1221
#          B-Quote       0.67      0.17      0.27        24
#   B-Relationship       0.82      0.41      0.55       125
#     B-Soundtrack       0.00      0.00      0.00        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.89      0.84      0.87      1731
#          I-Award       0.79      0.81      0.80       202
# I-Character_Name       0.61      0.12      0.20       165
#       I-Director       0.86      0.66      0.75       456
#          I-Genre       0.79      0.74      0.76       576
#        I-Opinion       0.07      0.10      0.08        84
#         I-Origin       0.66      0.71      0.68       729
#           I-Plot       0.84      0.95      0.89     11448
#          I-Quote       0.56      0.19      0.28       176
#   I-Relationship       0.59      0.41      0.48       240
#     I-Soundtrack       0.00      0.00      0.00        41
#           I-Year       0.77      0.82      0.79        33
#                O       0.86      0.83      0.85     10223
#
#         accuracy                           0.83     31304
#        macro avg       0.65      0.52      0.55     31304
#     weighted avg       0.82      0.83      0.82     31304
#
# (0.6511792441568742, 0.5165182905442266, 0.5535187309051867, None)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
#                   precision    recall  f1-score   support
#
#          B-Actor       0.87      0.87      0.87      1231
#          B-Award       0.76      0.60      0.67        75
#     B-Character_Name   0.65      0.13      0.22       212
#       B-Director       0.86      0.67      0.75       472
#          B-Genre       0.86      0.78      0.82       805
#        B-Opinion       0.47      0.23      0.30       160
#         B-Origin       0.58      0.44      0.50       159
#           B-Plot       0.49      0.46      0.47      1221
#          B-Quote       0.67      0.17      0.27        24
#     B-Relationship     0.82      0.41      0.55       125
#     B-Soundtrack       0.00      0.00      0.00        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.89      0.84      0.87      1731
#          I-Award       0.79      0.81      0.80       202
#     I-Character_Name   0.61      0.12      0.20       165
#       I-Director       0.86      0.66      0.75       456
#          I-Genre       0.79      0.74      0.76       576
#        I-Opinion       0.07      0.10      0.08        84
#         I-Origin       0.66      0.71      0.68       729
#           I-Plot       0.84      0.95      0.89     11448
#          I-Quote       0.56      0.19      0.28       176
#     I-Relationship     0.59      0.41      0.48       240
#     I-Soundtrack       0.00      0.00      0.00        41
#           I-Year       0.77      0.82      0.79        33
#                O       0.86      0.83      0.85     10223
#
#         accuracy                           0.83     31304
#        macro avg       0.65      0.52      0.55     31304
#     weighted avg       0.82      0.83      0.82     31304
#
#     (0.6511792441568742, 0.5165182905442266, 0.5535187309051867, None)

# %% [markdown]
#     Lowest precision:
#
#     B-Opinion
#     B-Plot
#     B-Soundtrack
#     I-Opinion
#     I-Soundtrack
#
#     Lowest recall:
#
#     B-Character_Name
#     B-Soundtrack
#     I-Character_Name
#     I-Opinion
#     I-Soundtrack

# %%
def confusion_matrix_heatmap(x20, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(x20))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(x20, preds, labels = labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!

# %%
confusion_matrix_heatmap(x20, preds)

# %% [markdown]
# # 2. Error analysis 1: False positives (5 marks)
#
# Performing error analyses is a key part of improving your NLP applications. For the 5 classes which have the lowest precision, according to the results table from your 20% development data, print out all the sentences where there is a false positive for that class (i.e. the label is predicted in the predicted label for a given word by the tagger, but this is not present in the corresponding ground truth label for that word). HINT: This may most easily be achieved by editing the code above beginning `print("testing tagger...")` and ending `print("done")`. Have a look at these errors closely, and think about which features could be added to reduce the number of these errors.

# %%
preds = []
truelabels = []
falselabel =[]
false_positive_sentences = []
categories = ["B-Opinion", "B-Plot", "B-Soundtrack", "I-Opinion", "I-Soundtrack"]
for sent in x_test:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    word=[s[0] for s in sent]
    for i in range(len(sent)):
      if sent_preds[i] != sent_true[i]: 
        if sent_preds[i] in categories:
          false_positive_sentences.append(word)
          truelabels.append(sent_true)
          falselabel.append(sent_preds)

# %%
from prettytable import PrettyTable

# %%
for i in range(len(false_positive_sentences)):
  x = PrettyTable()
  x.field_names = ["Sentence", "True Label", "Predicted Label"]
  for j in range(len(false_positive_sentences[i])):
    x.add_row([false_positive_sentences[i][j], truelabels[i][j], falselabel[i][j]])
  print(x)
# Out:
# Streaming output truncated to the last 5000 lines.
# +-----------+------------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  disney  | B-Director |    B-Director   |
# |  movie   |     O      |        O        |
# |   that   |     O      |        O        |
# | features |     O      |        O        |
# | lifelike |   B-Plot   |        O        |
# |   cars   |   I-Plot   |      B-Plot     |
# |   that   |   I-Plot   |      I-Plot     |
# |   can    |   I-Plot   |      I-Plot     |
# |   talk   |   I-Plot   |      I-Plot     |
# |   and    |   I-Plot   |      I-Plot     |
# | interact |   I-Plot   |      I-Plot     |
# |   with   |   I-Plot   |      I-Plot     |
# |   each   |   I-Plot   |      I-Plot     |
# |  other   |   I-Plot   |      I-Plot     |
# |   that   |   I-Plot   |      I-Plot     |
# |   also   |   I-Plot   |      I-Plot     |
# |   race   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |     what    |     O      |        O        |
# |      is     |     O      |        O        |
# |     the     |     O      |        O        |
# | documentary |  B-Genre   |     B-Genre     |
# |     that    |     O      |        O        |
# |      is     |     O      |        O        |
# |   written   |     O      |        O        |
# |   directed  |     O      |        O        |
# |     and     |     O      |        O        |
# |   starred   |     O      |        O        |
# |   michael   | B-Director |    B-Director   |
# |    moore    | I-Director |    I-Director   |
# |    about    |     O      |        O        |
# |     the     |   B-Plot   |        O        |
# |    highly   |   I-Plot   |      B-Plot     |
# |  profitable |   I-Plot   |      I-Plot     |
# |   american  |   I-Plot   |      I-Plot     |
# |    health   |   I-Plot   |      I-Plot     |
# |     care    |   I-Plot   |      I-Plot     |
# |   industry  |   I-Plot   |      I-Plot     |
# |      to     |   I-Plot   |      I-Plot     |
# |    other    |   I-Plot   |      I-Plot     |
# |   nations   |   I-Plot   |      I-Plot     |
# +-------------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  famous  | B-Opinion  |    B-Opinion    |
# |   cult   | I-Opinion  |     B-Genre     |
# | classic  | I-Opinion  |     I-Genre     |
# |  movie   |     O      |        O        |
# |  about   |   B-Plot   |        O        |
# |   the    |   I-Plot   |      B-Plot     |
# |   girl   |   I-Plot   |      I-Plot     |
# |  whose   |   I-Plot   |      I-Plot     |
# |  first   |   I-Plot   |      I-Plot     |
# |   love   |   I-Plot   |      I-Plot     |
# | returns  |   I-Plot   |      I-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   form   |   I-Plot   |      I-Plot     |
# |    of    |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |  pirate  |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |  kidnap  |   I-Plot   |      I-Plot     |
# |   her    |   I-Plot   |      I-Plot     |
# |   from   |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   man    |   I-Plot   |      I-Plot     |
# |   she    |   I-Plot   |      I-Plot     |
# |    is    |   I-Plot   |      I-Plot     |
# |  about   |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |  marry   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+----------------+-----------------+
# | Sentence |   True Label   | Predicted Label |
# +----------+----------------+-----------------+
# |   what   |       O        |        O        |
# |    is    |       O        |        O        |
# |   the    |       O        |        O        |
# |  final   | B-Relationship |  B-Relationship |
# |   film   | I-Relationship |  I-Relationship |
# |    in    | I-Relationship |  I-Relationship |
# |    an    | I-Relationship |  I-Relationship |
# |    8     | I-Relationship |  I-Relationship |
# |   film   | I-Relationship |  I-Relationship |
# |  series  | I-Relationship |  I-Relationship |
# | starring |       O        |        O        |
# |    a     |       O        |      B-Plot     |
# |   boy    |     B-Plot     |      I-Plot     |
# |  wizard  |     I-Plot     |      I-Plot     |
# |   and    |     I-Plot     |      I-Plot     |
# |   his    |     I-Plot     |      I-Plot     |
# | friends  |     I-Plot     |      I-Plot     |
# +----------+----------------+-----------------+
# +-------------------+----------------+-----------------+
# |      Sentence     |   True Label   | Predicted Label |
# +-------------------+----------------+-----------------+
# |        what       |       O        |        O        |
# |         is        |       O        |        O        |
# |        the        |       O        |        O        |
# |       first       | B-Relationship |  B-Relationship |
# |       movie       | I-Relationship |  I-Relationship |
# |         in        | I-Relationship |  I-Relationship |
# |         a         | I-Relationship |  I-Relationship |
# |       series      | I-Relationship |  I-Relationship |
# |      starring     |       O        |        O        |
# |     sigourney     |    B-Actor     |     B-Actor     |
# |       weaver      |    I-Actor     |     I-Actor     |
# |        and        |       O        |        O        |
# |      directed     |       O        |        O        |
# |         by        |       O        |        O        |
# |       james       |   B-Director   |    B-Director   |
# |      cameron      |   I-Director   |    I-Director   |
# |       about       |     B-Plot     |        O        |
# |         a         |     I-Plot     |      B-Plot     |
# |     spaceship     |     I-Plot     |      I-Plot     |
# |        that       |     I-Plot     |      I-Plot     |
# |     encounters    |     I-Plot     |      I-Plot     |
# |      terrible     |     I-Plot     |      I-Plot     |
# | extraterrestrials |     I-Plot     |      I-Plot     |
# +-------------------+----------------+-----------------+
# +-----------+----------------+-----------------+
# |  Sentence |   True Label   | Predicted Label |
# +-----------+----------------+-----------------+
# |    what   |       O        |        O        |
# |     is    |       O        |        O        |
# |    the    |       O        |        O        |
# |   first   | B-Relationship |        O        |
# |   movie   | I-Relationship |        O        |
# |     of    | I-Relationship |        O        |
# |    the    | I-Relationship |        O        |
# |   series  | I-Relationship |        O        |
# |  directed |       O        |        O        |
# |     by    |       O        |        O        |
# |   steven  |   B-Director   |    B-Director   |
# | spielberg |   I-Director   |    I-Director   |
# |   about   |     B-Plot     |        O        |
# |     an    |     I-Plot     |      B-Plot     |
# |   island  |     I-Plot     |      I-Plot     |
# | inhabited |     I-Plot     |      I-Plot     |
# |     by    |     I-Plot     |      I-Plot     |
# | dinosaurs |     I-Plot     |      I-Plot     |
# +-----------+----------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# |    is    |      O       |        O        |
# |   the    |      O       |        O        |
# |   fred   |   B-Actor    |     B-Actor     |
# | astaire  |   I-Actor    |     I-Actor     |
# |   and    |      O       |        O        |
# |   judy   |   B-Actor    |     B-Actor     |
# | garland  |   I-Actor    |     I-Actor     |
# |  movie   |      O       |        O        |
# |   with   |      O       |        O        |
# |   the    |      O       |        O        |
# |   song   | B-Soundtrack |        O        |
# |  about   | I-Soundtrack |        O        |
# |    a     | I-Soundtrack |      B-Plot     |
# |  bonnet  | I-Soundtrack |      I-Plot     |
# +----------+--------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  jason   |  B-Actor   |     B-Actor     |
# | statham  |  I-Actor   |     I-Actor     |
# |  where   |     O      |        O        |
# |    he    |   B-Plot   |        O        |
# |  plays   |   I-Plot   |        O        |
# |    a     |   I-Plot   |        O        |
# |  hitman  |   I-Plot   |      B-Plot     |
# |   who    |   I-Plot   |      I-Plot     |
# | teaches  |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   art    |   I-Plot   |      I-Plot     |
# |    of    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   job    |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# | another  |   I-Plot   |      I-Plot     |
# |   guy    |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |   jim    |  B-Actor   |     B-Actor     |
# |  carrey  |  I-Actor   |     I-Actor     |
# |   and    |     O      |        O        |
# |   ewan   |  B-Actor   |     B-Actor     |
# | mcgregor |  I-Actor   |     I-Actor     |
# |  movie   |     O      |        O        |
# |  about   |     O      |        O        |
# |    a     |     O      |      B-Plot     |
# |   man    |   B-Plot   |      I-Plot     |
# |   who    |   I-Plot   |      I-Plot     |
# |  after   |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |   car    |   I-Plot   |      I-Plot     |
# |  crash   |   I-Plot   |      I-Plot     |
# | decides  |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   live   |   I-Plot   |      I-Plot     |
# |   life   |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# | fullest  |   I-Plot   |      I-Plot     |
# |   ends   |   I-Plot   |      I-Plot     |
# |    up    |   I-Plot   |      I-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |   jail   |   I-Plot   |      I-Plot     |
# |   and    |   I-Plot   |      I-Plot     |
# |  meets   |   I-Plot   |      I-Plot     |
# |   his    |   I-Plot   |      I-Plot     |
# |   gay    |   I-Plot   |      I-Plot     |
# |  lover   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    what   |     O      |        O        |
# |     is    |     O      |        O        |
# |    the    |     O      |        O        |
# |    mel    | B-Director |    B-Director   |
# |   brooks  | I-Director |    I-Director   |
# |    film   |     O      |        O        |
# |   which   |     O      |        O        |
# |    also   |     O      |        O        |
# |  features |     O      |        O        |
# |    gene   |  B-Actor   |     B-Actor     |
# |   wilder  |  I-Actor   |     I-Actor     |
# |    that   |     O      |        O        |
# |   tells   |   B-Plot   |        O        |
# |    the    |   I-Plot   |        O        |
# |   story   |   I-Plot   |      B-Plot     |
# |     of    |   I-Plot   |      I-Plot     |
# |    two    |   I-Plot   |      I-Plot     |
# |    men    |   I-Plot   |      I-Plot     |
# |   trying  |   I-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |   create  |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |  broadway |   I-Plot   |      I-Plot     |
# |    flop   |   I-Plot   |      I-Plot     |
# |     in    |   I-Plot   |      I-Plot     |
# |   order   |   I-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |    bilk   |   I-Plot   |      I-Plot     |
# |   money   |   I-Plot   |      I-Plot     |
# |    from   |   I-Plot   |      I-Plot     |
# | investors |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |  about   |   B-Plot   |        O        |
# |    a     |   I-Plot   |      B-Plot     |
# | teenager |   I-Plot   |      I-Plot     |
# |   and    |   I-Plot   |      I-Plot     |
# |   his    |   I-Plot   |      I-Plot     |
# |  quest   |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   find   |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# | perfect  |   I-Plot   |      I-Plot     |
# |   date   |   I-Plot   |      I-Plot     |
# |   for    |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |  dance   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------+------------------+
# |  Sentence | True Label | Predicted Label  |
# +-----------+------------+------------------+
# |    what   |     O      |        O         |
# |     is    |     O      |        O         |
# |    the    |     O      |        O         |
# |   movie   |     O      |        O         |
# |   about   |     O      |        O         |
# |    the    |     O      |      B-Plot      |
# | barbarian |   B-Plot   |      I-Plot      |
# |    who    |   I-Plot   |      I-Plot      |
# |    goes   |   I-Plot   |      I-Plot      |
# |   after   |   I-Plot   |      I-Plot      |
# |    the    |   I-Plot   |      I-Plot      |
# |  warlord  |   I-Plot   |      I-Plot      |
# |    that   |   I-Plot   |      I-Plot      |
# | destroyed |   I-Plot   |      I-Plot      |
# |    his    |   I-Plot   |      I-Plot      |
# |  village  |   I-Plot   |      I-Plot      |
# |    and    |   I-Plot   |      I-Plot      |
# |   killed  |   I-Plot   |      I-Plot      |
# |    his    |   I-Plot   |      I-Plot      |
# |   father  |   I-Plot   |      I-Plot      |
# |     as    |   I-Plot   |      I-Plot      |
# |     a     |   I-Plot   |      I-Plot      |
# |   child   |   I-Plot   |      I-Plot      |
# | featuring |     O      |        O         |
# |   jason   |  B-Actor   |     B-Actor      |
# |   momoa   |  I-Actor   |     I-Actor      |
# |    and    |     O      |        O         |
# |    rose   |  B-Actor   | B-Character_Name |
# |  mcgowan  |  I-Actor   | I-Character_Name |
# +-----------+------------+------------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |  about   |     O      |        O        |
# |   the    |     O      |      B-Plot     |
# |   cop    |   B-Plot   |      I-Plot     |
# |   who    |   I-Plot   |      I-Plot     |
# |   goes   |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   find   |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# | missing  |   I-Plot   |      I-Plot     |
# |   girl   |   I-Plot   |      I-Plot     |
# |    on    |   I-Plot   |      I-Plot     |
# |    an    |   I-Plot   |      I-Plot     |
# |  island  |   I-Plot   |      I-Plot     |
# |   that   |   I-Plot   |      I-Plot     |
# |  turns   |   I-Plot   |      I-Plot     |
# |   out    |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   have   |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# | strange  |   I-Plot   |      I-Plot     |
# |  sexual  |   I-Plot   |      I-Plot     |
# |   cult   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |  about   |     O      |        O        |
# |   the    |     O      |      B-Plot     |
# |   guy    |   B-Plot   |      I-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |   jail   |   I-Plot   |      I-Plot     |
# |   and    |   I-Plot   |      I-Plot     |
# |   had    |   I-Plot   |      I-Plot     |
# |   that   |   I-Plot   |      I-Plot     |
# |  really  |   I-Plot   |      I-Plot     |
# |   big    |   I-Plot   |      I-Plot     |
# |   man    |   I-Plot   |      I-Plot     |
# |   that   |   I-Plot   |      I-Plot     |
# |   died   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |  based   |     O      |        O        |
# |    on    |     O      |        O        |
# |  actual  |     O      |      B-Plot     |
# |  events  |     O      |      I-Plot     |
# |  where   |     O      |      I-Plot     |
# |    a     |   B-Plot   |      I-Plot     |
# |   ship   |   I-Plot   |      I-Plot     |
# | crashes  |   I-Plot   |      I-Plot     |
# |   into   |   I-Plot   |      I-Plot     |
# |    an    |   I-Plot   |      I-Plot     |
# | iceberg  |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    what   |     O      |        O        |
# |     is    |     O      |        O        |
# |    the    |     O      |        O        |
# |   movie   |     O      |        O        |
# |   based   |     O      |     B-Origin    |
# |     on    |  B-Origin  |     I-Origin    |
# |    the    |  I-Origin  |     I-Origin    |
# |   louisa  |  I-Origin  |     I-Origin    |
# |    may    |  I-Origin  |     I-Origin    |
# |  allcott  |  I-Origin  |     I-Origin    |
# |   novel   |  I-Origin  |     I-Origin    |
# |   about   |   B-Plot   |        O        |
# |     a     |   I-Plot   |      B-Plot     |
# |   mother  |   I-Plot   |      I-Plot     |
# |    and    |   I-Plot   |      I-Plot     |
# |    her    |   I-Plot   |      I-Plot     |
# |     4     |   I-Plot   |      I-Plot     |
# | daughters |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |   from   |     O      |        O        |
# |   the    |     O      |        O        |
# |    60    |   B-Year   |      B-Year     |
# |    s     |   I-Year   |      I-Year     |
# |   that   |     O      |        O        |
# |   has    |     O      |        O        |
# |   rita   |  B-Actor   |     B-Actor     |
# |  moreno  |  I-Actor   |     I-Actor     |
# |   and    |     O      |        O        |
# |    is    |     O      |        O        |
# |  about   |   B-Plot   |        O        |
# |   star   |   I-Plot   |      B-Plot     |
# | crossed  |   I-Plot   |      I-Plot     |
# |  lovers  |   I-Plot   |      I-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |   new    |   I-Plot   |      I-Plot     |
# |   york   |   I-Plot   |      I-Plot     |
# |   city   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +------------+------------+-----------------+
# |  Sentence  | True Label | Predicted Label |
# +------------+------------+-----------------+
# |    what    |     O      |        O        |
# |     is     |     O      |        O        |
# |    the     |     O      |        O        |
# |   movie    |     O      |        O        |
# |    made    |     O      |        O        |
# |     in     |     O      |        O        |
# |    1984    |   B-Year   |      B-Year     |
# |   about    |     O      |        O        |
# |     a      |     O      |      B-Plot     |
# |   famous   |   B-Plot   |      I-Plot     |
# |   heavy    |   I-Plot   |      I-Plot     |
# |   metal    |   I-Plot   |      I-Plot     |
# |    band    |   I-Plot   |      I-Plot     |
# |     on     |   I-Plot   |      I-Plot     |
# |     a      |   I-Plot   |      I-Plot     |
# |  fateful   |   I-Plot   |      I-Plot     |
# |    tour    |   I-Plot   |      I-Plot     |
# | documented |     O      |      I-Plot     |
# |     by     |     O      |      I-Plot     |
# |    rob     | B-Director |      I-Plot     |
# |   reiner   | I-Director |      I-Plot     |
# +------------+------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |     what    |     O      |        O        |
# |      is     |     O      |        O        |
# |     the     |     O      |        O        |
# |    movie    |     O      |        O        |
# |   released  |     O      |        O        |
# |      in     |     O      |        O        |
# |     2010    |   B-Year   |      B-Year     |
# |     with    |     O      |        O        |
# |     one     |     O      |        O        |
# |      of     |     O      |        O        |
# |     ryan    |  B-Actor   |     B-Actor     |
# |    dunns    |  I-Actor   |     I-Actor     |
# |    final    |     O      |      B-Plot     |
# | appearances |     O      |      I-Plot     |
# |     and     |     O      |      I-Plot     |
# |      a      |   B-Plot   |      I-Plot     |
# |     ton     |   I-Plot   |      I-Plot     |
# |      of     |   I-Plot   |      I-Plot     |
# |  ridiculous |   I-Plot   |      I-Plot     |
# |    stunts   |   I-Plot   |      I-Plot     |
# +-------------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# | starring |     O      |        O        |
# |   adam   |  B-Actor   |     B-Actor     |
# | sandler  |  I-Actor   |     I-Actor     |
# |   and    |     O      |        O        |
# |   they   |   B-Plot   |        O        |
# |   are    |   I-Plot   |        O        |
# |    in    |   I-Plot   |        O        |
# |   jail   |   I-Plot   |        O        |
# |   and    |   I-Plot   |        O        |
# |   play   |   I-Plot   |        O        |
# | football |   I-Plot   |      B-Plot     |
# | against  |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |  guards  |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    what   |     O      |        O        |
# |     is    |     O      |        O        |
# |    the    |     O      |        O        |
# |   movie   |     O      |        O        |
# |  starring |     O      |        O        |
# |   adrien  |  B-Actor   |     B-Actor     |
# |   brody   |  I-Actor   |     I-Actor     |
# |     as    |     O      |        O        |
# |     a     |     O      |      B-Plot     |
# | scientist |   B-Plot   |      I-Plot     |
# |    who    |   I-Plot   |      I-Plot     |
# |  combines |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |    dna    |   I-Plot   |      I-Plot     |
# |     of    |   I-Plot   |      I-Plot     |
# | different |   I-Plot   |      I-Plot     |
# |  animals  |   I-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |   create  |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |    new    |   I-Plot   |      I-Plot     |
# |   hybrid  |   I-Plot   |      I-Plot     |
# |   animal  |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +--------------+------------+-----------------+
# |   Sentence   | True Label | Predicted Label |
# +--------------+------------+-----------------+
# |     what     |     O      |        O        |
# |      is      |     O      |        O        |
# |     the      |     O      |        O        |
# |    movie     |     O      |        O        |
# |   starring   |     O      |        O        |
# |     matt     |  B-Actor   |     B-Actor     |
# |    damon     |  I-Actor   |     I-Actor     |
# |      in      |   B-Plot   |        O        |
# |     iraq     |   I-Plot   |        O        |
# |    where     |   I-Plot   |        O        |
# |      he      |   I-Plot   |      B-Plot     |
# |  discovers   |   I-Plot   |      I-Plot     |
# |    faulty    |   I-Plot   |      I-Plot     |
# | intelligence |   I-Plot   |      I-Plot     |
# |     and      |   I-Plot   |      I-Plot     |
# |     goes     |   I-Plot   |      I-Plot     |
# |    rogue     |   I-Plot   |      I-Plot     |
# +--------------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |   that   |     O      |        O        |
# |  clint   |  B-Actor   |     B-Actor     |
# | eastwood |  I-Actor   |     I-Actor     |
# |    is    |     O      |        O        |
# |   well   |     O      |        O        |
# |  known   |     O      |        O        |
# |   for    |     O      |        O        |
# |   that   |     O      |        O        |
# |   was    |     O      |        O        |
# |   made   |     O      |        O        |
# |    in    |     O      |        O        |
# |   1966   |   B-Year   |      B-Year     |
# |  about   |   B-Plot   |        O        |
# | cowboys  |   I-Plot   |      B-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   west   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |   that   |     O      |        O        |
# |   was    |     O      |        O        |
# |    a     |     O      |        O        |
# |  remake  |  B-Origin  |        O        |
# |    of    |  I-Origin  |        O        |
# |    an    |  I-Origin  |        O        |
# |   old    |  I-Origin  |        O        |
# |  movie   |  I-Origin  |        O        |
# |  about   |   B-Plot   |        O        |
# |    a     |   I-Plot   |      B-Plot     |
# |  women   |   I-Plot   |      I-Plot     |
# |   who    |   I-Plot   |      I-Plot     |
# |  falls   |   I-Plot   |      I-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |   love   |   I-Plot   |      I-Plot     |
# |   with   |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   rich   |   I-Plot   |      I-Plot     |
# |  house   |   I-Plot   |      I-Plot     |
# |  owner   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    what   |     O      |        O        |
# |     is    |     O      |        O        |
# |    the    |     O      |        O        |
# |   movie   |     O      |        O        |
# |   where   |     O      |        O        |
# |     a     |     O      |      B-Plot     |
# |   father  |   B-Plot   |      I-Plot     |
# |    and    |   I-Plot   |      I-Plot     |
# |    his    |   I-Plot   |      I-Plot     |
# | estranged |   I-Plot   |      I-Plot     |
# |    son    |   I-Plot   |      I-Plot     |
# |   travel  |   I-Plot   |      I-Plot     |
# |   around  |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |  country  |   I-Plot   |      I-Plot     |
# |    with   |   I-Plot   |      I-Plot     |
# |   their   |   I-Plot   |      I-Plot     |
# |   boxing  |   I-Plot   |      I-Plot     |
# |   robot   |   I-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |    try    |   I-Plot   |      I-Plot     |
# |    and    |   I-Plot   |      I-Plot     |
# |   regain  |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |   glory   |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |   father  |   I-Plot   |      I-Plot     |
# |    knew   |   I-Plot   |      I-Plot     |
# |    when   |   I-Plot   |      I-Plot     |
# |     he    |   I-Plot   |      I-Plot     |
# |    was    |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |   boxer   |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |  where   |     O      |        O        |
# |  actor   |     O      |        O        |
# |   adam   |  B-Actor   |     B-Actor     |
# | sandler  |  I-Actor   |     I-Actor     |
# |  plays   |   B-Plot   |        O        |
# | himself  |   I-Plot   |        O        |
# |    as    |   I-Plot   |        O        |
# |   both   |   I-Plot   |        O        |
# |    a     |   I-Plot   |      B-Plot     |
# |   man    |   I-Plot   |      I-Plot     |
# |   and    |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |  woman   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-------------+------------+------------------+
# |   Sentence  | True Label | Predicted Label  |
# +-------------+------------+------------------+
# |     what    |     O      |        O         |
# |      is     |     O      |        O         |
# |     the     |     O      |        O         |
# |    movie    |     O      |        O         |
# |    where    |     O      |        O         |
# |    kathy    |  B-Actor   | B-Character_Name |
# |    bates    |  I-Actor   | I-Character_Name |
# |    coined   |     O      |      B-Plot      |
# |     the     |     O      |      I-Plot      |
# | catchphrase |     O      |      I-Plot      |
# |   tawanda   |  B-Quote   |      I-Plot      |
# |    while    |     O      |      I-Plot      |
# |  committing |   B-Plot   |      I-Plot      |
# |  vehicular  |   I-Plot   |      I-Plot      |
# |   assault   |   I-Plot   |      I-Plot      |
# +-------------+------------+------------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |  where   |     O      |        O        |
# |   the    |     O      |      B-Plot     |
# |   guy    |   B-Plot   |      I-Plot     |
# |   has    |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   kill   |   I-Plot   |      I-Plot     |
# |   his    |   I-Plot   |      I-Plot     |
# |  future  |   I-Plot   |      I-Plot     |
# |   self   |   I-Plot   |      I-Plot     |
# |   who    |   I-Plot   |      I-Plot     |
# |    is    |   I-Plot   |      I-Plot     |
# |   sent   |   I-Plot   |      I-Plot     |
# |   back   |   I-Plot   |      I-Plot     |
# |    by    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |  mafia   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    what   |     O      |        O        |
# |     is    |     O      |        O        |
# |    the    |     O      |        O        |
# |   movie   |     O      |        O        |
# |    with   |     O      |        O        |
# |   clint   |  B-Actor   |     B-Actor     |
# |  eastwood |  I-Actor   |     I-Actor     |
# |    and    |     O      |        O        |
# |   hilary  |  B-Actor   |     B-Actor     |
# |   swank   |  I-Actor   |     I-Actor     |
# |   about   |     O      |        O        |
# |    the    |     O      |      B-Plot     |
# |   female  |   B-Plot   |      I-Plot     |
# |   boxing  |   I-Plot   |      I-Plot     |
# |  champion |   I-Plot   |      I-Plot     |
# |    who    |   I-Plot   |      I-Plot     |
# |     is    |   I-Plot   |      I-Plot     |
# | paralyzed |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |   with   |     O      |        O        |
# |  marlon  |  B-Actor   |     B-Actor     |
# |  brando  |  I-Actor   |     I-Actor     |
# |   from   |     O      |        O        |
# |   the    |     O      |        O        |
# |    50    |   B-Year   |      B-Year     |
# |    s     |   I-Year   |      I-Year     |
# |  where   |   B-Plot   |        O        |
# |    he    |   I-Plot   |      B-Plot     |
# |  works   |   I-Plot   |      I-Plot     |
# |    on    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |  docks   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |   with   |     O      |        O        |
# |  steve   |  B-Actor   |     B-Actor     |
# | carrell  |  I-Actor   |     I-Actor     |
# |    in    |     O      |        O        |
# |  which   |     O      |        O        |
# |   his    |   B-Plot   |        O        |
# |   wife   |   I-Plot   |        O        |
# |  cheats  |   I-Plot   |        O        |
# |    on    |   I-Plot   |        O        |
# |   him    |   I-Plot   |        O        |
# |   with   |   I-Plot   |        O        |
# |  kevin   |  B-Actor   |     B-Actor     |
# |  bacon   |  I-Actor   |     I-Actor     |
# |   and    |   B-Plot   |        O        |
# |    he    |   I-Plot   |      B-Plot     |
# |  tries   |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   win    |   I-Plot   |      I-Plot     |
# |   her    |   I-Plot   |      I-Plot     |
# |   back   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------------+-----------------+
# | Sentence |    True Label    | Predicted Label |
# +----------+------------------+-----------------+
# |   what   |        O         |        O        |
# |    is    |        O         |        O        |
# |   the    |        O         |        O        |
# |  movie   |        O         |        O        |
# |   with   |        O         |        O        |
# |   the    |     B-Actor      |        O        |
# |   rock   |     I-Actor      |      B-Plot     |
# |   and    |        O         |      I-Plot     |
# |   that   |        O         |      I-Plot     |
# |   guy    |        O         |      I-Plot     |
# |   who    |        O         |      I-Plot     |
# |  plays   |        O         |      I-Plot     |
# |  peeta   | B-Character_Name |      I-Plot     |
# | mellark  | I-Character_Name |      I-Plot     |
# |    on    |        O         |      I-Plot     |
# |  hunger  |        O         |      I-Plot     |
# |  games   |        O         |      I-Plot     |
# +----------+------------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |  movie   |     O      |        O        |
# |   with   |     O      |        O        |
# |   tina   |  B-Actor   |     B-Actor     |
# |   fey    |  I-Actor   |     I-Actor     |
# |   and    |     O      |        O        |
# |  steve   |  B-Actor   |     B-Actor     |
# |  carell  |  I-Actor   |     I-Actor     |
# |    in    |     O      |        O        |
# |  which   |     O      |        O        |
# |   they   |   B-Plot   |        O        |
# |   play   |   I-Plot   |        O        |
# |    a     |   I-Plot   |      B-Plot     |
# |  boring  |   I-Plot   |      I-Plot     |
# | married  |   I-Plot   |      I-Plot     |
# |  couple  |   I-Plot   |      I-Plot     |
# |  whose   |   I-Plot   |      I-Plot     |
# | regular  |   I-Plot   |      I-Plot     |
# |   date   |   I-Plot   |      I-Plot     |
# |  night   |   I-Plot   |      I-Plot     |
# |   gets   |   I-Plot   |      I-Plot     |
# |  messed  |   I-Plot   |      I-Plot     |
# |    up    |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# | musical  |  B-Genre   |     B-Genre     |
# | romance  |  I-Genre   |     I-Genre     |
# | starring |     O      |        O        |
# |   judy   |  B-Actor   |     B-Actor     |
# | garland  |  I-Actor   |     I-Actor     |
# |  james   |  I-Actor   |     I-Actor     |
# |  mason   |  I-Actor   |     I-Actor     |
# |   and    |     O      |        O        |
# |   jack   |  B-Actor   |     B-Actor     |
# |  carson  |  I-Actor   |     I-Actor     |
# |  about   |     O      |        O        |
# |    a     |   B-Plot   |        O        |
# |  movie   |   I-Plot   |        O        |
# |   star   |   I-Plot   |      B-Plot     |
# |  helps   |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |  young   |   I-Plot   |      I-Plot     |
# |  singer  |   I-Plot   |      I-Plot     |
# | actress  |   I-Plot   |      I-Plot     |
# |   find   |   I-Plot   |      I-Plot     |
# |   fame   |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-------------+----------------+-----------------+
# |   Sentence  |   True Label   | Predicted Label |
# +-------------+----------------+-----------------+
# |     what    |       O        |        O        |
# |      is     |       O        |        O        |
# |     the     |       O        |        O        |
# |     name    |       O        |        O        |
# |      of     |       O        |        O        |
# |      a      |       O        |        O        |
# |    disney   |   B-Director   |    B-Director   |
# |    sequel   | B-Relationship |    I-Director   |
# |  featuring  |       O        |        O        |
# |      a      |       O        |        O        |
# |     cast    |       O        |        O        |
# |      of     |       O        |        O        |
# |  different  |       O        |        O        |
# |   talking   |       O        |      B-Plot     |
# | automobiles |       O        |      I-Plot     |
# +-------------+----------------+-----------------+
# +------------+------------+-----------------+
# |  Sentence  | True Label | Predicted Label |
# +------------+------------+-----------------+
# |    what    |     O      |        O        |
# |     is     |     O      |        O        |
# |    the     |     O      |        O        |
# |    name    |     O      |        O        |
# |     of     |     O      |        O        |
# |    that    |     O      |        O        |
# |   movie    |     O      |        O        |
# |   where    |   B-Plot   |        O        |
# |    the     |   I-Plot   |        O        |
# |    main    |   I-Plot   |      B-Plot     |
# |    guy     |   I-Plot   |      I-Plot     |
# |    went    |   I-Plot   |      I-Plot     |
# |    back    |   I-Plot   |      I-Plot     |
# |     in     |   I-Plot   |      I-Plot     |
# |    time    |   I-Plot   |      I-Plot     |
# |     in     |   I-Plot   |      I-Plot     |
# |     a      |   I-Plot   |      I-Plot     |
# | lamborgini |   I-Plot   |      I-Plot     |
# +------------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    what   |     O      |        O        |
# |     is    |     O      |        O        |
# |    the    |     O      |        O        |
# |    name   |     O      |        O        |
# |     of    |     O      |        O        |
# |    that   |     O      |        O        |
# |   movie   |     O      |        O        |
# |   where   |   B-Plot   |        O        |
# |    the    |   I-Plot   |      B-Plot     |
# |    man    |   I-Plot   |      I-Plot     |
# |   saves   |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |    jews   |   I-Plot   |      I-Plot     |
# |    from   |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |   nazis   |   I-Plot   |      I-Plot     |
# |     by    |   I-Plot   |      I-Plot     |
# | employing |   I-Plot   |      I-Plot     |
# |    them   |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |   name   |     O      |        O        |
# |    of    |     O      |        O        |
# |   the    |     O      |        O        |
# |   1994   |   B-Year   |      B-Year     |
# |  movies  |     O      |        O        |
# | directed |     O      |        O        |
# |    by    |     O      |        O        |
# |  george  | B-Director |     B-Actor     |
# |  seaton  | I-Director |     I-Actor     |
# |   and    |     O      |        O        |
# |    is    |     O      |        O        |
# |  about   |   B-Plot   |        O        |
# |    an    |   I-Plot   |      B-Plot     |
# |   old    |   I-Plot   |      I-Plot     |
# |   man    |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |     is    |        O         |        O        |
# |    the    |        O         |        O        |
# |    name   |        O         |        O        |
# |     of    |        O         |        O        |
# |    the    |        O         |        O        |
# |   disney  |    B-Director    |    B-Director   |
# |   movie   |        O         |        O        |
# |   where   |        O         |        O        |
# |  princess | B-Character_Name |      B-Plot     |
# |  jazmine  | I-Character_Name |      I-Plot     |
# |    goes   |      B-Plot      |      I-Plot     |
# |     on    |      I-Plot      |      I-Plot     |
# |     a     |      I-Plot      |      I-Plot     |
# |   magic   |      I-Plot      |      I-Plot     |
# |   carpet  |      I-Plot      |      I-Plot     |
# |    ride   |      I-Plot      |      I-Plot     |
# |    with   |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |   lease   |      I-Plot      |      I-Plot     |
# | character |      I-Plot      |      I-Plot     |
# +-----------+------------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |   name   |     O      |        O        |
# |    of    |     O      |        O        |
# |   the    |     O      |        O        |
# |  disney  | B-Director |    B-Director   |
# |  movie   |     O      |        O        |
# |   with   |     O      |        O        |
# |   the    |     O      |        O        |
# |   baby   |     O      |      B-Plot     |
# | elephant |     O      |      I-Plot     |
# |   with   |     O      |      I-Plot     |
# |   the    |     O      |      I-Plot     |
# |   big    |     O      |      I-Plot     |
# |   ears   |     O      |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |   name   |     O      |        O        |
# |    of    |     O      |        O        |
# |   the    |     O      |        O        |
# |  disney  |  B-Genre   |    B-Director   |
# |  pixar   |  I-Genre   |    I-Director   |
# |  movie   |     O      |        O        |
# |   that   |     O      |        O        |
# |   made   |     O      |        O        |
# |  clown   |     O      |      B-Plot     |
# |   fish   |     O      |      I-Plot     |
# |  become  |     O      |      I-Plot     |
# | popular  |     O      |      I-Plot     |
# |   pets   |     O      |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# |    is    |     O      |        O        |
# |   the    |     O      |        O        |
# |   name   |     O      |        O        |
# |    of    |     O      |        O        |
# |   the    |     O      |        O        |
# |   most   |     O      |        O        |
# |  recent  |     O      |        O        |
# |  famous  | B-Opinion  |        O        |
# | children |  B-Origin  |     B-Origin    |
# |    s     |  I-Origin  |     I-Origin    |
# |   book   |  I-Origin  |     I-Origin    |
# |   that   |     O      |        O        |
# |   was    |     O      |        O        |
# | brought  |     O      |      B-Plot     |
# |    to    |     O      |      I-Plot     |
# |   life   |     O      |      I-Plot     |
# |    on    |     O      |      I-Plot     |
# |   the    |     O      |      I-Plot     |
# |   big    |     O      |      I-Plot     |
# |  screen  |     O      |      I-Plot     |
# +----------+------------+-----------------+
# +--------------+------------+-----------------+
# |   Sentence   | True Label | Predicted Label |
# +--------------+------------+-----------------+
# |     what     |     O      |        O        |
# |      is      |     O      |        O        |
# |     the      |     O      |        O        |
# |     name     |     O      |        O        |
# |      of      |     O      |        O        |
# ...
# |    the    |     O      |        O        |
# | following |     O      |        O        |
# |   films   |     O      |        O        |
# |   listed  |     O      |      B-Plot     |
# |    took   |   B-Plot   |      I-Plot     |
# |   place   |   I-Plot   |      I-Plot     |
# |     in    |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |   french  |   I-Plot   |      I-Plot     |
# |   train   |   I-Plot   |      I-Plot     |
# |  station  |   I-Plot   |      I-Plot     |
# |     in    |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |    1930   |   I-Plot   |      I-Plot     |
# |     s     |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |   which   |     O      |        O        |
# |   period  |  B-Genre   |     B-Genre     |
# |   drama   |  I-Genre   |     I-Genre     |
# |  centered |     O      |        O        |
# |   around  |     O      |        O        |
# |   music   |     O      |        O        |
# |  features |   B-Plot   |        O        |
# |   rival   |   I-Plot   |      B-Plot     |
# | composers |   I-Plot   |      I-Plot     |
# | competing |   I-Plot   |      I-Plot     |
# |  against  |   I-Plot   |      I-Plot     |
# |    each   |   I-Plot   |      I-Plot     |
# |   other   |   I-Plot   |      I-Plot     |
# |     in    |   I-Plot   |      I-Plot     |
# |   vienna  |   I-Plot   |      I-Plot     |
# |   during  |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |     18    |   I-Plot   |      I-Plot     |
# |     th    |   I-Plot   |      I-Plot     |
# |  century  |   I-Plot   |      I-Plot     |
# +-----------+------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |    which    |     O      |        O        |
# |   quentin   | B-Director |    B-Director   |
# |  tarantino  | I-Director |    I-Director   |
# |     film    |     O      |        O        |
# |     told    |     O      |      B-Plot     |
# |     the     |     O      |      I-Plot     |
# |    story    |   B-Plot   |      I-Plot     |
# |      of     |   I-Plot   |      I-Plot     |
# |     two     |   I-Plot   |      I-Plot     |
# |   attempts  |   I-Plot   |      I-Plot     |
# |      to     |   I-Plot   |      I-Plot     |
# | assassinate |   I-Plot   |      I-Plot     |
# |  political  |   I-Plot   |      I-Plot     |
# |   leaders   |   I-Plot   |      I-Plot     |
# |      in     |   I-Plot   |      I-Plot     |
# |     nazi    |   I-Plot   |      I-Plot     |
# |   germany   |   I-Plot   |      I-Plot     |
# +-------------+------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |    which    |     O      |        O        |
# |    steven   | B-Director |    B-Director   |
# |  spielberg  | I-Director |    I-Director   |
# |     film    |     O      |        O        |
# |    tells    |     O      |        O        |
# |     the     |   B-Plot   |        O        |
# |    story    |   I-Plot   |      B-Plot     |
# |      of     |   I-Plot   |      I-Plot     |
# |      a      |   I-Plot   |      I-Plot     |
# |    german   |   I-Plot   |      I-Plot     |
# | businessman |   I-Plot   |      I-Plot     |
# |     who     |   I-Plot   |      I-Plot     |
# |    saved    |   I-Plot   |      I-Plot     |
# |     the     |   I-Plot   |      I-Plot     |
# |    lives    |   I-Plot   |      I-Plot     |
# |      of     |   I-Plot   |      I-Plot     |
# |    nearly   |   I-Plot   |      I-Plot     |
# |      a      |   I-Plot   |      I-Plot     |
# |   thousand  |   I-Plot   |      I-Plot     |
# |     jews    |   I-Plot   |      I-Plot     |
# |    during   |   I-Plot   |      I-Plot     |
# |    world    |   I-Plot   |      I-Plot     |
# |     war     |   I-Plot   |      I-Plot     |
# |      2      |   I-Plot   |      I-Plot     |
# +-------------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |  which   |     O      |        O        |
# |   war    |  B-Genre   |        O        |
# |   film   |     O      |        O        |
# | depicted |     O      |      B-Plot     |
# |   the    |   B-Plot   |      I-Plot     |
# |   life   |   I-Plot   |      I-Plot     |
# |    of    |   I-Plot   |      I-Plot     |
# | ordinary |   I-Plot   |      I-Plot     |
# | sailors  |   I-Plot   |      I-Plot     |
# |    on    |   I-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |  german  |   I-Plot   |      I-Plot     |
# |    u     |   I-Plot   |      I-Plot     |
# |   boat   |   I-Plot   |      I-Plot     |
# |  during  |   I-Plot   |      I-Plot     |
# |  world   |   I-Plot   |      I-Plot     |
# |   war    |   I-Plot   |      I-Plot     |
# |    2     |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |     whos     |        O         |      B-Plot     |
# |    brain     |        O         |      I-Plot     |
# |     did      |        O         |      I-Plot     |
# |      dr      | B-Character_Name |      I-Plot     |
# | frankenstein | I-Character_Name |      I-Plot     |
# |     put      |      B-Plot      |      I-Plot     |
# |      in      |      I-Plot      |      I-Plot     |
# |     the      |      I-Plot      |      I-Plot     |
# |     jar      |      I-Plot      |      I-Plot     |
# +--------------+------------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |     why     |  B-Quote   |      B-Plot     |
# |     were    |  I-Quote   |      I-Plot     |
# |     the     |  I-Quote   |      I-Plot     |
# |  pacifists  |  I-Quote   |      I-Plot     |
# |      so     |  I-Quote   |      I-Plot     |
# |    easily   |  I-Quote   |      I-Plot     |
# |    turned   |  I-Quote   |      I-Plot     |
# |      to     |  I-Quote   |      I-Plot     |
# |    murder   |  I-Quote   |      I-Plot     |
# |   perhaps   |  I-Quote   |      I-Plot     |
# | vegetarians |  I-Quote   |      I-Plot     |
# |     have    |  I-Quote   |      I-Plot     |
# |     the     |  I-Quote   |      I-Plot     |
# |     same    |  I-Quote   |      I-Plot     |
# |     lust    |  I-Quote   |      I-Plot     |
# |     for     |  I-Quote   |      I-Plot     |
# |     life    |  I-Quote   |      I-Plot     |
# |      as     |  I-Quote   |      I-Plot     |
# |     the     |  I-Quote   |      I-Plot     |
# |     rest    |  I-Quote   |      I-Plot     |
# |      of     |  I-Quote   |      I-Plot     |
# |      us     |  I-Quote   |      I-Plot     |
# +-------------+------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    will    |     B-Actor      |     B-Actor     |
# |   forte    |     I-Actor      |     I-Actor     |
# |   plays    |        O         |        O        |
# |     an     |        O         |      B-Plot     |
# |     ex     |      B-Plot      |      I-Plot     |
# |  special   |      I-Plot      |      I-Plot     |
# | operative  |      I-Plot      |      I-Plot     |
# |   trying   |      I-Plot      |      I-Plot     |
# |     to     |      I-Plot      |      I-Plot     |
# |    stop    |      I-Plot      |      I-Plot     |
# |    his     |      I-Plot      |      I-Plot     |
# |    arch    |      I-Plot      |      I-Plot     |
# |   enemy    |      I-Plot      |      I-Plot     |
# |   dieter   | B-Character_Name |      I-Plot     |
# |    von     | I-Character_Name |      I-Plot     |
# |   cunth    | I-Character_Name |      I-Plot     |
# |    from    |      B-Plot      |      I-Plot     |
# | destroying |      I-Plot      |      I-Plot     |
# | washington |      I-Plot      |      I-Plot     |
# |     d      |      I-Plot      |      I-Plot     |
# |     c      |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +--------------+------------+-----------------+
# |   Sentence   | True Label | Predicted Label |
# +--------------+------------+-----------------+
# |   william    | B-Director |     B-Actor     |
# |    brent     | I-Director |     I-Actor     |
# |     bell     | I-Director |     I-Actor     |
# |    wrote     |     O      |        O        |
# |     and      |     O      |        O        |
# |   directed   |     O      |        O        |
# |     this     |     O      |        O        |
# |     2012     |   B-Year   |      B-Year     |
# |    horror    |  B-Genre   |     B-Genre     |
# |    movie     |     O      |        O        |
# |    about     |   B-Plot   |        O        |
# |      a       |   I-Plot   |      B-Plot     |
# |    series    |   I-Plot   |      I-Plot     |
# |      of      |   I-Plot   |      I-Plot     |
# | unauthorized |   I-Plot   |      I-Plot     |
# |  exorcisms   |   I-Plot   |      I-Plot     |
# |      in      |   I-Plot   |      I-Plot     |
# |    italy     |   I-Plot   |      I-Plot     |
# +--------------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |   winona  |  B-Actor   |     B-Actor     |
# |   ryder   |  I-Actor   |     I-Actor     |
# |     is    |     O      |        O        |
# |     a     |  B-Actor   |      B-Plot     |
# |    girl   |  I-Actor   |      I-Plot     |
# |    who    |  I-Actor   |      I-Plot     |
# |    half   |  I-Actor   |      I-Plot     |
# | heartedly |  I-Actor   |      I-Plot     |
# |   tries   |   B-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |     be    |   I-Plot   |      I-Plot     |
# |    part   |   I-Plot   |      I-Plot     |
# |     of    |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |     in    |   I-Plot   |      I-Plot     |
# |   crowd   |   I-Plot   |      I-Plot     |
# |     of    |   I-Plot   |      I-Plot     |
# |    her    |   I-Plot   |      I-Plot     |
# |   school  |   I-Plot   |      I-Plot     |
# |    when   |   I-Plot   |      I-Plot     |
# |    she    |   I-Plot   |      I-Plot     |
# |   meets   |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |   rebel   |   I-Plot   |      I-Plot     |
# |    who    |   I-Plot   |      I-Plot     |
# |  teaches  |   I-Plot   |      I-Plot     |
# |    her    |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |    more   |   I-Plot   |      I-Plot     |
# |  devious  |   I-Plot   |      I-Plot     |
# |    way    |   I-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |    play   |   I-Plot   |      I-Plot     |
# |   social  |   I-Plot   |      I-Plot     |
# |  politics |   I-Plot   |      I-Plot     |
# |     in    |     O      |        O        |
# |    this   |     O      |        O        |
# |    1988   |   B-Year   |      B-Year     |
# |   comedy  |  B-Genre   |     B-Genre     |
# |   drama   |  I-Genre   |     I-Genre     |
# +-----------+------------+-----------------+
# +-----------+------------+-----------------+
# |  Sentence | True Label | Predicted Label |
# +-----------+------------+-----------------+
# |    you    |     O      |      B-Plot     |
# |    are    |     O      |      I-Plot     |
# |   living  |   B-Plot   |      I-Plot     |
# |     in    |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |  pacific  |   I-Plot   |      I-Plot     |
# | northwest |   I-Plot   |      I-Plot     |
# |    and    |   I-Plot   |      I-Plot     |
# |  forming  |   I-Plot   |      I-Plot     |
# |     a     |   I-Plot   |      I-Plot     |
# |   group   |   I-Plot   |      I-Plot     |
# |     of    |   I-Plot   |      I-Plot     |
# | neighbors |   I-Plot   |      I-Plot     |
# |     to    |   I-Plot   |      I-Plot     |
# |    hold   |   I-Plot   |      I-Plot     |
# |    back   |   I-Plot   |      I-Plot     |
# |    the    |   I-Plot   |      I-Plot     |
# |  invading |   I-Plot   |      I-Plot     |
# |   north   |   I-Plot   |      I-Plot     |
# |  koreans  |   I-Plot   |      I-Plot     |
# |    what   |     O      |        O        |
# |   movie   |     O      |        O        |
# |    are    |     O      |        O        |
# |    you    |     O      |        O        |
# |     in    |     O      |        O        |
# +-----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   you    |     O      |      B-Plot     |
# |   are    |     O      |      I-Plot     |
# |   told   |     O      |      I-Plot     |
# |   that   |     O      |      I-Plot     |
# |   who    |     O      |      I-Plot     |
# |   need   |     O      |      I-Plot     |
# |    to    |     O      |      I-Plot     |
# |   rob    |   B-Plot   |      I-Plot     |
# |    a     |   I-Plot   |      I-Plot     |
# |   bank   |   I-Plot   |      I-Plot     |
# |    or    |   I-Plot   |      I-Plot     |
# |   else   |   I-Plot   |      I-Plot     |
# |    by    |   I-Plot   |      I-Plot     |
# |   two    |   I-Plot   |      I-Plot     |
# |  people  |   I-Plot   |      I-Plot     |
# | dressed  |   I-Plot   |      I-Plot     |
# |    in    |   I-Plot   |      I-Plot     |
# |  planet  |   I-Plot   |      I-Plot     |
# |    of    |   I-Plot   |      I-Plot     |
# |   the    |   I-Plot   |      I-Plot     |
# |   apes   |   I-Plot   |      I-Plot     |
# |  masks   |   I-Plot   |      I-Plot     |
# |   what   |     O      |        O        |
# |  movie   |     O      |        O        |
# |   are    |     O      |        O        |
# |   you    |     O      |        O        |
# |    in    |     O      |        O        |
# +----------+------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   you    |  B-Quote   |        O        |
# |   know   |  I-Quote   |        O        |
# |   the    |  I-Quote   |        O        |
# | prefects |  I-Quote   |      B-Plot     |
# | bathroom |  I-Quote   |      I-Plot     |
# |    on    |  I-Quote   |      I-Plot     |
# |   the    |  I-Quote   |      I-Plot     |
# |  fifth   |  I-Quote   |      I-Plot     |
# |  floor   |  I-Quote   |      I-Plot     |
# |    it    |  I-Quote   |      I-Plot     |
# |    s     |  I-Quote   |      I-Plot     |
# |   not    |  I-Quote   |      I-Plot     |
# |    a     |  I-Quote   |      I-Plot     |
# |   bad    |  I-Quote   |      I-Plot     |
# |  place   |  I-Quote   |      I-Plot     |
# |   for    |  I-Quote   |      I-Plot     |
# |    a     |  I-Quote   |      I-Plot     |
# |   bath   |  I-Quote   |      I-Plot     |
# |   just   |  I-Quote   |      I-Plot     |
# |   take   |  I-Quote   |      I-Plot     |
# |   your   |  I-Quote   |      I-Plot     |
# |   egg    |  I-Quote   |      I-Plot     |
# |   and    |  I-Quote   |      I-Plot     |
# |   mull   |  I-Quote   |      I-Plot     |
# |  things  |  I-Quote   |      I-Plot     |
# |   over   |  I-Quote   |      I-Plot     |
# |    in    |  I-Quote   |      I-Plot     |
# |   the    |  I-Quote   |      I-Plot     |
# |   hot    |  I-Quote   |      I-Plot     |
# |  water   |  I-Quote   |      I-Plot     |
# |    is    |     O      |        O        |
# |    a     |     O      |        O        |
# |  quote   |     O      |        O        |
# |   from   |     O      |        O        |
# |  which   |     O      |        O        |
# |    j     |  B-Origin  |     B-Origin    |
# |    k     |  I-Origin  |     I-Origin    |
# | rowling  |  I-Origin  |     I-Origin    |
# |  novel   |  I-Origin  |     I-Origin    |
# |  turned  |     O      |     I-Origin    |
# |  movie   |     O      |     I-Origin    |
# +----------+------------+-----------------+

# %%
false_positive_sentences = np.array(false_positive_sentences)
false_positive_sentences.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (729,)

# %%
new_false_positive_sentences = np.unique(false_positive_sentences)
new_false_positive_sentences.shape
# Out:
# (619,)

# %%
print('False Positive Sentences:')
new_false_positive_sentences
# Out:
# False Positive Sentences:
# array([list(['on', 'a', 'vacation', 'in', 'paris', 'one', 'of', 'three', 'travelers', 'is', 'mistaken', 'for', 'a', 'british', 'heiress']),
#        list(['one', 'of', 'the', 'first', 'disney', 'animated', 'films', 'with', 'beautiful', 'images', 'few', 'lines', 'and', 'a', 'lot', 'of', 'music']),
#        list(['orson', 'welles', 'directed', 'and', 'starred', 'in', 'this', '1965', 'movie', 'about', 'the', 'career', 'of', 'shakespeare', 's', 'sir', 'john', 'falstaff', 'as', 'roistering', 'companion', 'to', 'young', 'prince', 'hal']),
#        list(['orson', 'wells', 'psychological', 'profile', 'of', 'an', 'eccentric', 'billionaire', 'has', 'been', 'voted', 'the', 'greatest', 'movie', 'of', 'all', 'time', 'by', 'some']),
#        list(['paul', 'giamatti', 'and', 'thomas', 'haden', 'church', 'are', 'two', 'men', 'reaching', 'middle', 'age', 'with', 'not', 'much', 'to', 'show', 'but', 'disappointment', 'in', 'this', '2004', 'comedy', 'romance', 'movie']),
#        list(['paul', 'newman', 'starred', 'in', 'this', '1977', 'hockey', 'movie', 'about', 'the', 'struggles', 'of', 'a', 'minor', 'league', 'team']),
#        list(['perseus', 'mortal', 'son', 'of', 'zeus', 'battles', 'the', 'minions', 'of', 'the', 'underworld', 'to', 'stop', 'them', 'from', 'conquering', 'the', 'earth', 'and', 'the', 'heavens', 'in', 'this', '2010', 'action', 'adventure', 'fantasy']),
#        list(['peter', 'hedges', 'directed', 'this', 'charming', 'fantasy', 'based', 'on', 'the', 'story', 'by', 'ahmet', 'zappa', 'about', 'a', 'boy', 'who', 'joins', 'a', 'family', 'by', 'rather', 'unusual', 'means']),
#        list(['peter', 'jackson', 'directed', 'this', 'smash', 'hit', 'starring', 'jack', 'black', 'as', 'a', '1930', 's', 'film', 'maker', 'on', 'a', 'mission', 'to', 'make', 'an', 'unforgettable', 'nature', 'documentary', 'who', 'gets', 'more', 'than', 'he', 'bargained', 'for']),
#        list(['peter', 'sellers', 'is', 'a', 'lowly', 'gardener', 'who', 's', 'simple', 'utterances', 'are', 'mistaken', 'for', 'profound', 'wisdom', 'in', 'this', '1979', 'comedy']),
#        list(['phoebe', 'cates', 'famously', 'rose', 'from', 'the', 'pool', 'removing', 'her', 'red', 'bikini', 'top', 'while', 'sean', 'penn', 'was', 'a', 'stoned', 'spicoli', 'in', 'this', '1982', 'comedy']),
#        list(['play', 'it', 'again', 'sam', 'is', 'one', 'of', 'the', 'memorable', 'quotes', 'from', 'this', 'classic', 'humphrey', 'bogart', 'romance']),
#        list(['ray', 'liotta', 'robert', 'de', 'niro', 'and', 'joe', 'pesci', 'star', 'in', 'this', 'film', 'about', 'gangsters', 'in', 'organized', 'crime']),
#        list(['red', 'riding', 'hood', 'is', 'training', 'in', 'the', 'group', 'of', 'sister', 'hoods', 'when', 'she', 'and', 'the', 'wolf', 'are', 'called', 'to', 'examine', 'the', 'sudden', 'mysterious', 'disappearance', 'of', 'hansel', 'and', 'gretel', 'in', 'this', 'animated', 'feature']),
#        list(['remember', 'that', 'movie', 'where', 'the', 'lion', 'ruled', 'the', 'jungle', 'and', 'his', 'brother', 'turned', 'on', 'him']),
#        list(['renoir', 's', 'look', 'at', 'bourgeois', 'life', 'in', 'france', 'at', 'the', 'onset', 'of', 'world', 'war', 'ii', 'is', 'the', 'plot', 'of', 'this', '1939', 'comedy', 'drama']),
#        list(['richard', 'gere', 'took', 'tap', 'dance', 'lessons', 'for', 'three', 'months', 'to', 'prepare', 'for', 'his', 'role', 'as', 'the', 'criminal', 'defense', 'attorney', 'billy', 'flynn', 'in', 'this', '2002', 'musical']),
#        list(['robert', 'de', 'niro', 'is', 'a', 'former', 'prohibition', 'era', 'jewish', 'gangster', 'who', 'returns', 'to', 'brooklyn', 'over', '30', 'years', 'later', 'in', 'this', '1984', 'crime', 'drama']),
#        list(['robert', 'de', 'niro', 'walked', 'away', 'with', 'the', 'oscar', 'for', 'his', 'role', 'of', 'a', 'boxer', 'who', 'ca', 'n', 't', 'control', 'his', 'temper', 'in', 'this', '1980', 'sports', 'drama', 'directed', 'by', 'martin', 'scorsese']),
#        list(['robert', 'downey', 'jr', 'and', 'zach', 'galifinakis', 'star', 'this', 'comedy', 'about', 'a', 'man', 'traveling', 'with', 'an', 'obnoxious', 'road', 'mate', 'to', 'see', 'his', 'wife', 'before', 'she', 'delivers', 'their', 'child']),
#        list(['romance', 'movie', 'based', 'off', 'of', 'nicholas', 'sparks', 'novel', 'about', 'a', 'marine', 'finding', 'the', 'woman', 'who', 'saved', 'him']),
#        list(['rufus', 't', 'firefly', 'is', 'named', 'president', 'dictator', 'of', 'bankrupt', 'freedonia', 'and', 'declares', 'war', 'on', 'neighboring', 'sylvania', 'over', 'the', 'love', 'of', 'wealthy', 'mrs', 'teasdale', 'is', 'the', 'plot', 'of', 'this', 'classic', 'comedy', 'starring', 'all', 'three', 'of', 'the', 'marx', 'brothers']),
#        list(['russell', 'brandt', 'starred', 'as', 'the', 'title', 'character', 'in', 'this', 'most', 'recent', 'adaption', 'of', 'steve', 'gordon', 's', 'story', 'about', 'a', 'rich', 'drunken', 'playboy', 'who', 'falls', 'in', 'love', 'with', 'a', 'penniless', 'girl']),
#        list(['russell', 'crowe', 'stars', 'in', 'this', 'drama', 'about', 'a', 'intelligent', 'man', 'that', 'accepts', 'secret', 'work', 'but', 'his', 'life', 'turns', 'for', 'the', 'worst']),
#        list(['ryan', 'o', 'neal', 'ca', 'n', 't', 'seem', 'to', 'keep', 'out', 'of', 'trouble', 'whenever', 'barbra', 'streisand', 'is', 'around', 'in', 'this', '1972', 'comedy']),
#        list(['samuel', 'l', 'jackson', 'narrates', 'this', '2011', 'nature', 'documentary', 'about', 'the', 'king', 'of', 'the', 'jungle', 'raising', 'cubs', 'in', 'the', 'wild']),
#        list(['sequel', 'to', 'the', 'popular', 'film', 'starring', 'tiny', 'singing', 'critters']),
#        list(['sequel', 'to', 'the', 'popular', 'story', 'of', 'entering', 'a', 'strange', 'world', 'through', 'a', 'wardrobe']),
#        list(['set', 'in', '1825', 'a', 'man', 'is', 'captured', 'by', 'indians', 'but', 'eventually', 'becomes', 'the', 'leader', 'of', 'the', 'tribe']),
#        list(['stacy', 'keach', 'and', 'james', 'keach', 'play', 'frank', 'and', 'jesse', 'james', 'in', 'this', '1980', 'western', 'about', 'the', 'outlaws', 'and', 'their', 'gang']),
#        list(['stanley', 'kubrick', 'directed', 'this', '1968', 'science', 'fiction', 'classic', 'starring', 'keir', 'dullea', 'gary', 'lockwood', 'and', 'hal', 'the', 'computer']),
#        list(['steve', 'carell', 'starred', 'in', 'this', 'animated', 'movie', 'about', 'a', 'lovable', 'villain', 'with', 'thousands', 'of', 'tiny', 'henchmen']),
#        list(['steven', 'spielberg', 'directed', 'this', '2011', 'drama', 'about', 'a', 'man', 'who', 'enlists', 'in', 'the', 'army', 'when', 'his', 'beloved', 'steed', 'is', 'taken', 'into', 'the', 'cavalry']),
#        list(['steven', 'spielberg', 'personally', 'screened', 'this', '1982', 'film', 'at', 'the', 'white', 'house', 'for', 'ronald', 'reagan', 'and', 'nancy', 'davis']),
#        list(['stopped', 'they', 'must', 'be', 'on', 'this', 'all', 'depends', 'only', 'a', 'fully', 'trained', 'jedi', 'knight', 'with', 'the', 'force', 'as', 'his', 'ally', 'will', 'conquer', 'vader', 'in', 'this', '1980', 'george', 'lucas', 'sequel']),
#        list(['superhero', 'movie', 'where', 'team', 'of', 'superheros', 'get', 'together', 'to', 'defeat', 'threats', 'too', 'big', 'for', 'just', 'one', 'hero']),
#        list(['susan', 'sarandon', 'won', 'an', 'oscar', 'for', 'her', 'role', 'as', 'a', 'nun', 'who', 'develops', 'a', 'special', 'relationship', 'with', 'a', 'prisoner', 'in', 'this', 'drama', 'based', 'on', 'the', 'novel', 'by', 'helen', 'prejean']),
#        list(['tattooine', 'is', 'the', 'home', 'planet', 'for', 'a', 'certain', 'hero', 'in', 'this', 'famous', 'trilogy', 'which', 'is', 'set', 'in', 'a', 'distant', 'galaxy']),
#        list(['the', 'bellas', 'take', 'on', 'their', 'male', 'rivals', 'in', 'a', 'campus', 'competition', 'in', 'this', '2012', 'comedy', 'musical']),
#        list(['the', 'classic', 'scene', 'between', 'burt', 'lancaster', 'and', 'deborah', 'kerr', 'in', 'the', 'rushing', 'water', 'on', 'the', 'beach', 'was', 'a', 'last', 'minute', 'inspiration', 'from', 'the', 'director', 'fred', 'zinnemann', 'in', 'this', 'romantic', 'drama']),
#        list(['the', 'debut', 'movie', 'of', 'the', 'famous', 'director', 'kevin', 'smith', 'featuring', 'his', 'breakout', 'characters', 'jay', 'and', 'silent', 'bob']),
#        list(['the', 'film', 'i', 'm', 'thinking', 'of', 'is', 'a', 'romantic', 'comedy', 'starring', 'jason', 'segel', 'and', 'emily', 'blunt', 'as', 'a', 'couple', 'whose', 'relationship', 'begins', 'to', 'deteriorate', 'the', 'more', 'they', 'put', 'off', 'their', 'wedding']),
#        list(['the', 'last', 'part', 'of', 'a', 'vampire', 'love', 'story', 'between', 'bella', 'and', 'edward']),
#        list(['the', 'lesson', 'of', 'this', 'disney', 'story', 'is', 'do', 'n', 't', 'talk', 'to', 'strangers', 'and', 'do', 'n', 't', 'take', 'short', 'cuts']),
#        list(['the', 'main', 'character', 'of', 'this', 'animated', 'film', 'is', 'a', 'fiery', 'red', 'haired', 'princess', 'who', 'loves', 'archery', 'and', 'has', 'mom', 'issues']),
#        list(['the', 'movie', 'about', 'the', 'famed', 'english', 'hero', 'who', 'steals', 'from', 'the', 'rich', 'and', 'gives', 'to', 'the', 'poor']),
#        list(['the', 'movie', 'about', 'the', 'high', 'school', 'girl', 'who', 'lies', 'about', 'a', 'date', 'and', 'losing', 'her', 'virginity', 'she', 'rides', 'off', 'on', 'a', 'lawnmower', 'with', 'the', 'guy', 'she', 'likes', 'at', 'the', 'end']),
#        list(['the', 'movie', 'adaptation', 'of', 'a', 'high', 'school', 'singing', 'group', 'that', 'brought', 'the', 'fox', 'show', 'into', '3', 'dimensions']),
#        list(['the', 'movie', 'starring', 'emma', 'stone', 'who', 'pretends', 'to', 'be', 'a', 'slut', 'to', 'become', 'more', 'popular', 'at', 'school']),
#        list(['the', 'movie', 'where', 'marty', 'mcfly', 'and', 'doc', 'brown', 'go', 'back', 'in', 'time', 'and', 'have', 'to', 'get', 'marty', 's', 'mom', 'to', 'marry', 'his', 'dad']),
#        list(['the', 'movie', 'where', 'two', 'geeks', 'played', 'by', 'simon', 'pegg', 'and', 'nick', 'frost', 'on', 'their', 'way', 'to', 'comic', 'con', 'meet', 'an', 'alien']),
#        list(['the', 'name', 'of', 'this', 'classic', 'movie', 'is', 'the', 'same', 'as', 'the', 'now', 'famous', 'monster', 'a', 'giant', 'beast', 'that', 'wrecks', 'tokyo']),
#        list(['the', 'producer', 'of', 'this', 'movie', 'was', 'shaken', 'down', 'for', 'a', 'contribution', 'to', 'the', 'campaign', 'of', 'the', 'now', 'convicted', 'felon', 'and', 'former', 'illinois', 'governor', 'rod', 'blagojevich']),
#        list(['the', 'referee', 'in', 'the', 'final', 'match', 'in', 'this', '1984', 'martial', 'arts', 'movie', 'starring', 'ralph', 'macchio', 'is', 'pat', 'e', 'johnson', 'a', 'martial', 'arts', 'expert', 'and', 'former', 'student', 'of', 'chuck', 'norris']),
#        list(['the', 'script', 'was', 'originally', 'written', 'as', 'a', 'sequel', 'to', 'l', 'on', 'the', 'professional', 'and', 'would', 'have', 'focused', 'on', 'natalie', 'portman', 's', 'character', 'mathilda', 'but', 'was', 'later', 'changed', 'to', 'star', 'a', 'main', 'character', 'with', 'south', 'american', 'background']),
#        list(['the', 'second', 'to', 'last', 'movie', 'about', 'a', 'boy', 'wizard', 'and', 'his', 'quest', 'to', 'destroy', 'the', 'most', 'dangerous', 'wizard', 'alive']),
#        list(['the', 'sequel', 'to', 'a', 'popular', 'children', 's', 'movie', 'about', 'talking', 'motor', 'vehicle']),
#        list(['the', 'story', 'of', 't', 'e', 'lawrence', 'a', 'flamboyant', 'and', 'controversial', 'british', 'military', 'figure', 'and', 'his', 'conflicted', 'loyalties', 'during', 'his', 'world', 'war', 'i', 'service', 'in', 'the', 'middle', 'east', 'staring', 'peter', 'o', 'toole']),
#        list(['the', 'tagline', 'for', 'the', 'final', 'installment', 'of', 'this', '2010', 'dreamworks', 'animation', 'film', 'was', 'it', 'aint', 'ogre', 'til', 'it', 's', 'ogre']),
#        list(['the', 'true', 'story', 'of', 'a', 'horse', 'that', 'defied', 'expectations', 'and', 'now', 'works', 'for', 'craig', 'ferguson']),
#        list(['thinking', 'of', 'a', '1939', 'blockbuster', 'about', 'love', 'and', 'war']),
#        list(['third', 'series', 'of', 'animated', 'movie', 'that', 'focuses', 'on', 'zoo', 'animals', 'who', 'have', 'escaped', 'from', 'the', 'nyc', 'zoo']),
#        list(['this', '1954', 'classic', 'stars', 'marlon', 'brando', 'as', 'a', 'dockworker', 'that', 'witnesses', 'a', 'murder', 'orchestrated', 'by', 'corrupt', 'union', 'bosses']),
#        list(['this', '1960', 'thriller', 'is', 'a', 'black', 'and', 'white', 'hitchcock', 'classic', 'that', 'features', 'a', 'famous', 'shower', 'murder', 'scene']),
#        list(['this', '1973', 'horror', 'classic', 'is', 'well', 'known', 'for', 'it', 's', 'famous', '360', 'degree', 'head', 'spin', 'scene']),
#        list(['this', '1974', 'film', 'by', 'mel', 'brooks', 'is', 'about', 'a', 'doctor', 's', 'grandson', 'and', 'his', 'assistant', 'igor', 'who', 'decides', 'to', 'repeat', 'his', 'grandfather', 's', 'experiments', 'with', 'hilariously', 'disastrous', 'results']),
#        list(['this', '1976', 'classic', 'was', 'written', 'by', 'and', 'stars', 'sylvester', 'stallone', 'as', 'a', 'boxer', 'who', 'tries', 'to', 'become', 'a', 'heavyweight', 'champion']),
#        list(['this', '1979', 'vision', 'of', 'post', 'apocalypse', 'australia', 'stars', 'mel', 'gibson', 'as', 'the', 'title', 'character', 'on', 'his', 'quest', 'for', 'vengeance']),
#        list(['this', '1990', 'film', 'starred', 'kevin', 'costner', 'as', 'a', 'civil', 'war', 'soldier', 'and', 'won', 'numerous', 'academy', 'awards']),
#        list(['this', '1990', 's', 'animated', 'feature', 'taught', 'us', 'the', 'song', 'hakuna', 'matata', 'which', 'championed', 'a', 'down', 'to', 'earth', 'problem', 'free', 'philosophy']),
#        list(['this', '1997', 'animated', 'film', 'directed', 'by', 'hayao', 'miyazaki', 'helped', 'popularize', 'anime', 'in', 'the', 'united', 'states']),
#        list(['this', '1997', 'blockbuster', 'revolves', 'around', 'a', 'famous', 'maritime', 'tragedy', 'in', 'which', 'an', 'ocean', 'liner', 'strikes', 'an', 'ice', 'berg']),
#        list(['this', '2010', 'american', 'supernatural', 'horror', 'film', 'starred', 'sprague', 'grayden', 'as', 'kristi', 'and', 'molly', 'ephraim', 'as', 'ali']),
#        list(['this', '2010', 'drama', 'romance', 'starring', 'julia', 'roberts', 'is', 'about', 'a', 'woman', 'who', 'realizes', 'her', 'life', 'needs', 'a', 'different', 'direction']),
#        list(['this', '2010', 'romantic', 'comedy', 'film', 'featured', 'cameos', 'from', 'multiple', 'nba', 'players', 'including', 'rajon', 'rondon', 'and', 'dwight', 'howard']),
#        list(['this', '2011', 'adventure', 'stars', 'asa', 'butterfield', 'trying', 'to', 'find', 'secrets', 'his', 'father', 'left', 'him']),
#        list(['this', '2011', 'comedy', 'film', 'starred', 'steve', 'martin', 'jack', 'black', 'and', 'owen', 'wilson', 'as', 'bird', 'enthusiasts']),
#        list(['this', '2011', 'film', 'stars', 'joseph', 'gordon', 'levitt', 'as', 'a', 'young', 'adult', 'who', 'learns', 'that', 'he', 'has', 'cancer']),
#        list(['this', '2011', 'film', 'was', 'based', 'on', 'a', 'comic', 'book', 'character', 'whose', 'job', 'it', 'is', 'to', 'police', 'the', 'galaxy']),
#        list(['this', '2011', 'superhero', 'movie', 'stars', 'seth', 'rogen', 'as', 'an', 'unlikely', 'hero', 'who', 'starts', 'a', 'crime', 'fighting', 'career', 'with', 'the', 'help', 'of', 'his', 'father', 's', 'assistant', 'kato']),
#        list(['this', '2012', 'action', 'adventure', 'film', 'was', 'a', 'unique', 'twist', 'on', 'an', 'old', 'fairy', 'tale']),
#        list(['this', '2012', 'comedy', 'from', 'seth', 'macfarlane', 'has', 'a', 'main', 'character', 'also', 'voiced', 'by', 'macfarlane', 'who', 'is', 'a', 'stuffed', 'animal']),
#        list(['this', '2012', 'film', 'features', 'real', 'united', 'states', 'navy', 'seals', 'and', 'their', 'attempts', 'to', 'recover', 'a', 'kidnapped', 'cia', 'agent']),
#        list(['this', '2012', 'kung', 'fu', 'film', 'was', 'written', 'and', 'directed', 'by', 'and', 'stars', 'hip', 'hop', 'legend', 'rza', 'as', 'a', 'man', 'who', 'must', 'fight', 'evil', 'men', 'who', 'threaten', 'the', 'safety', 'of', 'his', 'town']),
#        list(['this', '2012', 'movie', 'of', 'a', 'classic', 'dr', 'seuss', 'book', 'is', 'about', 'a', 'mustached', 'creature', 'that', 'tries', 'to', 'protect', 'the', 'trees']),
#        list(['this', '942', 'american', 'biographical', 'musical', 'film', 'about', 'george', 'm', 'cohan', 'known', 'as', 'the', 'man', 'who', 'owns', 'broadway']),
#        list(['this', 'action', 'film', 'features', 'aaaron', 'johnson', 'as', 'a', 'high', 'school', 'student', 'turned', 'vigilante', 'nicholas', 'cage', 'and', 'chloe', 'moretz', 'are', 'also', 'featured', 'as', 'big', 'daddy', 'and', 'hit', 'girl']),
#        list(['this', 'action', 'packed', 'sequel', 'stars', 'arnold', 'schwarzenegger', 'as', 'a', 'robot', 'sent', 'back', 'in', 'time', 'this', 'time', 'to', 'protect', 'young', 'john', 'connor']),
#        list(['this', 'action', 'packed', 'shooter', 'is', 'the', 'story', 'of', 'man', 'whose', 'life', 'is', 'changed', 'by', 'one', 'little', 'pill', 'after', 'taking', 'this', 'pill', 'he', 'is', 'launched', 'into', 'a', 'world', 'of', 'fighting', 'where', 'reality', 'is', 'not', 'what', 'it', 'seems', 'this', 'film', 'features', 'star', 'keanu', 'reeves']),
#        list(['this', 'alfred', 'hitchcock', 'film', 'includes', 'a', 'motel', 'manager', 'norman', 'bates', 'in', 'an', 'infamous', 'shower', 'scene']),
#        list(['this', 'ambitious', '2012', 'film', 'from', 'the', 'wachowski', 'siblings', 'is', 'based', 'on', 'a', 'book', 'that', 'interweaves', 'six', 'different', 'narratives', 'to', 'tell', 'a', 'tale', 'about', 'how', 'all', 'life', 'is', 'connected']),
#        list(['this', 'animated', 'sequel', 'features', 'ben', 'stiller', 'as', 'alex', 'the', 'lion', 'and', 'his', 'continuing', 'adventures', 'in', 'africa']),
#        list(['this', 'black', 'and', 'white', 'comedy', 'directed', 'by', 'mel', 'brooks', 'stars', 'gene', 'wilder', 'and', 'peter', 'boyle', 'and', 'features', 'the', 'classic', 'song', 'puttin', 'on', 'the', 'ritz']),
#        list(['this', 'children', 's', 'movie', 'is', 'about', 'a', 'young', 'boy', 'named', 'greg', 'heffley', 'who', 'enters', 'the', 'sixth', 'grade', 'and', 'tries', 'to', 'make', 'it', 'through', 'the', 'school', 'year', 'unscathed']),
#        list(['this', 'classic', '1938', 'warner', 'bros', 'gangster', 'picture', 'stars', 'james', 'cagney', 'pat', 'o', 'brien', 'humphrey', 'bogart', 'and', 'the', 'dead', 'end', 'kids']),
#        list(['this', 'classic', 'gangster', 'film', 'directed', 'by', 'francis', 'ford', 'coppola', 'shows', 'the', 'inner', 'workings', 'of', 'the', 'corleone', 'crime', 'family']),
#        list(['this', 'classic', 'sequel', 'features', 'a', 'robot', 'from', 'the', 'future', 'who', 'battles', 'an', 'even', 'more', 'powerful', 'robot', 'from', 'the', 'future']),
#        list(['this', 'classic', 'silent', 'horror', 'film', 'from', '1922', 'stars', 'max', 'schrek', 'as', 'the', 'title', 'villain', 'and', 'monster']),
#        list(['this', 'comedy', 'features', 'anna', 'kendrick', 'and', 'brittany', 'snow', 'as', 'college', 'students', 'who', 'participate', 'in', 'the', 'competitive', 'sport', 'of', 'a', 'capella', 'singing', 'groups']),
#        list(['this', 'comedy', 'stars', 'paul', 'rudd', 'as', 'a', 'man', 'who', 'recruits', 'an', 'idiot', 'steve', 'carell', 'to', 'come', 'with', 'him', 'to', 'his', 'company', 's', 'annual', 'contest']),
#        list(['this', 'computer', 'animated', 'comedy', 'features', 'the', 'voice', 'of', 'steve', 'carrell', 'as', 'the', 'villainous', 'but', 'likeable', 'gru']),
#        list(['this', 'computer', 'animated', 'film', 'stars', 'johnny', 'depp', 'as', 'a', 'timid', 'chameleon', 'who', 'finds', 'courage', 'in', 'the', 'desert']),
#        list(['this', 'crime', 'film', 'from', 'martin', 'scorcese', 'is', 'about', 'two', 'men', 'one', 'a', 'cop', 'that', 'goes', 'undercover', 'in', 'a', 'gang', 'the', 'other', 'a', 'member', 'of', 'the', 'gang', 'who', 'goes', 'undercover', 'as', 'a', 'cop']),
#        list(['this', 'disney', 'animated', 'film', 'features', 'the', 'voice', 'of', 'john', 'travolta', 'as', 'the', 'titular', 'dog', 'who', 'is', 'a', 'tv', 'superhero', 'who', 'is', 'thrown', 'into', 'a', 'real', 'life', 'superhero', 'situation']),
#        list(['this', 'disney', 'film', 'follows', 'the', 'adventures', 'of', 'a', 'dog', 'who', 'befriends', 'a', 'family', 'but', 'then', 'suffers', 'tragically']),
#        list(['this', 'disney', 'princess', 'pricks', 'her', 'finger', 'on', 'a', 'spinning', 'wheel', 'needle', 'and', 'sends', 'the', 'entire', 'kingdom', 'into', 'a', 'deep', 'slumber', 'until', 'her', 'prince', 'arrives', 'with', 'the', 'kiss', 'to', 'wake', 'her']),
#        list(['this', 'famous', 'musical', 'takes', 'place', 'in', 'new', 'york', 'city', 'where', 'two', 'teenage', 'gangs', 'struggle', 'for', 'control', 'of', 'the', 'neighborhood']),
#        list(['this', 'film', 'celebrated', 'the', 'famed', '1980', 'u', 's', 'hockey', 'team', 'and', 'their', 'victory', 'over', 'the', 'soviet', 'union']),
#        list(['this', 'film', 'directed', 'by', 'ben', 'affleck', 'tells', 'the', 'story', 'of', 'a', 'band', 'of', 'men', 'who', 'go', 'through', 'boston', 'with', 'just', 'their', 'guns', 'and', 'their', 'skills', 'robbing', 'banks', 'and', 'armored', 'vehicles', 'and', 'not', 'letting', 'anything', 'get', 'in', 'the', 'way', 'that', 'is', 'until', 'they', 'take', 'a', 'hostage']),
#        list(['this', 'film', 'looks', 'at', 'paranormal', 'happenings', 'in', 'a', 'former', 'soviet', 'republic']),
#        list(['this', 'film', 'showed', 'a', 'more', 'feminine', 'side', 'of', 'adam', 'sandler', 'who', 'played', 'himself', 'and', 'his', 'twin', 'sister']),
#        list(['this', 'finale', 'finally', 'tells', 'the', 'true', 'story', 'of', 'a', 'potions', 'professor', 'who', 'apparently', 'despises', 'the', 'protagonist']),
#        list(['this', 'holiday', 'classic', 'involves', 'a', 'man', 'who', 'changes', 'his', 'ways', 'after', 'he', 'is', 'visited', 'by', 'ghosts', 'on', 'christmas', 'eve']),
#        list(['this', 'horror', 'is', 'the', 'exact', 'middle', 'movie', 'of', 'a', 'series', 'featuring', 'a', 'deplorable', 'puppet']),
#        list(['this', 'horror', 'movie', 'features', 'one', 'of', 'the', 'most', 'famous', 'villains', 'in', 'the', 'genre', 'who', 'kills', 'victims', 'in', 'their', 'nightmares', 'with', 'his', 'signature', 'bladed', 'hands']),
#        list(['this', 'horror', 'movie', 'takes', 'place', 'at', 'a', 'summer', 'camp', 'and', 'spawned', 'a', 'series', 'of', 'movies', 'about', 'a', 'gruesome', 'killed', 'named', 'jason']),
#        list(['this', 'iconic', 'science', 'fiction', 'space', 'opera', 'features', 'one', 'of', 'the', 'main', 'characters', 'being', 'frozen', 'in', 'carbonite']),
#        list(['this', 'is', 'one', 'of', 'the', 'most', 'famous', 'kung', 'fu', 'movies', 'of', 'all', 'time', 'about', 'two', 'warriors', 'in', 'pursuit', 'of', 'a', 'stolen', 'sword']),
#        list(['this', 'is', 'the', 'fifth', 'movie', 'in', 'a', 'series', 'of', 'films', 'that', 'focus', 'on', 'illegal', 'street', 'racing']),
#        list(['this', 'is', 'the', 'first', 'part', 'of', 'the', 'epic', 'conclusion', 'to', 'an', '8', 'part', 'movie', 'series', 'about', 'a', 'boy', 'wizard', 'fighting', 'the', 'forces', 'of', 'evil']),
#        list(['this', 'is', 'the', 'movie', 'that', 'made', 'tim', 'burton', 'famous', 'and', 'put', 'and', 'combined', 'two', 'famous', 'holidays']),
#        list(['this', 'japanese', 'anime', 'set', 'in', 'shattered', 'neo', 'tokyo', 'includes', 'several', 'old', 'children', 'who', 'battle', 'with', 'telekinesis', 'and', 'telepathy']),
#        list(['this', 'marvel', 'superhero', 'film', 'assembles', 'captain', 'america', 'iron', 'man', 'thor', 'and', 'the', 'hulk', 'to', 'battle', 'an', 'evil', 'being', 'named', 'loki']),
#        list(['this', 'marvel', 'superhero', 'film', 'stars', 'chris', 'hemsworth', 'as', 'the', 'titular', 'character', 'who', 'is', 'banished', 'from', 'his', 'own', 'world', 'and', 'forced', 'to', 'earth']),
#        list(['this', 'mel', 'brook', 's', 'classic', 'takes', 'place', 'in', 'the', 'wild', 'west', 'and', 'a', 'small', 'town', 'is', 'in', 'chaos', 'after', 'a', 'black', 'sheriff', 'comes', 'town']),
#        list(['this', 'modern', 'batman', 'film', 'pits', 'batman', 'against', 'bane', 'and', 'catwoman', 'in', 'a', 'besieged', 'new', 'york', 'city']),
#        list(['this', 'modern', 'crime', 'film', 'features', 'robert', 'downey', 'jr', 'as', 'a', 'bumbling', 'crook', 'caught', 'up', 'in', 'a', 'mystery', 'alongside', 'val', 'kilmer', 'as', 'private', 'investigator', 'gay', 'perry']),
#        list(['this', 'modern', 'version', 'of', 'an', '80', 's', 'classic', 'features', 'an', 'old', 'jeff', 'bridges', 'and', 'a', 'well', 'animated', 'young', 'jeff', 'bridges']),
#        list(['this', 'movie', 'based', 'on', 'a', 'famous', 'j', 'r', 'r', 'tolkein', 'book', 'is', 'the', 'first', 'in', 'a', 'film', 'trilogy', 'featuring', 'hobbits', 'orcs', 'and', 'elves']),
#        list(['this', 'movie', 'features', 'scientifically', 'inaccurate', 'but', 'scary', 'and', 'intense', 'recreations', 'of', 'a', 'past', 'extinct', 'species']),
#        list(['this', 'movie', 'is', 'a', 'comic', 'book', 'adaptation', 'of', 'one', 'of', 'the', 'first', 'comic', 'book', 'heroes', 'set', 'mainly', 'during', 'world', 'war', '2']),
#        list(['this', 'movie', 'is', 'a', 'one', 'word', 'three', 'letter', 'title', 'that', 'is', 'the', 'first', 'word', 'of', 'the', 'river', 'bordering', 'texas', 'and', 'mexico']),
#        list(['this', 'movie', 'is', 'about', 'a', 'civil', 'war', 'veteran', 'that', 'is', 'transported', 'off', 'earth', 'to', 'another', 'planet', 'where', 'he', 'is', 'found', 'to', 'have', 'superhuman', 'abilities', 'based', 'on', 'the', 'reduced', 'gravity']),
#        list(['this', 'movie', 'is', 'about', 'a', 'lone', 'avatar', 'who', 'has', 'the', 'power', 'to', 'manipulate', 'all', 'four', 'elements', 'he', 'teams', 'up', 'with', 'katara', 'who', 'is', 'a', 'waterbender']),
#        list(['this', 'movie', 'is', 'about', 'a', 'man', 'who', 'becomes', 'tired', 'with', 'his', 'mundane', 'life', 'and', 'tries', 'to', 'find', 'a', 'way', 'to', 'break', 'out', 'only', 'to', 'discover', 'his', 'life', 'is', 'not', 'real', 'and', 'once', 'in', 'the', 'real', 'world', 'that', 'he', 'may', 'be', 'the', 'savior', 'the', 'world', 'has', 'been', 'expecting']),
#        list(['this', 'movie', 'is', 'based', 'on', 'actual', 'events', 'where', 'a', 'young', 'girl', 'is', 'involved', 'in', 'a', 'shark', 'attack']),
#        list(['this', 'movie', 'on', 'my', 'mind', 'is', 'a', 'spoof', 'of', 'the', 'vampire', 'love', 'story', 'genre', 'type', 'movies']),
#        list(['this', 'noir', 'film', 'was', 'directed', 'by', 'roman', 'polanski', 'and', 'featured', 'jack', 'nicholson', 'as', 'a', 'private', 'investigator']),
#        list(['this', 'pixar', 'film', 'features', 'and', 'old', 'man', 'who', 'attaches', 'thousands', 'of', 'balloons', 'to', 'his', 'house']),
#        list(['this', 'reboot', 'of', 'a', 'classic', 'comicbook', 'group', 'features', 'the', 'younger', 'versions', 'of', 'mutants', 'including', 'james', 'mcavoy']),
#        list(['this', 'recent', 'thriller', 'portrays', 'a', 'blonde', 'young', 'girl', 'as', 'a', 'killer', 'trained', 'in', 'the', 'wilderness', 'by', 'her', 'father']),
#        list(['this', 'road', 'trip', 'comedy', 'features', 'robert', 'downey', 'jr', 'and', 'zach', 'galifianakis', 'as', 'an', 'unlikely', 'pair', 'traveling', 'across', 'the', 'country']),
#        list(['this', 'rockumentary', 'from', 'director', 'rob', 'reiner', 'chronicles', 'the', 'misadventures', 'of', 'a', 'fictional', 'heavy', 'metal', 'band', 'turn', 'it', 'up', 'to', '11']),
#        list(['this', 'romance', 'film', 'stars', 'julia', 'roberts', 'as', 'a', 'woman', 'traveling', 'around', 'europe', 'in', 'an', 'attempt', 'to', 'improve', 'her', 'life']),
#        list(['this', 'russel', 'crowe', 'drama', 'follows', 'the', 'story', 'of', 'a', 'mathematician', 'whose', 'life', 'is', 'destroyed', 'by', 'paranoid', 'schizophrenia']),
#        list(['this', 'scary', 'movie', 'is', 'named', 'about', 'a', 'street', 'and', 'the', 'horrible', 'things', 'that', 'happen', 'when', 'you', 'have', 'a', 'bad', 'dream']),
#        list(['this', 'sci', 'fi', 'hit', 'stars', 'keanu', 'reeves', 'as', 'the', 'one', 'who', 'will', 'save', 'humanity', 'from', 'their', 'enslavement', 'by', 'the', 'machines']),
#        list(['this', 'stop', 'motion', 'animated', 'feature', 'directed', 'by', 'henry', 'selick', 'shows', 'the', 'adventures', 'of', 'jack', 'skellington', 'who', 'tries', 'to', 'spread', 'the', 'magic', 'of', 'christmas']),
#        list(['this', 'summer', 'love', 'story', 'not', 'only', 'brought', 'their', 'characters', 'together', 'in', 'the', 'movie', 'but', 'also', 'brought', 'miley', 'cirus', 'and', 'liam', 'hemsworth', 'together', 'in', 'real', 'life']),
#        list(['this', 'surreal', 'romp', 'from', '1967', 'stars', 'the', 'beatles', 'and', 'features', 'some', 'of', 'their', 'famous', 'hit', 'songs']),
#        list(['this', 'suspense', 'film', 'starred', 'amanda', 'seyfried', 'as', 'a', 'young', 'woman', 'who', 'escaped', 'a', 'murderer', 'and', 'has', 'to', 'find', 'him', 'to', 'save', 'her', 'sister']),
#        list(['this', 'tragedy', 'written', 'by', 'william', 'shakespeare', 'centers', 'on', 'the', 'prince', 'of', 'denmark', 'who', 'is', 'driven', 'mad', 'by', 'his', 'own', 'desire', 'for', 'revenge', 'against', 'his', 'murderous', 'uncle']),
#        list(['this', 'was', 'the', 'first', 'movie', 'produced', 'by', 'pixar', 'to', 'be', 'rated', 'below', '50', 'percent', 'on', 'the', 'popular', 'movie', 'review', 'site', 'rotten', 'tomatoes']),
#        list(['this', 'was', 'the', 'movie', 'that', 'macaulay', 'culkin', 'was', 'watching', 'in', 'the', 'scene', 'in', 'home', 'alone', 'when', 'the', 'pizza', 'boy', 'arrived']),
#        list(['this', 'zombie', 'thriller', 'directed', 'by', 'george', 'a', 'romero', 'set', 'the', 'stage', 'for', 'the', 'modern', 'zombie', 'movie', 'scene', 'and', 'is', 'considered', 'to', 'be', 'one', 'of', 'the', 'greatest', 'horror', 'movies', 'of', 'all', 'time']),
#        list(['vin', 'diesel', 'and', 'his', 'gang', 'are', 'planning', 'a', 'massive', 'heist', 'to', 'buy', 'their', 'freedom', 'while', 'in', 'the', 'sights', 'of', 'a', 'powerful', 'brazilian', 'drug', 'lord', 'and', 'a', 'dangerous', 'federal', 'agent', 'in', 'the', '2011', 'installment', 'of', 'this', 'movie', 'series']),
#        list(['vin', 'diesel', 'is', 'the', 'voice', 'of', 'an', 'alien', 'robot', 'that', 'a', 'young', 'boy', 'is', 'trying', 'to', 'save', 'from', 'being', 'destroyed', 'by', 'the', 'government', 'in', 'this', '1999', 'animated', 'feature']),
#        list(['wes', 'anderson', 's', 'adaptation', 'of', 'roald', 'dahl', 's', 'popular', 'children', 's', 'book', 'about', 'a', 'fox', 'who', 'must', 'help', 'his', 'friends', 'and', 'family', 'survive', 'the', 'onslaught', 'of', 'local', 'farmers']),
#        list(['what', '1930', 'ernst', 'lubitsch', 'film', 'starring', 'jeanette', 'macdonald', 'took', 'place', 'in', 'a', 'famous', 'european', 'gambling', 'city', 'and', 'featured', 'the', 'song', 'beyond', 'the', 'blue', 'horizon']),
#        list(['what', '1931', 'film', 'featured', 'a', 'man', 'hunt', 'in', 'germany', 'for', 'a', 'child', 'killer', 'aided', 'by', 'police', 'and', 'other', 'criminals', 'alike']),
#        list(['what', '1931', 'movie', 'depicts', 'the', 'creation', 'of', 'an', 'monster', 'made', 'up', 'of', 'parts', 'of', 'dead', 'people']),
#        list(['what', '1937', 'french', 'war', 'film', 'is', 'directed', 'by', 'jean', 'renoir', 'and', 'about', 'french', 'officers', 'attempting', 'to', 'escape', 'pow', 'camp']),
#        list(['what', '1938', 'howard', 'hawks', 'romantic', 'comedy', 'starred', 'katharine', 'hepburn', 'cary', 'grant', 'charles', 'ruggles', 'and', 'barry', 'fitzgerald']),
#        list(['what', '1939', 'frank', 'capra', 'drama', 'stars', 'james', 'stewart', 'jean', 'arthur', 'claude', 'rains', 'edward', 'arnold', 'and', 'thomas', 'mitchell']),
#        list(['what', '1939', 'victor', 'fleming', 'movie', 'centers', 'around', 'a', 'girl', 'named', 'dorothy', 'who', 'gets', 'swept', 'away', 'to', 'a', 'magical', 'land']),
#        list(['what', '1940', 'dramatic', 'movie', 'depicted', 'a', 'poor', 'midwest', 'family', 'that', 'is', 'forced', 'off', 'their', 'land']),
#        list(['what', '1941', 'john', 'huston', 'crime', 'drama', 'starred', 'humphrey', 'bogart', 'mary', 'astor', 'peter', 'lorre', 'and', 'gladys', 'george']),
#        list(['what', '1941', 'orson', 'welles', 'movie', 'garnered', 'him', 'an', 'oscar', 'for', 'best', 'writing', 'along', 'with', 'writing', 'partner', 'herman', 'j', 'mankiewicz']),
#        list(['what', '1942', 'best', 'picture', 'oscar', 'winning', 'film', 'was', 'set', 'in', 'unoccupied', 'africa', 'during', 'the', 'early', 'days', 'of', 'world', 'war', 'ii']),
#        list(['what', '1942', 'movie', 'garnered', 'a', 'best', 'music', 'original', 'song', 'oscar', 'win', 'to', 'irving', 'berlin', 'for', 'his', 'song', 'white', 'christmas']),
#        list(['what', '1945', 'movie', 'centered', 'around', 'a', 'woman', 'who', 'is', 'tempted', 'to', 'cheat', 'on', 'her', 'husband', 'with', 'a', 'stranger', 'in', 'a', 'railway', 'station']),
#        list(['what', '1946', 'john', 'huston', 'documentary', 'marked', 'the', 'final', 'entry', 'in', 'a', 'trilogy', 'of', 'films', 'he', 'produced', 'for', 'the', 'u', 's', 'government']),
#        list(['what', '1948', 'film', 'centers', 'around', 'a', 'man', 'driving', 'his', 'cattle', 'when', 'his', 'adopted', 'son', 'turns', 'against', 'him']),
#        list(['what', '1949', 'george', 'cukor', 'romantic', 'comedy', 'centered', 'around', 'a', 'husband', 'and', 'wife', 'working', 'as', 'opposing', 'lawyers', 'in', 'a', 'case', 'involving', 'a', 'woman', 'who', 'shot', 'her', 'husband']),
#        list(['what', '1950', 'joseph', 'l', 'mankiewicz', 'movie', 'garnered', 'a', 'total', 'of', 'six', 'oscar', 'wins', 'including', 'best', 'writing', 'and', 'best', 'directing', 'for', 'mankiewicz', 'and', 'best', 'picture']),
#        list(['what', '1951', 'george', 'stevens', 'movie', 'centers', 'around', 'a', 'poor', 'boy', 'working', 'for', 'his', 'rich', 'uncle', 'and', 'ends', 'up', 'falling', 'in', 'love', 'with', 'two', 'women']),
#        list(['what', '1954', 'elia', 'kazan', 'crime', 'movie', 'depicted', 'an', 'ex', 'prize', 'fighter', 'turned', 'longshoreman', 'struggling', 'to', 'stand', 'up', 'to', 'corrupt', 'union', 'bosses']),
#        list(['what', '1957', 'king', 'vidor', 'movie', 'starring', 'audrey', 'hepburn', 'and', 'henry', 'fonda', 'centered', 'around', 'napoleon', 's', 'tumultuous', 'relations', 'with', 'russia']),
#        list(['what', '1960', 'french', 'horror', 'film', 'directed', 'by', 'georges', 'franju', 'created', 'massive', 'controvery', 'upon', 'its', 'release']),
#        list(['what', '1960', 'stanley', 'kubrick', 'biopic', 'centered', 'around', 'a', 'slave', 'that', 'leads', 'a', 'violent', 'revolt', 'against', 'the', 'decadent', 'roman', 'republic']),
#        list(['what', '1962', 'david', 'lean', 'biopic', 'tells', 'the', 'story', 'of', 'a', 'flamboyant', 'and', 'controversial', 'british', 'military', 'figure']),
#        list(['what', '1965', 'cartoon', 'is', 'a', 'timeless', 'classic', 'starring', 'the', 'lovable', 'charlie', 'brown', 'and', 'his', 'dog', 'snoopy']),
#        list(['what', '1965', 'musical', 'based', 'on', 'a', 'rogers', 'and', 'hammerstein', 'musical', 'of', 'the', 'same', 'name', 'features', 'the', 'von', 'trapp', 'family', 'singers']),
#        list(['what', '1966', 'sergio', 'leone', 'western', 'adventure', 'movie', 'featured', 'clint', 'eastwood', 'and', 'eli', 'wallach', 'in', 'a', 'bounty', 'hunting', 'scam']),
#        list(['what', '1967', 'musical', 'comedy', 'follows', 'the', 'adventures', 'of', 'the', 'beatles', 'on', 'a', 'special', 'charter', 'bus']),
#        list(['what', '1970', 'movie', 'takes', 'place', 'in', '1825', 'and', 'centers', 'around', 'an', 'english', 'aristocrat', 'who', 'is', 'captured', 'by', 'indians']),
#        list(['what', '1970', 'robert', 'altman', 'movie', 'about', 'the', 'korean', 'war', 'spawned', 'a', 'long', 'running', 'television', 'series']),
#        list(['what', '1972', 'movie', 'starred', 'john', 'wayne', 'roscoe', 'lee', 'browns', 'bruce', 'dern', 'colleen', 'dewhurst', 'and', 'alfred', 'barker', 'jr']),
#        list(['what', '1972', 'romantic', 'comedy', 'centered', 'around', 'the', 'accidental', 'mix', 'up', 'of', 'four', 'identical', 'overnight', 'bags']),
#        list(['what', '1973', 'francois', 'truffaut', 'romantic', 'comedy', 'starred', 'jacqueline', 'bisset', 'and', 'jean', 'pierre', 'leaud', 'and', 'valentina', 'cortese']),
#        list(['what', '1974', 'american', 'comedy', 'film', 'directed', 'by', 'mel', 'brooks', 'was', 'a', 'parody', 'of', 'the', 'classical', 'frankenstein', 'horror', 'fim']),
#        list(['what', '1974', 'billy', 'wilder', 'movie', 'starred', 'jack', 'lemmon', 'walter', 'matthau', 'susan', 'sarandon', 'and', 'vincent', 'gardenia']),
#        list(['what', '1974', 'stop', 'motion', 'animated', 'tv', 'special', 'features', 'kris', 'kringle', 'running', 'into', 'the', 'heater', 'miser']),
#        list(['what', '1976', 'richard', 'donner', 'horror', 'film', 'featured', 'gregory', 'peck', 'as', 'an', 'american', 'ambassador', 'and', 'lee', 'remick', 'as', 'his', 'wife']),
#        list(['what', '1976', 'western', 'centered', 'around', 'a', 'dying', 'gunfighter', 'spending', 'his', 'last', 'days', 'looking', 'for', 'a', 'way', 'to', 'die', 'with', 'dignity']),
#        list(['what', '1977', 'george', 'lucas', 'sci', 'fi', 'movie', 'featured', 'mark', 'hamill', 'harrison', 'ford', 'carrie', 'fisher', 'and', 'alec', 'guinness']),
#        list(['what', '1977', 'steven', 'spielberg', 'sci', 'fi', 'adventured', 'found', 'richard', 'dreyfuss', 'making', 'a', 'mountain', 'out', 'of', 'mashed', 'potatoes']),
#        list(['what', '1979', 'movie', 'stars', 'jon', 'voight', 'as', 'an', 'ex', 'boxer', 'who', 'works', 'as', 'a', 'horse', 'trainer', 'and', 'raises', 'his', 'son']),
#        list(['what', '1979', 'ridley', 'scott', 'sci', 'fi', 'horror', 'movie', 'featured', 'sigourney', 'weaver', 'as', 'part', 'of', 'a', 'commercial', 'deep', 'space', 'mining', 'ship', 'crew']),
#        list(['what', '1980', 'american', 'film', 'featured', 'a', 'single', 'woman', 'moving', 'to', 'san', 'fransisco', 'during', 'the', 'holidays', 'whil', 'trying', 'to', 'get', 'her', 'life', 'back', 'togeather', 'after', 'a', 'divorce']),
#        list(['what', '1980', 'harold', 'ramis', 'sport', 'comedy', 'takes', 'place', 'at', 'an', 'exclusive', 'golf', 'course', 'that', 'has', 'a', 'dancing', 'gopher']),
#        list(['what', '1982', 'horror', 'film', 'centers', 'around', 'a', 'man', 'who', 'seeks', 'vengeance', 'against', 'the', 'doctors', 'who', 'separated', 'him', 'against', 'his', 'will', 'from', 'his', 'siamese', 'twin', 'brother']),
#        list(['what', '1982', 'ridley', 'scott', 'sci', 'fi', 'flick', 'stars', 'harrison', 'ford', 'as', 'a', 'man', 'who', 'has', 'to', 'track', 'down', 'and', 'terminate', '4', 'replicants']),
#        list(['what', '1983', 'harold', 'ramis', 'comedy', 'finds', 'the', 'griswold', 'family', 'cross', 'country', 'driving', 'to', 'theme', 'park', 'walley', 'world']),
#        list(['what', '1984', 'barry', 'levinson', 'sport', 'drama', 'centered', 'around', 'an', 'average', 'baseball', 'player', 'out', 'of', 'nowhere', 'to', 'become', 'a', 'legendary', 'player']),
#        list(['what', '1984', 'historical', 'biopic', 'centered', 'around', 'a', 'photographer', 'trapped', 'in', 'cambodia', 'during', 'a', 'violent', 'time']),
#        list(['what', '1984', 'james', 'cameron', 'film', 'depicted', 'a', 'robotic', 'assassin', 'from', 'a', 'post', 'apocalyptic', 'future', 'sent', 'back', 'in', 'time', 'to', 'eliminate', 'a', 'waitress']),
#        list(['what', '1984', 'james', 'cameron', 'film', 'starring', 'arnold', 'schwarzenegger', 'has', 'spawned', 'three', 'sequels', 'and', 'a', 'television', 'program']),
#        list(['what', '1985', 'harold', 'becker', 'coming', 'of', 'age', 'movie', 'finds', 'a', 'high', 'school', 'student', 'wanting', 'to', 'be', 'something', 'more']),
#        list(['what', '1986', 'sports', 'movie', 'featured', 'gene', 'hackman', 'as', 'a', 'coach', 'of', 'a', 'high', 'school', 'team']),
#        list(['what', '1987', 'brian', 'depalma', 'film', 'features', 'kevin', 'costner', 'as', 'federal', 'agent', 'eliot', 'ness', 'out', 'to', 'stop', 'al', 'capone']),
#        list(['what', '1987', 'stanley', 'kubrick', 'film', 'showed', 'what', 'it', 's', 'like', 'to', 'be', 'in', 'the', 'u', 's', 'marine', 'bootcamp']),
#        list(['what', '1988', 'gary', 'marshall', 'chick', 'flick', 'centered', 'around', 'a', 'rich', 'debutante', 'and', 'a', 'cynical', 'entertainer', 'who', 'share', 'an', 'enduring', 'childhood', 'friendship', 'through', 'the', 'years']),
#        list(['what', '1988', 'ron', 'howard', 'movie', 'shows', 'a', 'reluctant', 'dwarf', 'playing', 'a', 'critical', 'role', 'in', 'protecting', 'a', 'special', 'baby']),
#        list(['what', '1990', 'american', 'crime', 'film', 'featured', 'the', 'famous', 'story', 'of', 'the', 'rise', 'and', 'fall', 'of', 'the', 'lucchese', 'crime', 'family']),
#        list(['what', '1990', 'jeannot', 'szwarc', 'film', 'centered', 'around', 'a', 'chicago', 'playwright', 'who', 'uses', 'self', 'hypnosis', 'to', 'find', 'the', 'actress', 'whose', 'vintage', 'portrait', 'hangs', 'in', 'a', 'grand', 'hotel']),
#        list(['what', '1990', 'martin', 'scorsese', 'biopic', 'centers', 'around', 'henry', 'hill', 'and', 'his', 'friends', 'as', 'they', 'work', 'their', 'way', 'up', 'through', 'the', 'mob', 'hierarchy']),
#        list(['what', '1990', 'sci', 'fi', 'flick', 'centers', 'around', 'a', 'man', 'in', 'the', 'future', 'who', 'goes', 'in', 'for', 'virtual', 'vacation', 'memories', 'but', 'then', 'faces', 'unforeseen', 'consequences']),
#        list(['what', '1990', 'tim', 'burton', 'film', 'featured', 'johnny', 'depp', 'as', 'a', 'hairstylist', 'and', 'hedge', 'trimmer', 'and', 'winona', 'ryder', 'as', 'his', 'love', 'interest']),
#        list(['what', '1991', 'animated', 'disney', 'movie', 'tells', 'the', 'tale', 'of', 'a', 'love', 'story', 'between', 'two', 'unlikely', 'lovers']),
#        list(['what', '1992', 'neil', 'jordan', 'dramatic', 'movie', 'centered', 'around', 'a', 'british', 'soldier', 'kidnapped', 'by', 'ira', 'terrorists']),
#        list(['what', '1993', 'drama', 'film', 'directed', 'by', 'steven', 'speilberg', 'featured', 'liam', 'neeson', 'as', 'schindler', 'in', 'nazi', 'germany']),
#        list(['what', '1993', 'jane', 'campion', 'romantic', 'drama', 'centered', 'on', 'a', 'mute', 'woman', 'lusted', 'after', 'by', 'a', 'local', 'worker']),
#        list(['what', '1993', 'wayne', 'wang', 'film', 'shared', 'the', 'life', 'histories', 'of', 'four', 'asian', 'women', 'and', 'their', 'daughters']),
#        list(['what', '1994', 'james', 'cameron', 'film', 'was', 'partially', 'shot', 'on', 'location', 'in', 'the', 'florida', 'keys', 'u', 's', 'a']),
#        list(['what', '1994', 'jan', 'de', 'bont', 'thriller', 'centered', 'around', 'a', 'young', 'cop', 'who', 'tries', 'to', 'keep', 'a', 'bomb', 'on', 'a', 'bus', 'from', 'exploding']),
#        list(['what', '1995', 'chick', 'flick', 'starred', 'clint', 'eastwood', 'as', 'photographer', 'robert', 'kincaid', 'and', 'meryl', 'streep', 'as', 'his', 'short', 'lived', 'love', 'interest']),
#        list(['what', '1995', 'family', 'film', 'centers', 'around', 'a', 'pig', 'raised', 'by', 'sheep', 'dogs', 'with', 'a', 'little', 'help', 'from', 'farmer', 'hoggett']),
#        list(['what', '1995', 'movie', 'centers', 'on', 'a', 'man', 'on', 'the', 'run', 'after', 'committing', 'murder', 'who', 'takes', 'a', 'journey', 'into', 'the', 'spiritual', 'world']),
#        list(['what', '1996', 'billy', 'bob', 'thornton', 'movie', 'centered', 'around', 'a', 'lifelong', 'hospitalized', 'man', 'who', 'is', 'released', 'to', 'start', 'a', 'new', 'life', 'in', 'a', 'small', 'town']),
#        list(['what', '1997', 'hit', 'contained', 'the', 'famous', 'quote', 'i', 'm', 'the', 'king', 'of', 'the', 'world']),
#        list(['what', '1997', 'james', 'cameron', 'film', 'featured', 'leonardo', 'dicaprio', 'exclaiming', 'i', 'm', 'the', 'king', 'of', 'the', 'world']),
#        list(['what', '1999', 'action', 'flick', 'starred', 'brad', 'pitt', 'and', 'edward', 'norton', 'and', 'also', 'had', 'the', 'famous', 'musician', 'meat', 'loaf']),
#        list(['what', '1999', 'film', 'stars', 'nicholas', 'cage', 'as', 'an', 'ambulance', 'paramedic', 'struggling', 'to', 'keep', 'his', 'sanity']),
#        list(['what', '1999', 'movie', 'found', 'haley', 'joel', 'osment', 'as', 'cole', 'sear', 'a', 'boy', 'who', 'communicated', 'with', 'spirits']),
#        list(['what', '2001', 'pixar', 'animated', 'movie', 'stars', 'kevin', 'spacey', 'as', 'the', 'voice', 'of', 'a', 'misfit', 'ant']),
#        list(['what', '2005', 'documentary', 'tells', 'the', 'story', 'of', 'danny', 'trejo', 'from', 'his', 'troubled', 'childhood', 'through', 'present', 'day']),
#        list(['what', '2005', 'james', 'mangold', 'biopic', 'centered', 'around', 'the', 'lives', 'of', 'johnny', 'cash', 'and', 'june', 'carter', 'cash']),
#        list(['what', '2005', 'ron', 'howard', 'biopic', 'tells', 'the', 'story', 'of', 'james', 'braddock', 'a', 'washed', 'up', 'boxer', 'who', 'came', 'back', 'to', 'become', 'a', 'champion']),
#        list(['what', '2006', 'movie', 'takes', 'place', 'in', 'turn', 'of', 'the', 'century', 'vienna', 'where', 'a', 'magician', 'uses', 'his', 'abilities', 'to', 'secure', 'the', 'love', 'of', 'a', 'woman']),
#        list(['what', '2007', 'biopic', 'is', 'about', 'the', 'story', 'of', 'jean', 'dominique', 'bauby', 'and', 'his', 'trouble', 'with', 'locked', 'in', 'syndrome']),
#        list(['what', '2007', 'parody', 'comedy', 'made', 'fun', 'of', 'everyone', 'from', 'the', 'jonas', 'brothers', 'tiger', 'woods', 'and', 'the', 'twilight', 'series']),
#        list(['what', '2008', 'disney', 'pixar', 'classic', 'shows', 'the', 'adventure', 'of', 'a', 'lonely', 'waste', 'collecting', 'robot', 'who', 'goes', 'on', 'a', 'journey', 'in', 'outer', 'space']),
#        list(['what', '2008', 'japanese', 'animated', 'fantasy', 'film', 'written', 'and', 'directed', 'by', 'hayao', 'miyazaki', 'is', 'about', 'brunhilde', 'the', 'fish', 'girl']),
#        list(['what', '2009', 'horror', 'film', 'takes', 'place', 'in', 'the', 'year', '2019', 'when', 'a', 'plague', 'has', 'transformed', 'almost', 'every', 'human', 'into', 'vampires']),
#        list(['what', '2010', 'action', 'adventure', 'comedy', 'stars', 'tom', 'cruise', 'as', 'a', 'troubled', 'spy']),
#        list(['what', '2010', 'american', 'supernatural', 'film', 'featured', 'a', 'group', 'of', 'strangers', 'including', 'arch', 'angel', 'micheal', 'fighting', 'for', 'the', 'fate', 'of', 'humanity']),
#        list(['what', '2010', 'brian', 'levant', 'film', 'starred', 'jackie', 'chan', 'amber', 'valletta', 'billy', 'ray', 'cyrus', 'and', 'madeline', 'carroll']),
#        list(['what', '2010', 'drama', 'centered', 'on', 'the', 'efforts', 'of', 'joan', 'and', 'aileen', 'crowley', 'to', 'find', 'a', 'researcher', 'who', 'might', 'develop', 'a', 'cure', 'for', 'their', 'children', 's', 'rare', 'genetic', 'disorder']),
#        list(['what', '2010', 'horror', 'sequal', 'shows', 'the', 'haunting', 'of', 'a', 'home', 'in', 'carlsbad', 'california']),
#        list(['what', '2010', 'movie', 'centers', 'around', 'a', 'cia', 'special', 'forces', 'team', 'that', 'was', 'betrayed', 'and', 'left', 'for', 'dead', 'by', 'their', 'superiors']),
# ...
#        list(['what', 's', 'the', 'movie', 'based', 'on', 'a', 'true', 'story', 'about', 'the', 'mod', 's', 'involvement', 'in', 'the', 'history', 'of', 'las', 'vegas']),
#        list(['what', 's', 'the', 'movie', 'i', 'always', 'confuse', 'with', 'goodfellas', 'its', 'by', 'the', 'same', 'director', 'and', 'its', 'about', 'gangsters', 'running', 'gambling', 'in', 'las', 'vegas']),
#        list(['what', 's', 'the', 'movie', 'starring', 'nathan', 'lane', 'and', 'matthew', 'broderick', 'in', 'which', 'the', 'intentionally', 'try', 'to', 'create', 'the', 'worlds', 'worst', 'play']),
#        list(['what', 's', 'the', 'movie', 'that', 'has', 'a', 'main', 'cast', 'of', 'nothing', 'but', 'girls', 'in', 'a', 'mental', 'institute', 'who', 'live', 'in', 'an', 'alternate', 'reality', 'and', 'stars', 'emily', 'browning', 'and', 'vanessa', 'hudgens']),
#        list(['what', 's', 'the', 'movie', 'where', 'a', 'film', 'crew', 'stumbles', 'on', 'a', 'heck', 'of', 'a', 'big', 'monkey']),
#        list(['what', 's', 'the', 'movie', 'where', 'brad', 'pitt', 'and', 'morgan', 'freeman', 'track', 'a', 'moralistic', 'killer', 'in', 'chicago']),
#        list(['what', 's', 'the', 'movie', 'with', 'john', 'wayne', 'where', 'you', 're', 'not', 'sure', 'if', 'he', 's', 'going', 'to', 'rescue', 'or', 'kill', 'a', 'girl']),
#        list(['what', 's', 'the', 'movie', 'with', 'russell', 'crowe', 'playing', 'a', 'genius', 'mathematician', 'who', 'gets', 'a', 'job', 'in', 'cryptography']),
#        list(['what', 's', 'the', 'name', 'of', 'that', 'famous', 'marlon', 'brando', 'film', 'where', 'he', 'says', 'i', 'coulda', 'been', 'a', 'contender']),
#        list(['what', 's', 'the', 'name', 'of', 'that', 'martial', 'film', 'by', 'ang', 'lee', 'where', 'chow', 'yun', 'fat', 'hunts', 'for', 'a', 'sword', 'in', 'the', 'hands', 'of', 'ziyi', 'zhang']),
#        list(['what', 's', 'the', 'name', 'of', 'that', 'movie', 'that', 'has', 'guy', 'in', 'the', 'wheelchair', 'and', 'that', 'actress', 'from', 'aliens', 'and', 'they', 're', 'on', 'an', 'alien', 'planet', 'that', 's', 'full', 'of', 'animals', 'and', 'plants']),
#        list(['what', 's', 'the', 'name', 'of', 'the', 'classic', 'movie', 'where', 'no', 'one', 'believes', 'the', 'guy', 'who', 'claims', 'to', 'be', 'santa', 'claus']),
#        list(['what', 's', 'the', 'name', 'of', 'the', 'comedy', 'where', 'jennifer', 'anniston', 'plays', 'a', 'sexually', 'deviant', 'character']),
#        list(['what', 's', 'the', 'name', 'of', 'the', 'movie', 'where', 'a', 'giant', 'green', 'lizard', 'goes', 'on', 'a', 'rampage', 'in', 'a', 'city']),
#        list(['what', 's', 'the', 'one', 'with', 'that', 'guy', 'from', 'the', 'matrix', 'and', 'the', 'girl', 'from', 'titanic', 'where', 'they', 'try', 'to', 'save', 'the', 'world']),
#        list(['what', 's', 'the', 'recent', 'movie', 'in', 'which', 'amy', 'adams', 'is', 'the', 'estranged', 'adult', 'child', 'of', 'clint', 'eastwood', 's', 'character', 'who', 'is', 'heavy', 'into', 'the', 'baseball', 'world', 'and', 'she', 'meets', 'a', 'guy', 'along', 'the', 'way']),
#        list(['what', 's', 'the', 'true', 'life', 'movie', 'starring', 'johnny', 'depp', 'about', 'the', 'ringleader', 'of', 'a', 'massive', 'drug', 'cartel']),
#        list(['what', 's', 'the', 'ultra', 'violent', 'chinese', 'film', 'that', 'ends', 'in', 'a', 'prolonged', 'shootout', 'between', 'cops', 'and', 'bad', 'guys', 'in', 'a', 'hospital']),
#        list(['what', 's', 'the', 'violent', 'movie', 'where', 'ryan', 'goslin', 'does', 'all', 'sorts', 'of', 'nasty', 'stuff', 'to', 'bad', 'guys', 'to', 'protect', 'a', 'wife', 'and', 'kid']),
#        list(['what', 'sci', 'fi', 'film', 'features', 'a', 'small', 'group', 'of', 'older', 'children', 'obsessed', 'with', 'filming', 'on', 'their', 'new', 'super', '8', 'camera', 'witnessing', 'an', 'alien', 'discovery']),
#        list(['what', 'sequel', 'to', 'an', 'animated', 'box', 'office', 'smash', 'hit', 'involves', 'a', 'colorful', 'cast', 'of', 'animals', 'that', 'are', 'masters', 'in', 'martial', 'arts']),
#        list(['what', 'spielberg', 'movie', 'is', 'considered', 'the', 'first', 'summer', 'blockbuster', 'and', 'involves', 'a', 'killer', 'shark', 's', 'rampage', 'on', 'a', 'resort', 'town']),
#        list(['what', 'stanley', 'kubric', 'masterpiece', 'is', 'hailed', 'as', 'one', 'of', 'the', 'greatest', 'science', 'fiction', 'films', 'ever', 'made']),
#        list(['what', 'stanley', 'kubric', 'masterpiece', 'is', 'hailed', 'as', 'one', 'of', 'the', 'most', 'controversial', 'films', 'of', 'all', 'time']),
#        list(['what', 'stunning', 'action', 'film', 'featured', 'bane', 'as', 'a', 'charismatic', 'super', 'villain', 'trying', 'to', 'take', 'over', 'gothem']),
#        list(['what', 'the', '80', 's', 'movie', 'about', 'a', 'group', 'of', 'former', 'college', 'friends', 'that', 'get', 'together', 'for', 'the', 'weekend']),
#        list(['what', 'timeless', 'classic', 'starring', 'clint', 'eastwood', 'does', 'he', 'carry', 'a', 'large', 'firearm', 'as', 'a', 'police', 'officer']),
#        list(['what', 'was', 'that', 'movie', 'featuring', 'a', 'young', 'anne', 'hathaway', 'as', 'a', 'girl', 'who', 'learns', 'she', 's', 'heir', 'to', 'the', 'throne', 'of', 'genovia']),
#        list(['what', 'was', 'that', 'movie', 'starring', 'jake', 'gyllenhal', 'and', 'heath', 'ledger', 'as', 'cowboys', 'who', 'fall', 'in', 'love', 'with', 'each', 'other']),
#        list(['what', 'was', 'that', 'movie', 'that', 'was', 'the', 'sequel', 'to', 'that', 'jack', 'black', 'animated', 'movie', 'about', 'the', 'animals', 'that', 'know', 'shaolin', 'kung', 'fu']),
#        list(['what', 'was', 'that', 'sci', 'fi', 'adventure', 'film', 'starring', 'keanu', 'reeves', 'in', 'which', 'most', 'characters', 'are', 'revealed', 'to', 'be', 'living', 'in', 'a', 'simulated', 'reality']),
#        list(['what', 'was', 'the', 'first', 'installment', 'of', 'christopher', 'nolan', 's', 'epic', 'trilogy', 'based', 'on', 'the', 'dc', 'comic', 'following', 'a', 'masked', 'vigilante']),
#        list(['what', 'was', 'the', 'last', 'of', 'a', 'series', 'of', 'movies', 'starring', 'johnny', 'depp', 'as', 'a', 'pirate']),
#        list(['what', 'was', 'the', 'movie', 'with', 'the', 'scientists', 'in', 'the', 'extremely', 'cold', 'environment', 'where', 'the', 'scientists', 'encounter', 'a', 'shape', 'shifting', 'alien']),
#        list(['what', 'was', 'the', 'name', 'of', 'that', 'movie', 'that', 'was', 'set', 'in', 'a', 'western', 'theme', 'and', 'being', 'from', 'outer', 'space', 'came', 'in']),
#        list(['what', 'was', 'the', 'name', 'of', 'that', 'walt', 'disney', 'movie', 'that', 'was', 'filled', 'with', 'all', 'kind', 'of', 'colorful', 'animation']),
#        list(['what', 'was', 'the', 'name', 'of', 'the', '1975', 'mega', 'hit', 'thriller', 'in', 'which', 'a', 'great', 'white', 'shark', 'menaced', 'and', 'munched', 'on', 'citizens', 'of', 'the', 'beach', 'resort', 'town', 'of', 'amity', 'during', 'july', '4', 'weekend']),
#        list(['what', 'was', 'the', 'name', 'of', 'the', 'documentary', 'that', 'compiled', 'clips', 'from', 'american', 'propaganda', 'films', 'showing', 'hilariously', 'ineffective', 'ways', 'to', 'survive', 'a', 'nuclear', 'holocaust']),
#        list(['what', 'was', 'the', 'name', 'of', 'the', 'first', 'sylvester', 'stallone', 'movie', 'in', 'a', 'long', 'line', 'of', 'them', 'where', 'he', 'was', 'a', 'boxer']),
#        list(['what', 'was', 'the', 'name', 'of', 'the', 'movie', 'with', 'the', 'little', 'girl', 'and', 'her', 'dad', 'had', 'a', 'whole', 'bunch', 'of', 'firearms', 'all', 'over', 'the', 'walls', 'inside', 'their', 'apartment']),
#        list(['what', 'was', 'the', 'second', 'movie', 'in', 'that', 'george', 'lucas', 'sci', 'fi', 'movie', 'trilogy', 'the', 'one', 'where', 'they', 'introduced', 'the', 'short', 'green', 'master', 'guy']),
#        list(['when', 'a', 'christmas', 'party', 'turns', 'into', 'a', 'hostage', 'crisis', 'one', 'man', 'takes', 'matters', 'into', 'his', 'own', 'hands']),
#        list(['when', 'a', 'mad', 'man', 'calling', 'himself', 'the', 'scorpio', 'killer', 'menaces', 'the', 'city', 'tough', 'as', 'nails', 'san', 'francisco', 'police', 'inspector', 'harry', 'callahan', 'is', 'assigned', 'to', 'track', 'down', 'and', 'ferret', 'out', 'the', 'crazed', 'psychopath']),
#        list(['when', 'a', 'man', 'goes', 'for', 'virtual', 'vacation', 'memories', 'of', 'the', 'planet', 'mars', 'an', 'unexpected', 'and', 'harrowing', 'series', 'of', 'events', 'forces', 'him', 'to', 'go', 'to', 'the', 'planet', 'is', 'the', 'plot', 'of', 'this', 'sci', 'fic', 'action', 'movie']),
#        list(['when', 'a', 'sports', 'agent', 'has', 'a', 'moral', 'epiphany', 'and', 'is', 'fired', 'for', 'expressing', 'it', 'he', 'decides', 'to', 'put', 'his', 'new', 'philosophy', 'to', 'the', 'test', 'as', 'an', 'independent', 'with', 'the', 'only', 'athlete', 'who', 'stays', 'with', 'him', 'is', 'the', 'plot', 'of', 'this', '1996', 'romantic', 'drama', 'starring', 'tom', 'cruise']),
#        list(['which', '1985', 'film', 'based', 'on', 'a', '1982', 'novel', 'by', 'alice', 'walker', 'focuses', 'on', 'the', 'problems', 'faced', 'by', 'african', 'american', 'women', 'during', 'the', '1900', 's']),
#        list(['which', '1988', 'movie', 'stars', 'a', 'young', 'val', 'kilmer', 'where', 'he', 'has', 'to', 'help', 'a', 'dwarf', 'protect', 'a', 'baby', 'from', 'an', 'evil', 'queen']),
#        list(['which', '2003', 'christmas', 'comedy', 'starred', 'snl', 'comedian', 'will', 'ferrell', 'who', 'travels', 'from', 'the', 'north', 'pole', 'to', 'new', 'york', 'city', 'in', 'search', 'of', 'his', 'father']),
#        list(['which', '90', 's', 'american', 'slasher', 'film', 'directed', 'by', 'wes', 'craven', 'features', 'an', 'iconically', 'masked', 'murderer', 'who', 'preys', 'on', 'teenagers', 'loosely', 'based', 'on', 'the', 'gainesville', 'ripper']),
#        list(['which', '90', 's', 'animated', 'film', 'has', 'such', 'songs', 'as', 'hakuna', 'matata', 'and', 'the', 'circle', 'of', 'life']),
#        list(['which', 'comedy', 'classic', 'featuring', 'billy', 'crystal', 'and', 'andre', 'the', 'giant', 'tells', 'the', 'story', 'of', 'prince', 'wesley', 'as', 'he', 'tries', 'to', 'capture', 'the', 'affections', 'and', 'save', 'the', 'life', 'of', 'princess', 'buttercup']),
#        list(['which', 'disney', 'film', 'introduces', 'a', 'curly', 'red', 'headed', 'overly', 'independent', 'princess', 'looking', 'to', 'follow', 'her', 'dreams']),
#        list(['which', 'film', 'starred', 'vanessa', 'hudgens', 'in', 'a', 'modern', 'day', 'retelling', 'of', 'beauty', 'and', 'the', 'beast']),
#        list(['which', 'film', 'stars', 'steve', 'carrell', 'as', 'a', 'middle', 'aged', 'divorced', 'man', 'trying', 'to', 'find', 'love', 'after', 'his', 'wife', 'has', 'an', 'affair']),
#        list(['which', 'film', 'was', 'quirky', 'director', 'wes', 'anderson', 's', 'foray', 'into', 'the', 'world', 'of', 'author', 'roald', 'dahl', 'and', 'hand', 'crafted', 'stop', 'motion', 'filmmaking']),
#        list(['which', 'francis', 'ford', 'coppola', 'directed', 'movie', 'featured', 'robert', 'deniro', 'playing', 'a', 'young', 'don', 'corleone', 'in', 'sicily']),
#        list(['which', 'hayao', 'miyazaki', 'animated', 'film', 'tells', 'the', 'story', 'of', 'a', 'girl', 'who', 'enters', 'an', 'alternate', 'reality', 'and', 'must', 'find', 'her', 'way', 'to', 'freedom']),
#        list(['which', 'iconic', 'detective', 'movie', 'has', 'a', 'young', 'clint', 'eastwood', 'uttering', 'the', 'words', 'make', 'my', 'day']),
#        list(['which', 'is', 'the', 'movie', 'based', 'on', 'a', 'book', 'by', 'c', 's', 'lewis', 'featuring', 'the', 'pevensie', 'children', 'as', 'they', 'try', 'to', 'rescue', 'the', 'seven', 'lords', 'of', 'narnia']),
#        list(['which', 'john', 'travolta', 'and', 'nick', 'cage', 'movie', 'features', 'an', 'undercover', 'agent', 'who', 'must', 'change', 'his', 'appearance', 'to', 'infiltrate', 'a', 'criminal', 'organization']),
#        list(['which', 'movie', 'features', 'the', 'trials', 'and', 'tribulations', 'of', 'mark', 'zuckerberg', 'setting', 'up', 'his', 'digital', 'empire']),
#        list(['which', 'movie', 'is', 'the', 'one', 'that', 's', 'about', 'the', 'girl', 'in', 'the', 'tower', 'who', 'has', 'long', 'magical', 'hair', 'that', 'glows']),
#        list(['which', 'movie', 'starring', 'brad', 'pitt', 'and', 'edward', 'norton', 'contains', 'the', 'first', 'rule', 'is', 'to', 'not', 'talk', 'about', 'it']),
#        list(['which', 'musical', 'set', 'in', '1950', 's', 'new', 'york', 'features', 'two', 'rival', 'gangs', 'the', 'sharks', 'and', 'the', 'jets', 'playing', 'out', 'a', 'modern', 'day', 'retelling', 'of', 'romeo', 'and', 'juliet']),
#        list(['which', 'of', 'these', 'films', 'showed', 'us', 'the', 'murder', 'of', 'a', 'king', 'the', 'defection', 'of', 'a', 'prince', 'and', 'an', 'angry', 'uncle', 'ascending', 'the', 'throne']),
#        list(['which', 'of', 'these', 'movies', 'has', 'an', 'actor', 'who', 'has', 'since', 'gotten', 'into', 'trouble', 'with', 'the', 'law', 'several', 'times']),
#        list(['which', 'of', 'these', 'movies', 'is', 'a', 'cross', 'over', 'of', 'two', 'separate', 'films', 'that', 'exist', 'within', 'a', 'similar', 'genre']),
#        list(['which', 'one', 'of', 'the', 'following', 'films', 'listed', 'took', 'place', 'in', 'a', 'french', 'train', 'station', 'in', 'the', '1930', 's']),
#        list(['which', 'period', 'drama', 'centered', 'around', 'music', 'features', 'rival', 'composers', 'competing', 'against', 'each', 'other', 'in', 'vienna', 'during', 'the', '18', 'th', 'century']),
#        list(['which', 'quentin', 'tarantino', 'film', 'told', 'the', 'story', 'of', 'two', 'attempts', 'to', 'assassinate', 'political', 'leaders', 'in', 'nazi', 'germany']),
#        list(['which', 'steven', 'spielberg', 'film', 'tells', 'the', 'story', 'of', 'a', 'german', 'businessman', 'who', 'saved', 'the', 'lives', 'of', 'nearly', 'a', 'thousand', 'jews', 'during', 'world', 'war', '2']),
#        list(['which', 'war', 'film', 'depicted', 'the', 'life', 'of', 'ordinary', 'sailors', 'on', 'a', 'german', 'u', 'boat', 'during', 'world', 'war', '2']),
#        list(['whos', 'brain', 'did', 'dr', 'frankenstein', 'put', 'in', 'the', 'jar']),
#        list(['why', 'were', 'the', 'pacifists', 'so', 'easily', 'turned', 'to', 'murder', 'perhaps', 'vegetarians', 'have', 'the', 'same', 'lust', 'for', 'life', 'as', 'the', 'rest', 'of', 'us']),
#        list(['will', 'forte', 'plays', 'an', 'ex', 'special', 'operative', 'trying', 'to', 'stop', 'his', 'arch', 'enemy', 'dieter', 'von', 'cunth', 'from', 'destroying', 'washington', 'd', 'c']),
#        list(['william', 'brent', 'bell', 'wrote', 'and', 'directed', 'this', '2012', 'horror', 'movie', 'about', 'a', 'series', 'of', 'unauthorized', 'exorcisms', 'in', 'italy']),
#        list(['winona', 'ryder', 'is', 'a', 'girl', 'who', 'half', 'heartedly', 'tries', 'to', 'be', 'part', 'of', 'the', 'in', 'crowd', 'of', 'her', 'school', 'when', 'she', 'meets', 'a', 'rebel', 'who', 'teaches', 'her', 'a', 'more', 'devious', 'way', 'to', 'play', 'social', 'politics', 'in', 'this', '1988', 'comedy', 'drama']),
#        list(['you', 'are', 'living', 'in', 'the', 'pacific', 'northwest', 'and', 'forming', 'a', 'group', 'of', 'neighbors', 'to', 'hold', 'back', 'the', 'invading', 'north', 'koreans', 'what', 'movie', 'are', 'you', 'in']),
#        list(['you', 'are', 'told', 'that', 'who', 'need', 'to', 'rob', 'a', 'bank', 'or', 'else', 'by', 'two', 'people', 'dressed', 'in', 'planet', 'of', 'the', 'apes', 'masks', 'what', 'movie', 'are', 'you', 'in']),
#        list(['you', 'know', 'the', 'prefects', 'bathroom', 'on', 'the', 'fifth', 'floor', 'it', 's', 'not', 'a', 'bad', 'place', 'for', 'a', 'bath', 'just', 'take', 'your', 'egg', 'and', 'mull', 'things', 'over', 'in', 'the', 'hot', 'water', 'is', 'a', 'quote', 'from', 'which', 'j', 'k', 'rowling', 'novel', 'turned', 'movie'])],
#       dtype=object)

# %% [markdown]
# # 3. Error analysis 2: False negatives (5 marks)
#
# For the 5 classes which have the lowest recall, according to the results table from your 20% development data,, print out all the sentences where there is a false negative for that label (i.e. the label is present in the ground truth label for a given word, but that label is not predicted for that word by the tagger). HINT: This may most easily be achieved by editing the code above beginning `print("testing tagger...")` and ending `print("done")`. Have a look at these errors closely, and think about which features could be added to reduce the number of these errors.

# %%
preds2 = []
truelabels2 = []
falselabel2 =[]
false_negative_sentences = []
categories2 = ["B-Character_Name", "B-Soundtrack", "I-Character_Name", "I-Opinion", "I-Soundtrack"]
for sent2 in x_test:
    sent_preds2 = [x[1] for x in ct.tag([s[0] for s in sent2])]
    sent_true2 = [s[1] for s in sent2]
    word2=[s[0] for s in sent2]
    for i in range(len(sent2)):
      if sent_preds2[i] != sent_true2[i]: 
        if sent_true2[i] in categories2:
          false_negative_sentences.append(word2)
          truelabels2.append(sent_true2)
          falselabel2.append(sent_preds2)

# %%
for i in range(len(false_negative_sentences)):
  x2 = PrettyTable()
  x2.field_names = ["Sentence", "True Label", "Predicted Label"]
  for j in range(len(false_negative_sentences[i])):
    x2.add_row([false_negative_sentences[i][j], truelabels2[i][j], falselabel2[i][j]])
  print(x2)
# Out:
# Streaming output truncated to the last 5000 lines.
# |  simba   | B-Character_Name | B-Character_Name |
# |   who    |      B-Plot      |      B-Plot      |
# | returns  |      I-Plot      |      I-Plot      |
# |    to    |      I-Plot      |      I-Plot      |
# |   his    |      I-Plot      |      I-Plot      |
# | homeland |      I-Plot      |      I-Plot      |
# |    to    |      I-Plot      |      I-Plot      |
# | reclaim  |      I-Plot      |      I-Plot      |
# |   the    |      I-Plot      |      I-Plot      |
# |  crown   |      I-Plot      |      I-Plot      |
# |   from   |      I-Plot      |      I-Plot      |
# |   his    |      I-Plot      |      I-Plot      |
# |  uncle   | B-Character_Name |      I-Plot      |
# |   scar   | I-Character_Name |      I-Plot      |
# +----------+------------------+------------------+
# +--------------+------------+-----------------+
# |   Sentence   | True Label | Predicted Label |
# +--------------+------------+-----------------+
# |     what     |     O      |        O        |
# |    black     |     O      |        O        |
# |     and      |     O      |        O        |
# |    white     |     O      |        O        |
# |   japanese   |  B-Genre   |     B-Genre     |
# |   classic    | B-Opinion  |     I-Genre     |
# |     epic     | I-Opinion  |     I-Genre     |
# |   features   |     O      |        O        |
# |      a       |   B-Plot   |        O        |
# |    story     |   I-Plot   |        O        |
# |    about     |   I-Plot   |        O        |
# |      7       |   I-Plot   |      B-Plot     |
# |   warriors   |   I-Plot   |      I-Plot     |
# |    facing    |   I-Plot   |      I-Plot     |
# | unimaginable |   I-Plot   |      I-Plot     |
# |     odds     |   I-Plot   |      I-Plot     |
# +--------------+------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |     what    |     O      |        O        |
# | blockbuster | B-Opinion  |        O        |
# |     film    |     O      |        O        |
# |    stars    |     O      |        O        |
# |     liam    |  B-Actor   |     B-Actor     |
# |    nieson   |  I-Actor   |     I-Actor     |
# |      in     |     O      |      B-Plot     |
# |     his     |     O      |      I-Plot     |
# |    heart    | B-Opinion  |      I-Plot     |
# |   stopping  | I-Opinion  |      I-Plot     |
# |   thriller  |  B-Genre   |      I-Plot     |
# |    which    |     O      |      I-Plot     |
# |    takes    |     O      |      I-Plot     |
# |    place    |     O      |      I-Plot     |
# |      in     |     O      |      I-Plot     |
# |      a      |     O      |      I-Plot     |
# |    snowy    |     O      |      I-Plot     |
# |  wasteland  |     O      |      I-Plot     |
# +-------------+------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |   boxing  |     B-Genre      |        O        |
# |  centric  |     I-Genre      |        O        |
# |   movie   |        O         |        O        |
# |  inspired |        O         |      B-Plot     |
# |    the    |        O         |      I-Plot     |
# | character |        O         |      I-Plot     |
# |    tag    |        O         |      I-Plot     |
# |    line   |        O         |      I-Plot     |
# |     of    |        O         |      I-Plot     |
# |  italian  | B-Character_Name |      I-Plot     |
# |  stallion | I-Character_Name |      I-Plot     |
# |    and    |        O         |      I-Plot     |
# |  inspired |      B-Plot      |      I-Plot     |
# |  legions  |      I-Plot      |      I-Plot     |
# |     of    |      I-Plot      |      I-Plot     |
# |    fans   |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |  workout  |      I-Plot      |      I-Plot     |
# |     to    |        O         |      I-Plot     |
# |    the    |        O         |      I-Plot     |
# |    song   |        O         |      I-Plot     |
# |    eye    |   B-Soundtrack   |      I-Plot     |
# |     of    |   I-Soundtrack   |      I-Plot     |
# |    the    |   I-Soundtrack   |      I-Plot     |
# |   tiger   |   I-Soundtrack   |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |   boxing  |     B-Genre      |        O        |
# |  centric  |     I-Genre      |        O        |
# |   movie   |        O         |        O        |
# |  inspired |        O         |      B-Plot     |
# |    the    |        O         |      I-Plot     |
# | character |        O         |      I-Plot     |
# |    tag    |        O         |      I-Plot     |
# |    line   |        O         |      I-Plot     |
# |     of    |        O         |      I-Plot     |
# |  italian  | B-Character_Name |      I-Plot     |
# |  stallion | I-Character_Name |      I-Plot     |
# |    and    |        O         |      I-Plot     |
# |  inspired |      B-Plot      |      I-Plot     |
# |  legions  |      I-Plot      |      I-Plot     |
# |     of    |      I-Plot      |      I-Plot     |
# |    fans   |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |  workout  |      I-Plot      |      I-Plot     |
# |     to    |        O         |      I-Plot     |
# |    the    |        O         |      I-Plot     |
# |    song   |        O         |      I-Plot     |
# |    eye    |   B-Soundtrack   |      I-Plot     |
# |     of    |   I-Soundtrack   |      I-Plot     |
# |    the    |   I-Soundtrack   |      I-Plot     |
# |   tiger   |   I-Soundtrack   |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |   boxing  |     B-Genre      |        O        |
# |  centric  |     I-Genre      |        O        |
# |   movie   |        O         |        O        |
# |  inspired |        O         |      B-Plot     |
# |    the    |        O         |      I-Plot     |
# | character |        O         |      I-Plot     |
# |    tag    |        O         |      I-Plot     |
# |    line   |        O         |      I-Plot     |
# |     of    |        O         |      I-Plot     |
# |  italian  | B-Character_Name |      I-Plot     |
# |  stallion | I-Character_Name |      I-Plot     |
# |    and    |        O         |      I-Plot     |
# |  inspired |      B-Plot      |      I-Plot     |
# |  legions  |      I-Plot      |      I-Plot     |
# |     of    |      I-Plot      |      I-Plot     |
# |    fans   |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |  workout  |      I-Plot      |      I-Plot     |
# |     to    |        O         |      I-Plot     |
# |    the    |        O         |      I-Plot     |
# |    song   |        O         |      I-Plot     |
# |    eye    |   B-Soundtrack   |      I-Plot     |
# |     of    |   I-Soundtrack   |      I-Plot     |
# |    the    |   I-Soundtrack   |      I-Plot     |
# |   tiger   |   I-Soundtrack   |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |   boxing  |     B-Genre      |        O        |
# |  centric  |     I-Genre      |        O        |
# |   movie   |        O         |        O        |
# |  inspired |        O         |      B-Plot     |
# |    the    |        O         |      I-Plot     |
# | character |        O         |      I-Plot     |
# |    tag    |        O         |      I-Plot     |
# |    line   |        O         |      I-Plot     |
# |     of    |        O         |      I-Plot     |
# |  italian  | B-Character_Name |      I-Plot     |
# |  stallion | I-Character_Name |      I-Plot     |
# |    and    |        O         |      I-Plot     |
# |  inspired |      B-Plot      |      I-Plot     |
# |  legions  |      I-Plot      |      I-Plot     |
# |     of    |      I-Plot      |      I-Plot     |
# |    fans   |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |  workout  |      I-Plot      |      I-Plot     |
# |     to    |        O         |      I-Plot     |
# |    the    |        O         |      I-Plot     |
# |    song   |        O         |      I-Plot     |
# |    eye    |   B-Soundtrack   |      I-Plot     |
# |     of    |   I-Soundtrack   |      I-Plot     |
# |    the    |   I-Soundtrack   |      I-Plot     |
# |   tiger   |   I-Soundtrack   |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |   boxing  |     B-Genre      |        O        |
# |  centric  |     I-Genre      |        O        |
# |   movie   |        O         |        O        |
# |  inspired |        O         |      B-Plot     |
# |    the    |        O         |      I-Plot     |
# | character |        O         |      I-Plot     |
# |    tag    |        O         |      I-Plot     |
# |    line   |        O         |      I-Plot     |
# |     of    |        O         |      I-Plot     |
# |  italian  | B-Character_Name |      I-Plot     |
# |  stallion | I-Character_Name |      I-Plot     |
# |    and    |        O         |      I-Plot     |
# |  inspired |      B-Plot      |      I-Plot     |
# |  legions  |      I-Plot      |      I-Plot     |
# |     of    |      I-Plot      |      I-Plot     |
# |    fans   |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |  workout  |      I-Plot      |      I-Plot     |
# |     to    |        O         |      I-Plot     |
# |    the    |        O         |      I-Plot     |
# |    song   |        O         |      I-Plot     |
# |    eye    |   B-Soundtrack   |      I-Plot     |
# |     of    |   I-Soundtrack   |      I-Plot     |
# |    the    |   I-Soundtrack   |      I-Plot     |
# |   tiger   |   I-Soundtrack   |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |   boxing  |     B-Genre      |        O        |
# |  centric  |     I-Genre      |        O        |
# |   movie   |        O         |        O        |
# |  inspired |        O         |      B-Plot     |
# |    the    |        O         |      I-Plot     |
# | character |        O         |      I-Plot     |
# |    tag    |        O         |      I-Plot     |
# |    line   |        O         |      I-Plot     |
# |     of    |        O         |      I-Plot     |
# |  italian  | B-Character_Name |      I-Plot     |
# |  stallion | I-Character_Name |      I-Plot     |
# |    and    |        O         |      I-Plot     |
# |  inspired |      B-Plot      |      I-Plot     |
# |  legions  |      I-Plot      |      I-Plot     |
# |     of    |      I-Plot      |      I-Plot     |
# |    fans   |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |  workout  |      I-Plot      |      I-Plot     |
# |     to    |        O         |      I-Plot     |
# |    the    |        O         |      I-Plot     |
# |    song   |        O         |      I-Plot     |
# |    eye    |   B-Soundtrack   |      I-Plot     |
# |     of    |   I-Soundtrack   |      I-Plot     |
# |    the    |   I-Soundtrack   |      I-Plot     |
# |   tiger   |   I-Soundtrack   |      I-Plot     |
# +-----------+------------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |   B-Genre    |    B-Opinion    |
# |  disney  |   I-Genre    |     B-Genre     |
# |   film   |      O       |        O        |
# |  takes   |    B-Plot    |      B-Plot     |
# |  place   |    I-Plot    |      I-Plot     |
# |    in    |    I-Plot    |      I-Plot     |
# |  africa  |    I-Plot    |      I-Plot     |
# |   and    |      O       |      I-Plot     |
# | includes |      O       |      I-Plot     |
# | musical  |      O       |      I-Plot     |
# |  pieces  |      O       |      I-Plot     |
# |   such   |      O       |      I-Plot     |
# |    as    |      O       |      I-Plot     |
# | hakkuna  | B-Soundtrack |      I-Plot     |
# | mattata  | I-Soundtrack |      I-Plot     |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |   B-Genre    |    B-Opinion    |
# |  disney  |   I-Genre    |     B-Genre     |
# |   film   |      O       |        O        |
# |  takes   |    B-Plot    |      B-Plot     |
# |  place   |    I-Plot    |      I-Plot     |
# |    in    |    I-Plot    |      I-Plot     |
# |  africa  |    I-Plot    |      I-Plot     |
# |   and    |      O       |      I-Plot     |
# | includes |      O       |      I-Plot     |
# | musical  |      O       |      I-Plot     |
# |  pieces  |      O       |      I-Plot     |
# |   such   |      O       |      I-Plot     |
# |    as    |      O       |      I-Plot     |
# | hakkuna  | B-Soundtrack |      I-Plot     |
# | mattata  | I-Soundtrack |      I-Plot     |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +----------+--------------+-----------------+
# | Sentence |  True Label  | Predicted Label |
# +----------+--------------+-----------------+
# |   what   |      O       |        O        |
# | classic  |  B-Opinion   |     B-Genre     |
# | thriller |   B-Genre    |     I-Genre     |
# |  about   |      O       |        O        |
# |    an    |    B-Plot    |        O        |
# | enormous |    I-Plot    |    B-Opinion    |
# |  killer  |    I-Plot    |    I-Opinion    |
# |  shark   |    I-Plot    |    I-Opinion    |
# | spawned  |      O       |    I-Opinion    |
# |   one    | B-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   the    | I-Soundtrack |    I-Opinion    |
# |   most   | I-Soundtrack |    I-Opinion    |
# | popular  | I-Soundtrack |    I-Opinion    |
# |  movie   | I-Soundtrack |    I-Opinion    |
# |  themes  | I-Soundtrack |    I-Opinion    |
# |    of    | I-Soundtrack |    I-Opinion    |
# |   all    | I-Soundtrack |    I-Opinion    |
# |   time   | I-Soundtrack |    I-Opinion    |
# +----------+--------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |    film    |        O         |        O        |
# |  directed  |        O         |        O        |
# |     by     |        O         |        O        |
# |   david    |    B-Director    |    B-Director   |
# |  fincher   |    I-Director    |    I-Director   |
# |   tells    |        O         |        O        |
# |     of     |        O         |        O        |
# |    mark    | B-Character_Name |     B-Actor     |
# | zuckerberg | I-Character_Name |     I-Actor     |
# |     s      |        O         |      B-Plot     |
# |    rise    |      B-Plot      |      I-Plot     |
# |     to     |      I-Plot      |      I-Plot     |
# |   power    |      I-Plot      |      I-Plot     |
# |    and     |      I-Plot      |      I-Plot     |
# |    the     |      I-Plot      |      I-Plot     |
# |  creation  |      I-Plot      |      I-Plot     |
# |     of     |      I-Plot      |      I-Plot     |
# |  facebook  |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |    film    |        O         |        O        |
# |  directed  |        O         |        O        |
# |     by     |        O         |        O        |
# |   david    |    B-Director    |    B-Director   |
# |  fincher   |    I-Director    |    I-Director   |
# |   tells    |        O         |        O        |
# |     of     |        O         |        O        |
# |    mark    | B-Character_Name |     B-Actor     |
# | zuckerberg | I-Character_Name |     I-Actor     |
# |     s      |        O         |      B-Plot     |
# |    rise    |      B-Plot      |      I-Plot     |
# |     to     |      I-Plot      |      I-Plot     |
# |   power    |      I-Plot      |      I-Plot     |
# |    and     |      I-Plot      |      I-Plot     |
# |    the     |      I-Plot      |      I-Plot     |
# |  creation  |      I-Plot      |      I-Plot     |
# |     of     |      I-Plot      |      I-Plot     |
# |  facebook  |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |    film    |        O         |        O        |
# | introduced |        O         |        O        |
# |    the     |        O         |        O        |
# |   knives   |        O         |      B-Plot     |
# |    for     |        O         |      I-Plot     |
# |  fingers   |        O         |      I-Plot     |
# | character  |        O         |      I-Plot     |
# |     of     |        O         |      I-Plot     |
# |   freddy   | B-Character_Name |      I-Plot     |
# |  krueger   | I-Character_Name |      I-Plot     |
# |    that    |      B-Plot      |      I-Plot     |
# |   haunts   |      I-Plot      |      I-Plot     |
# |    the     |      I-Plot      |      I-Plot     |
# |   dreams   |      I-Plot      |      I-Plot     |
# |     of     |      I-Plot      |      I-Plot     |
# | teenagers  |      I-Plot      |      I-Plot     |
# | eventually |      I-Plot      |      I-Plot     |
# |  killing   |      I-Plot      |      I-Plot     |
# |    them    |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |    film    |        O         |        O        |
# | introduced |        O         |        O        |
# |    the     |        O         |        O        |
# |   knives   |        O         |      B-Plot     |
# |    for     |        O         |      I-Plot     |
# |  fingers   |        O         |      I-Plot     |
# | character  |        O         |      I-Plot     |
# |     of     |        O         |      I-Plot     |
# |   freddy   | B-Character_Name |      I-Plot     |
# |  krueger   | I-Character_Name |      I-Plot     |
# |    that    |      B-Plot      |      I-Plot     |
# |   haunts   |      I-Plot      |      I-Plot     |
# |    the     |      I-Plot      |      I-Plot     |
# |   dreams   |      I-Plot      |      I-Plot     |
# |     of     |      I-Plot      |      I-Plot     |
# | teenagers  |      I-Plot      |      I-Plot     |
# | eventually |      I-Plot      |      I-Plot     |
# |  killing   |      I-Plot      |      I-Plot     |
# |    them    |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +----------+------------+-----------------+
# | Sentence | True Label | Predicted Label |
# +----------+------------+-----------------+
# |   what   |     O      |        O        |
# | intense  | B-Opinion  |        O        |
# |  gritty  | I-Opinion  |        O        |
# |   2012   |   B-Year   |      B-Year     |
# |   cop    |  B-Genre   |     B-Genre     |
# |  drama   |  I-Genre   |     I-Genre     |
# | focuses  |   B-Plot   |        O        |
# |    on    |   I-Plot   |        O        |
# |   the    |   I-Plot   |      B-Plot     |
# |   day    |   I-Plot   |      I-Plot     |
# |    to    |   I-Plot   |      I-Plot     |
# |   day    |   I-Plot   |      I-Plot     |
# |    of    |   I-Plot   |      I-Plot     |
# |   two    |   I-Plot   |      I-Plot     |
# |   los    |   I-Plot   |      I-Plot     |
# | angelos  |   I-Plot   |      I-Plot     |
# |  police  |   I-Plot   |      I-Plot     |
# | officers |   I-Plot   |      I-Plot     |
# +----------+------------+-----------------+
# +----------+------------------+-----------------+
# | Sentence |    True Label    | Predicted Label |
# +----------+------------------+-----------------+
# |   what   |        O         |        O        |
# |    is    |        O         |        O        |
# |   that   |        O         |        O        |
# |   2012   |      B-Year      |      B-Year     |
# |  movie   |        O         |        O        |
# |   that   |        O         |        O        |
# |  stars   |        O         |        O        |
# |   liam   |     B-Actor      |     B-Actor     |
# |  neeson  |     I-Actor      |     I-Actor     |
# |    as    |        O         |        O        |
# |   zeus   | B-Character_Name |        O        |
# |   and    |        O         |        O        |
# |  ralph   |     B-Actor      |     B-Actor     |
# | fiennes  |     I-Actor      |     I-Actor     |
# |    as    |        O         |        O        |
# |  hades   | B-Character_Name |        O        |
# +----------+------------------+-----------------+
# +----------+------------------+-----------------+
# | Sentence |    True Label    | Predicted Label |
# +----------+------------------+-----------------+
# |   what   |        O         |        O        |
# |    is    |        O         |        O        |
# |   that   |        O         |        O        |
# |   2012   |      B-Year      |      B-Year     |
# |  movie   |        O         |        O        |
# |   that   |        O         |        O        |
# |  stars   |        O         |        O        |
# |   liam   |     B-Actor      |     B-Actor     |
# |  neeson  |     I-Actor      |     I-Actor     |
# |    as    |        O         |        O        |
# |   zeus   | B-Character_Name |        O        |
# |   and    |        O         |        O        |
# |  ralph   |     B-Actor      |     B-Actor     |
# | fiennes  |     I-Actor      |     I-Actor     |
# |    as    |        O         |        O        |
# |  hades   | B-Character_Name |        O        |
# +----------+------------------+-----------------+
# +------------+------------+-----------------+
# |  Sentence  | True Label | Predicted Label |
# +------------+------------+-----------------+
# |    what    |     O      |        O        |
# |     is     |     O      |        O        |
# |    that    |     O      |        O        |
# |   comedy   |  B-Genre   |     B-Genre     |
# |    film    |     O      |        O        |
# |  starring  |     O      |        O        |
# |    jon     |  B-Actor   |     B-Actor     |
# |   heder    |  I-Actor   |     I-Actor     |
# |     in     |     O      |        O        |
# |     a      |     O      |        O        |
# |  breakout  | B-Opinion  |        O        |
# |    role    | I-Opinion  |        O        |
# |     as     |     O      |        O        |
# |     an     |     O      |      B-Plot     |
# |  awkward   |   B-Plot   |      I-Plot     |
# |    teen    |   I-Plot   |      I-Plot     |
# |    and     |   I-Plot   |      I-Plot     |
# |  details   |   I-Plot   |      I-Plot     |
# |    his     |   I-Plot   |      I-Plot     |
# | adventures |   I-Plot   |      I-Plot     |
# |     in     |   I-Plot   |      I-Plot     |
# |    high    |   I-Plot   |      I-Plot     |
# |   school   |   I-Plot   |      I-Plot     |
# +------------+------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |     what     |        O         |        O        |
# |      is      |        O         |        O        |
# |     that     |        O         |        O        |
# |    movie     |        O         |        O        |
# |     2012     |      B-Year      |      B-Year     |
# | biographical |     B-Genre      |     B-Genre     |
# |     film     |        O         |        O        |
# |      co      |        O         |        O        |
# |   directed   |        O         |        O        |
# |      by      |        O         |        O        |
# |    curtis    |    B-Director    |     B-Actor     |
# |    hanson    |    I-Director    |     I-Actor     |
# |    about     |      B-Plot      |        O        |
# |     the      |      I-Plot      |      B-Plot     |
# |     life     |      I-Plot      |      I-Plot     |
# |      of      |      I-Plot      |      I-Plot     |
# |     jay      | B-Character_Name |      I-Plot     |
# |   moriarty   | I-Character_Name |      I-Plot     |
# +--------------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |     what     |        O         |        O        |
# |      is      |        O         |        O        |
# |     that     |        O         |        O        |
# |    movie     |        O         |        O        |
# |     2012     |      B-Year      |      B-Year     |
# | biographical |     B-Genre      |     B-Genre     |
# |     film     |        O         |        O        |
# |      co      |        O         |        O        |
# |   directed   |        O         |        O        |
# |      by      |        O         |        O        |
# |    curtis    |    B-Director    |     B-Actor     |
# |    hanson    |    I-Director    |     I-Actor     |
# |    about     |      B-Plot      |        O        |
# |     the      |      I-Plot      |      B-Plot     |
# |     life     |      I-Plot      |      I-Plot     |
# |      of      |      I-Plot      |      I-Plot     |
# |     jay      | B-Character_Name |      I-Plot     |
# |   moriarty   | I-Character_Name |      I-Plot     |
# +--------------+------------------+-----------------+
# +----------+------------------+-----------------+
# | Sentence |    True Label    | Predicted Label |
# +----------+------------------+-----------------+
# |   what   |        O         |        O        |
# |    is    |        O         |        O        |
# |   that   |        O         |        O        |
# |  movie   |        O         |        O        |
# |  about   |        O         |        O        |
# |   the    |        O         |        O        |
# | american |      B-Plot      |        O        |
# | cocaine  |      I-Plot      |     B-Actor     |
# | smuggler |      I-Plot      |     I-Actor     |
# |  george  | B-Character_Name |     I-Actor     |
# |   jung   | I-Character_Name |     I-Actor     |
# |   who    |        O         |        O        |
# |    is    |        O         |        O        |
# |  played  |        O         |        O        |
# |    by    |        O         |        O        |
# |  johnny  |     B-Actor      |     B-Actor     |
# |   depp   |     I-Actor      |     I-Actor     |
# +----------+------------------+-----------------+
# +----------+------------------+-----------------+
# | Sentence |    True Label    | Predicted Label |
# +----------+------------------+-----------------+
# |   what   |        O         |        O        |
# |    is    |        O         |        O        |
# |   that   |        O         |        O        |
# |  movie   |        O         |        O        |
# |  about   |        O         |        O        |
# |   the    |        O         |        O        |
# | american |      B-Plot      |        O        |
# | cocaine  |      I-Plot      |     B-Actor     |
# | smuggler |      I-Plot      |     I-Actor     |
# |  george  | B-Character_Name |     I-Actor     |
# |   jung   | I-Character_Name |     I-Actor     |
# |   who    |        O         |        O        |
# |    is    |        O         |        O        |
# |  played  |        O         |        O        |
# |    by    |        O         |        O        |
# |  johnny  |     B-Actor      |     B-Actor     |
# |   depp   |     I-Actor      |     I-Actor     |
# +----------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |     is     |        O         |        O        |
# |    that    |        O         |        O        |
# |   movie    |        O         |        O        |
# |  starring  |        O         |        O        |
# |  leonardo  |     B-Actor      |     B-Actor     |
# |     di     |     I-Actor      |     I-Actor     |
# |   caprio   |     I-Actor      |     I-Actor     |
# |     as     |        O         |        O        |
# |   howard   | B-Character_Name |      B-Plot     |
# |   hughes   | I-Character_Name |      I-Plot     |
# |    and     |        O         |      I-Plot     |
# | chronicles |      B-Plot      |      I-Plot     |
# |    his     |      I-Plot      |      I-Plot     |
# |    life    |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |     is     |        O         |        O        |
# |    that    |        O         |        O        |
# |   movie    |        O         |        O        |
# |  starring  |        O         |        O        |
# |  leonardo  |     B-Actor      |     B-Actor     |
# |     di     |     I-Actor      |     I-Actor     |
# |   caprio   |     I-Actor      |     I-Actor     |
# |     as     |        O         |        O        |
# |   howard   | B-Character_Name |      B-Plot     |
# |   hughes   | I-Character_Name |      I-Plot     |
# |    and     |        O         |      I-Plot     |
# | chronicles |      B-Plot      |      I-Plot     |
# |    his     |      I-Plot      |      I-Plot     |
# |    life    |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |     is     |        O         |        O        |
# |    that    |        O         |        O        |
# |   movie    |        O         |        O        |
# |    that    |        O         |        O        |
# |  details   |      B-Plot      |      B-Plot     |
# |    how     |      I-Plot      |      I-Plot     |
# |    mark    | B-Character_Name |      I-Plot     |
# | zuckerberg | I-Character_Name |      I-Plot     |
# |  created   |      B-Plot      |      I-Plot     |
# |  facebook  |      I-Plot      |      I-Plot     |
# |    and     |      I-Plot      |      I-Plot     |
# |  details   |      I-Plot      |      I-Plot     |
# |  facebook  |      I-Plot      |      I-Plot     |
# |     s      |      I-Plot      |      I-Plot     |
# |   early    |      I-Plot      |      I-Plot     |
# | inception  |      I-Plot      |      I-Plot     |
# |     at     |      I-Plot      |      I-Plot     |
# |  harvard   |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    what    |        O         |        O        |
# |     is     |        O         |        O        |
# |    that    |        O         |        O        |
# |   movie    |        O         |        O        |
# |    that    |        O         |        O        |
# |  details   |      B-Plot      |      B-Plot     |
# |    how     |      I-Plot      |      I-Plot     |
# |    mark    | B-Character_Name |      I-Plot     |
# | zuckerberg | I-Character_Name |      I-Plot     |
# |  created   |      B-Plot      |      I-Plot     |
# |  facebook  |      I-Plot      |      I-Plot     |
# |    and     |      I-Plot      |      I-Plot     |
# |  details   |      I-Plot      |      I-Plot     |
# |  facebook  |      I-Plot      |      I-Plot     |
# |     s      |      I-Plot      |      I-Plot     |
# |   early    |      I-Plot      |      I-Plot     |
# | inception  |      I-Plot      |      I-Plot     |
# |     at     |      I-Plot      |      I-Plot     |
# |  harvard   |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +---------------+------------------+-----------------+
# |    Sentence   |    True Label    | Predicted Label |
# +---------------+------------------+-----------------+
# |      what     |        O         |        O        |
# |       is      |        O         |        O        |
# |      that     |        O         |        O        |
# |      ron      |    B-Director    |    B-Director   |
# |     howard    |    I-Director    |    I-Director   |
# |    directed   |        O         |        O        |
# |     movie     |        O         |        O        |
# |     where     |        O         |        O        |
# |    russell    |     B-Actor      |     B-Actor     |
# |     crowe     |     I-Actor      |     I-Actor     |
# |     plays     |        O         |        O        |
# |      john     | B-Character_Name |      B-Plot     |
# |      nash     | I-Character_Name |      I-Plot     |
# |       a       |        O         |      I-Plot     |
# |      very     |      B-Plot      |      I-Plot     |
# |   brilliant   |      I-Plot      |      I-Plot     |
# |      but      |      I-Plot      |      I-Plot     |
# |    troubled   |      I-Plot      |      I-Plot     |
# | mathematician |      I-Plot      |      I-Plot     |
# +---------------+------------------+-----------------+
# +---------------+------------------+-----------------+
# |    Sentence   |    True Label    | Predicted Label |
# +---------------+------------------+-----------------+
# |      what     |        O         |        O        |
# |       is      |        O         |        O        |
# |      that     |        O         |        O        |
# |      ron      |    B-Director    |    B-Director   |
# |     howard    |    I-Director    |    I-Director   |
# |    directed   |        O         |        O        |
# |     movie     |        O         |        O        |
# |     where     |        O         |        O        |
# |    russell    |     B-Actor      |     B-Actor     |
# |     crowe     |     I-Actor      |     I-Actor     |
# |     plays     |        O         |        O        |
# |      john     | B-Character_Name |      B-Plot     |
# |      nash     | I-Character_Name |      I-Plot     |
# |       a       |        O         |      I-Plot     |
# |      very     |      B-Plot      |      I-Plot     |
# |   brilliant   |      I-Plot      |      I-Plot     |
# |      but      |      I-Plot      |      I-Plot     |
# |    troubled   |      I-Plot      |      I-Plot     |
# | mathematician |      I-Plot      |      I-Plot     |
# +---------------+------------------+-----------------+
# +-------------+------------+-----------------+
# |   Sentence  | True Label | Predicted Label |
# +-------------+------------+-----------------+
# |     what    |     O      |        O        |
# |      is     |     O      |        O        |
# |     that    |     O      |        O        |
# |    satire   |  B-Genre   |        O        |
# |    movie    |     O      |        O        |
# |     the     |     O      |        O        |
# |     1999    |   B-Year   |      B-Year     |
# |   american  |  B-Genre   |     B-Genre     |
# |    comedy   |  I-Genre   |     I-Genre     |
# |     film    |     O      |        O        |
# |    which    |     O      |        O        |
# |    became   |     O      |        O        |
# |      a      |     O      |        O        |
# |     cult    | B-Opinion  |     B-Genre     |
# |   classic   | I-Opinion  |     I-Genre     |
# |     and     |     O      |        O        |
# |   starring  |     O      |        O        |
# |     ron     |  B-Actor   |     B-Actor     |
# |  livingston |  I-Actor   |     I-Actor     |
# |      as     |   B-Plot   |        O        |
# |      a      |   I-Plot   |      B-Plot     |
# | disgruntled |   I-Plot   |      I-Plot     |
# |   employee  |   I-Plot   |      I-Plot     |
# +-------------+------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# |     is    |        O         |        O        |
# |    the    |        O         |        O        |
# |    1935   |      B-Year      |      B-Year     |
# |  american |     B-Genre      |     B-Genre     |
# |   comedy  |     I-Genre      |     I-Genre     |
# |    film   |        O         |        O        |
# |   opera   |      B-Plot      |     B-Actor     |
# |   singer  |      I-Plot      |     I-Actor     |
# |  riccardo | B-Character_Name |     I-Actor     |
# |   baroni  | I-Character_Name |     I-Actor     |
# |   wishes  |      B-Plot      |        O        |
# |     to    |      I-Plot      |        O        |
# |     be    |      I-Plot      |        O        |
# |    just   |      I-Plot      |        O        |
# |     as    |      I-Plot      |        O        |
# |    good   |      I-Plot      |        O        |
# |     as    |      I-Plot      |        O        |
# | lassparri | B-Character_Name |        O        |
# |    and    |      B-Plot      |        O        |
# |   hires   |      I-Plot      |      B-Plot     |
# |    his    |      I-Plot      |      I-Plot     |
# |    best   |      I-Plot      |      I-Plot     |
# |   friend  |      I-Plot      |      I-Plot     |
# |     to    |      I-Plot      |      I-Plot     |
# |     be    |      I-Plot      |      I-Plot     |
# |    his    |      I-Plot      |      I-Plot     |
# |  manager  |      I-Plot      |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |    what   |        O         |        O        |
# ...
# |  movie   |        O         |        O        |
# | featured |        O         |        O        |
# |  robert  |     B-Actor      |     B-Actor     |
# |  deniro  |     I-Actor      |     I-Actor     |
# | playing  |        O         |        O        |
# |    a     |        O         |      B-Plot     |
# |  young   |        O         |      I-Plot     |
# |   don    | B-Character_Name |      I-Plot     |
# | corleone | I-Character_Name |      I-Plot     |
# |    in    |        O         |      I-Plot     |
# |  sicily  |        O         |      I-Plot     |
# +----------+------------------+-----------------+
# +----------+------------------+-----------------+
# | Sentence |    True Label    | Predicted Label |
# +----------+------------------+-----------------+
# |  which   |        O         |        O        |
# | francis  |    B-Director    |    B-Director   |
# |   ford   |    I-Director    |    I-Director   |
# | coppola  |    I-Director    |    I-Director   |
# | directed |    I-Director    |        O        |
# |  movie   |        O         |        O        |
# | featured |        O         |        O        |
# |  robert  |     B-Actor      |     B-Actor     |
# |  deniro  |     I-Actor      |     I-Actor     |
# | playing  |        O         |        O        |
# |    a     |        O         |      B-Plot     |
# |  young   |        O         |      I-Plot     |
# |   don    | B-Character_Name |      I-Plot     |
# | corleone | I-Character_Name |      I-Plot     |
# |    in    |        O         |      I-Plot     |
# |  sicily  |        O         |      I-Plot     |
# +----------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |    which     |        O         |        O        |
# |    movie     |        O         |        O        |
# |   features   |        O         |        O        |
# |     the      |        O         |      B-Plot     |
# |    trials    |      B-Plot      |      I-Plot     |
# |     and      |      I-Plot      |      I-Plot     |
# | tribulations |      I-Plot      |      I-Plot     |
# |      of      |        O         |      I-Plot     |
# |     mark     | B-Character_Name |      I-Plot     |
# |  zuckerberg  | I-Character_Name |      I-Plot     |
# |   setting    |      B-Plot      |      I-Plot     |
# |      up      |      I-Plot      |      I-Plot     |
# |     his      |      I-Plot      |      I-Plot     |
# |   digital    |      I-Plot      |      I-Plot     |
# |    empire    |      I-Plot      |      I-Plot     |
# +--------------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |    which     |        O         |        O        |
# |    movie     |        O         |        O        |
# |   features   |        O         |        O        |
# |     the      |        O         |      B-Plot     |
# |    trials    |      B-Plot      |      I-Plot     |
# |     and      |      I-Plot      |      I-Plot     |
# | tribulations |      I-Plot      |      I-Plot     |
# |      of      |        O         |      I-Plot     |
# |     mark     | B-Character_Name |      I-Plot     |
# |  zuckerberg  | I-Character_Name |      I-Plot     |
# |   setting    |      B-Plot      |      I-Plot     |
# |      up      |      I-Plot      |      I-Plot     |
# |     his      |      I-Plot      |      I-Plot     |
# |   digital    |      I-Plot      |      I-Plot     |
# |    empire    |      I-Plot      |      I-Plot     |
# +--------------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |   which   |        O         |        O        |
# |  musical  |     B-Genre      |     B-Genre     |
# |    set    |        O         |        O        |
# |     in    |        O         |        O        |
# |    1950   |      B-Year      |      B-Year     |
# |     s     |      I-Year      |      I-Year     |
# |    new    |        O         |        O        |
# |    york   |        O         |        O        |
# |  features |      B-Plot      |        O        |
# |    two    |      I-Plot      |      B-Plot     |
# |   rival   |      I-Plot      |      I-Plot     |
# |   gangs   |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |   sharks  |      I-Plot      |      I-Plot     |
# |    and    |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |    jets   |      I-Plot      |      I-Plot     |
# |  playing  |      I-Plot      |      I-Plot     |
# |    out    |      I-Plot      |      I-Plot     |
# |     a     |      I-Plot      |      I-Plot     |
# |   modern  |      I-Plot      |      I-Plot     |
# |    day    |      I-Plot      |      I-Plot     |
# | retelling |  B-Relationship  |      I-Plot     |
# |     of    |  I-Relationship  |      I-Plot     |
# |   romeo   | B-Character_Name |      I-Plot     |
# |    and    | I-Character_Name |      I-Plot     |
# |   juliet  | I-Character_Name |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |   which   |        O         |        O        |
# |  musical  |     B-Genre      |     B-Genre     |
# |    set    |        O         |        O        |
# |     in    |        O         |        O        |
# |    1950   |      B-Year      |      B-Year     |
# |     s     |      I-Year      |      I-Year     |
# |    new    |        O         |        O        |
# |    york   |        O         |        O        |
# |  features |      B-Plot      |        O        |
# |    two    |      I-Plot      |      B-Plot     |
# |   rival   |      I-Plot      |      I-Plot     |
# |   gangs   |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |   sharks  |      I-Plot      |      I-Plot     |
# |    and    |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |    jets   |      I-Plot      |      I-Plot     |
# |  playing  |      I-Plot      |      I-Plot     |
# |    out    |      I-Plot      |      I-Plot     |
# |     a     |      I-Plot      |      I-Plot     |
# |   modern  |      I-Plot      |      I-Plot     |
# |    day    |      I-Plot      |      I-Plot     |
# | retelling |  B-Relationship  |      I-Plot     |
# |     of    |  I-Relationship  |      I-Plot     |
# |   romeo   | B-Character_Name |      I-Plot     |
# |    and    | I-Character_Name |      I-Plot     |
# |   juliet  | I-Character_Name |      I-Plot     |
# +-----------+------------------+-----------------+
# +-----------+------------------+-----------------+
# |  Sentence |    True Label    | Predicted Label |
# +-----------+------------------+-----------------+
# |   which   |        O         |        O        |
# |  musical  |     B-Genre      |     B-Genre     |
# |    set    |        O         |        O        |
# |     in    |        O         |        O        |
# |    1950   |      B-Year      |      B-Year     |
# |     s     |      I-Year      |      I-Year     |
# |    new    |        O         |        O        |
# |    york   |        O         |        O        |
# |  features |      B-Plot      |        O        |
# |    two    |      I-Plot      |      B-Plot     |
# |   rival   |      I-Plot      |      I-Plot     |
# |   gangs   |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |   sharks  |      I-Plot      |      I-Plot     |
# |    and    |      I-Plot      |      I-Plot     |
# |    the    |      I-Plot      |      I-Plot     |
# |    jets   |      I-Plot      |      I-Plot     |
# |  playing  |      I-Plot      |      I-Plot     |
# |    out    |      I-Plot      |      I-Plot     |
# |     a     |      I-Plot      |      I-Plot     |
# |   modern  |      I-Plot      |      I-Plot     |
# |    day    |      I-Plot      |      I-Plot     |
# | retelling |  B-Relationship  |      I-Plot     |
# |     of    |  I-Relationship  |      I-Plot     |
# |   romeo   | B-Character_Name |      I-Plot     |
# |    and    | I-Character_Name |      I-Plot     |
# |   juliet  | I-Character_Name |      I-Plot     |
# +-----------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |     whos     |        O         |      B-Plot     |
# |    brain     |        O         |      I-Plot     |
# |     did      |        O         |      I-Plot     |
# |      dr      | B-Character_Name |      I-Plot     |
# | frankenstein | I-Character_Name |      I-Plot     |
# |     put      |      B-Plot      |      I-Plot     |
# |      in      |      I-Plot      |      I-Plot     |
# |     the      |      I-Plot      |      I-Plot     |
# |     jar      |      I-Plot      |      I-Plot     |
# +--------------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |     whos     |        O         |      B-Plot     |
# |    brain     |        O         |      I-Plot     |
# |     did      |        O         |      I-Plot     |
# |      dr      | B-Character_Name |      I-Plot     |
# | frankenstein | I-Character_Name |      I-Plot     |
# |     put      |      B-Plot      |      I-Plot     |
# |      in      |      I-Plot      |      I-Plot     |
# |     the      |      I-Plot      |      I-Plot     |
# |     jar      |      I-Plot      |      I-Plot     |
# +--------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    will    |     B-Actor      |     B-Actor     |
# |   forte    |     I-Actor      |     I-Actor     |
# |   plays    |        O         |        O        |
# |     an     |        O         |      B-Plot     |
# |     ex     |      B-Plot      |      I-Plot     |
# |  special   |      I-Plot      |      I-Plot     |
# | operative  |      I-Plot      |      I-Plot     |
# |   trying   |      I-Plot      |      I-Plot     |
# |     to     |      I-Plot      |      I-Plot     |
# |    stop    |      I-Plot      |      I-Plot     |
# |    his     |      I-Plot      |      I-Plot     |
# |    arch    |      I-Plot      |      I-Plot     |
# |   enemy    |      I-Plot      |      I-Plot     |
# |   dieter   | B-Character_Name |      I-Plot     |
# |    von     | I-Character_Name |      I-Plot     |
# |   cunth    | I-Character_Name |      I-Plot     |
# |    from    |      B-Plot      |      I-Plot     |
# | destroying |      I-Plot      |      I-Plot     |
# | washington |      I-Plot      |      I-Plot     |
# |     d      |      I-Plot      |      I-Plot     |
# |     c      |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    will    |     B-Actor      |     B-Actor     |
# |   forte    |     I-Actor      |     I-Actor     |
# |   plays    |        O         |        O        |
# |     an     |        O         |      B-Plot     |
# |     ex     |      B-Plot      |      I-Plot     |
# |  special   |      I-Plot      |      I-Plot     |
# | operative  |      I-Plot      |      I-Plot     |
# |   trying   |      I-Plot      |      I-Plot     |
# |     to     |      I-Plot      |      I-Plot     |
# |    stop    |      I-Plot      |      I-Plot     |
# |    his     |      I-Plot      |      I-Plot     |
# |    arch    |      I-Plot      |      I-Plot     |
# |   enemy    |      I-Plot      |      I-Plot     |
# |   dieter   | B-Character_Name |      I-Plot     |
# |    von     | I-Character_Name |      I-Plot     |
# |   cunth    | I-Character_Name |      I-Plot     |
# |    from    |      B-Plot      |      I-Plot     |
# | destroying |      I-Plot      |      I-Plot     |
# | washington |      I-Plot      |      I-Plot     |
# |     d      |      I-Plot      |      I-Plot     |
# |     c      |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +------------+------------------+-----------------+
# |  Sentence  |    True Label    | Predicted Label |
# +------------+------------------+-----------------+
# |    will    |     B-Actor      |     B-Actor     |
# |   forte    |     I-Actor      |     I-Actor     |
# |   plays    |        O         |        O        |
# |     an     |        O         |      B-Plot     |
# |     ex     |      B-Plot      |      I-Plot     |
# |  special   |      I-Plot      |      I-Plot     |
# | operative  |      I-Plot      |      I-Plot     |
# |   trying   |      I-Plot      |      I-Plot     |
# |     to     |      I-Plot      |      I-Plot     |
# |    stop    |      I-Plot      |      I-Plot     |
# |    his     |      I-Plot      |      I-Plot     |
# |    arch    |      I-Plot      |      I-Plot     |
# |   enemy    |      I-Plot      |      I-Plot     |
# |   dieter   | B-Character_Name |      I-Plot     |
# |    von     | I-Character_Name |      I-Plot     |
# |   cunth    | I-Character_Name |      I-Plot     |
# |    from    |      B-Plot      |      I-Plot     |
# | destroying |      I-Plot      |      I-Plot     |
# | washington |      I-Plot      |      I-Plot     |
# |     d      |      I-Plot      |      I-Plot     |
# |     c      |      I-Plot      |      I-Plot     |
# +------------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |    young     |      B-Plot      |      B-Plot     |
# |   traveler   |      I-Plot      |      I-Plot     |
# |    allan     | B-Character_Name |      I-Plot     |
# |     gray     | I-Character_Name |      I-Plot     |
# |  discovers   |      B-Plot      |      I-Plot     |
# |   evidence   |      I-Plot      |      I-Plot     |
# |      of      |      I-Plot      |      I-Plot     |
# |     the      |      I-Plot      |      I-Plot     |
# | supernatural |      I-Plot      |      I-Plot     |
# |      in      |        O         |        O        |
# |     this     |        O         |        O        |
# |    black     |        O         |        O        |
# |     and      |        O         |        O        |
# |    white     |        O         |        O        |
# |     1932     |      B-Year      |      B-Year     |
# |    horror    |     B-Genre      |     B-Genre     |
# |     film     |        O         |        O        |
# +--------------+------------------+-----------------+
# +--------------+------------------+-----------------+
# |   Sentence   |    True Label    | Predicted Label |
# +--------------+------------------+-----------------+
# |    young     |      B-Plot      |      B-Plot     |
# |   traveler   |      I-Plot      |      I-Plot     |
# |    allan     | B-Character_Name |      I-Plot     |
# |     gray     | I-Character_Name |      I-Plot     |
# |  discovers   |      B-Plot      |      I-Plot     |
# |   evidence   |      I-Plot      |      I-Plot     |
# |      of      |      I-Plot      |      I-Plot     |
# |     the      |      I-Plot      |      I-Plot     |
# | supernatural |      I-Plot      |      I-Plot     |
# |      in      |        O         |        O        |
# |     this     |        O         |        O        |
# |    black     |        O         |        O        |
# |     and      |        O         |        O        |
# |    white     |        O         |        O        |
# |     1932     |      B-Year      |      B-Year     |
# |    horror    |     B-Genre      |     B-Genre     |
# |     film     |        O         |        O        |
# +--------------+------------------+-----------------+

# %%
false_negative_sentences = np.array(false_negative_sentences)
false_negative_sentences.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (459,)

# %%
new_false_negative_sentences = np.unique(false_negative_sentences)
new_false_negative_sentences.shape
# Out:
# (201,)

# %%
print('False Negative Sentences:')
new_false_negative_sentences
# Out:
# False Negative Sentences:
# array([list(['one', 'of', 'the', 'most', 'memorable', 'scenes', 'from', 'this', 'film', 'involve', 'a', 'boy', 'riding', 'his', 'bike', 'through', 'the', 'sky']),
#        list(['orson', 'wells', 'psychological', 'profile', 'of', 'an', 'eccentric', 'billionaire', 'has', 'been', 'voted', 'the', 'greatest', 'movie', 'of', 'all', 'time', 'by', 'some']),
#        list(['paul', 'newman', 'stars', 'as', 'rocky', 'graziano', 'in', 'this', 'biographical', 'drama', 'about', 'a', 'criminal', 'turned', 'boxer']),
#        list(['penny', 'chenery', 'tweedy', 'and', 'colleagues', 'guide', 'her', 'long', 'shot', 'but', 'precocious', 'stallion', 'to', 'set', 'in', '1973', 'the', 'unbeaten', 'record', 'for', 'winning', 'the', 'triple', 'crown', 'is', 'the', 'plot', 'of', 'this', '2010', 'family', 'drama']),
#        list(['perseus', 'mortal', 'son', 'of', 'zeus', 'battles', 'the', 'minions', 'of', 'the', 'underworld', 'to', 'stop', 'them', 'from', 'conquering', 'the', 'earth', 'and', 'the', 'heavens', 'in', 'this', '2010', 'action', 'adventure', 'fantasy']),
#        list(['peter', 'jackson', 'directed', 'this', 'smash', 'hit', 'starring', 'jack', 'black', 'as', 'a', '1930', 's', 'film', 'maker', 'on', 'a', 'mission', 'to', 'make', 'an', 'unforgettable', 'nature', 'documentary', 'who', 'gets', 'more', 'than', 'he', 'bargained', 'for']),
#        list(['red', 'riding', 'hood', 'is', 'training', 'in', 'the', 'group', 'of', 'sister', 'hoods', 'when', 'she', 'and', 'the', 'wolf', 'are', 'called', 'to', 'examine', 'the', 'sudden', 'mysterious', 'disappearance', 'of', 'hansel', 'and', 'gretel', 'in', 'this', 'animated', 'feature']),
#        list(['reese', 'witherspoon', 'won', 'an', 'oscar', 'for', 'best', 'actress', 'for', 'playing', 'the', 'wife', 'of', 'johnny', 'cash', 'in', 'this', 'film']),
#        list(['richard', 'gere', 'took', 'tap', 'dance', 'lessons', 'for', 'three', 'months', 'to', 'prepare', 'for', 'his', 'role', 'as', 'the', 'criminal', 'defense', 'attorney', 'billy', 'flynn', 'in', 'this', '2002', 'musical']),
#        list(['robert', 'duvall', 'is', 'bank', 'robber', 'outlaw', 'jesse', 'james', 'in', 'this', 'movie', 'about', 'a', 'bank', 'robbery', 'gone', 'wrong']),
#        list(['robert', 'redford', 'directed', 'ralph', 'fiennes', 'as', 'charles', 'van', 'doren', 'in', 'this', '1994', 'film', 'set', 'in', 'the', '1950', 's']),
#        list(['rufus', 't', 'firefly', 'is', 'named', 'president', 'dictator', 'of', 'bankrupt', 'freedonia', 'and', 'declares', 'war', 'on', 'neighboring', 'sylvania', 'over', 'the', 'love', 'of', 'wealthy', 'mrs', 'teasdale', 'is', 'the', 'plot', 'of', 'this', 'classic', 'comedy', 'starring', 'all', 'three', 'of', 'the', 'marx', 'brothers']),
#        list(['sarah', 'jessica', 'parker', 'is', 'kate', 'reddy', 'a', 'finance', 'executive', 'who', 'is', 'the', 'breadwinner', 'for', 'her', 'husband', 'and', 'two', 'kids', 'in', 'this', '2011', 'movie', 'based', 'on', 'the', 'novel', 'by', 'allison', 'pearson']),
#        list(['sean', 'anderson', 'partners', 'with', 'his', 'mom', 's', 'husband', 'on', 'a', 'mission', 'to', 'find', 'his', 'grandfather', 'who', 'is', 'thought', 'to', 'be', 'missing', 'in', 'a', 'mythical', 'location', 'in', 'this', '2012', 'adventure', 'starring', 'dwayne', 'johnson']),
#        list(['stacy', 'keach', 'and', 'james', 'keach', 'play', 'frank', 'and', 'jesse', 'james', 'in', 'this', '1980', 'western', 'about', 'the', 'outlaws', 'and', 'their', 'gang']),
#        list(['stopped', 'they', 'must', 'be', 'on', 'this', 'all', 'depends', 'only', 'a', 'fully', 'trained', 'jedi', 'knight', 'with', 'the', 'force', 'as', 'his', 'ally', 'will', 'conquer', 'vader', 'in', 'this', '1980', 'george', 'lucas', 'sequel']),
#        list(['the', 'debut', 'movie', 'of', 'the', 'famous', 'director', 'kevin', 'smith', 'featuring', 'his', 'breakout', 'characters', 'jay', 'and', 'silent', 'bob']),
#        list(['the', 'last', 'part', 'of', 'a', 'vampire', 'love', 'story', 'between', 'bella', 'and', 'edward']),
#        list(['the', 'movie', 'i', 'm', 'thinking', 'of', 'has', 'a', 'rabbit', 'named', 'thumper', 'and', 'a', 'faun', 'that', 'grows', 'to', 'a', 'female', 'deer', 'who', 'the', 'movie', 'is', 'named', 'after']),
#        list(['the', 'movie', 'where', 'marty', 'mcfly', 'and', 'doc', 'brown', 'go', 'back', 'in', 'time', 'and', 'have', 'to', 'get', 'marty', 's', 'mom', 'to', 'marry', 'his', 'dad']),
#        list(['the', 'movie', 'where', 'two', 'of', 'the', 'characters', 'have', 'dogs', 'with', 'country', 'singers', 'names', 'one', 'was', 'willie', 'nelson', 'and', 'the', 'other', 'dolly', 'parton']),
#        list(['the', 'second', 'movie', 'in', 'a', 'popular', 'fantasy', 'trilogy', 'this', 'film', 'introduces', 'a', 'character', 'named', 'treebeard']),
#        list(['the', 'story', 'of', 'avant', 'garde', 'comedian', 'andy', 'kaufman', 'and', 'his', 'notorious', 'antics', 'on', 'the', 'stage']),
#        list(['the', 'story', 'of', 't', 'e', 'lawrence', 'a', 'flamboyant', 'and', 'controversial', 'british', 'military', 'figure', 'and', 'his', 'conflicted', 'loyalties', 'during', 'his', 'world', 'war', 'i', 'service', 'in', 'the', 'middle', 'east', 'staring', 'peter', 'o', 'toole']),
#        list(['this', '1948', 'american', 'film', 'written', 'by', 'john', 'huston', 'starred', 'humphrey', 'bogart', 'as', 'the', 'character', 'dobbs']),
#        list(['this', '1962', 'classic', 'drama', 'features', 'a', 'little', 'girl', 'named', 'scout', 'who', 'lived', 'in', 'the', 'depression', 'era', 'south']),
#        list(['this', '1990', 's', 'animated', 'feature', 'taught', 'us', 'the', 'song', 'hakuna', 'matata', 'which', 'championed', 'a', 'down', 'to', 'earth', 'problem', 'free', 'philosophy']),
#        list(['this', '1997', 'smash', 'hit', 'is', 'loosely', 'based', 'on', 'a', 'famous', 'cruise', 'ship', 'that', 'sank', 'in', '1912']),
#        list(['this', '2010', 'american', 'supernatural', 'horror', 'film', 'starred', 'sprague', 'grayden', 'as', 'kristi', 'and', 'molly', 'ephraim', 'as', 'ali']),
#        list(['this', '2011', 'superhero', 'movie', 'stars', 'seth', 'rogen', 'as', 'an', 'unlikely', 'hero', 'who', 'starts', 'a', 'crime', 'fighting', 'career', 'with', 'the', 'help', 'of', 'his', 'father', 's', 'assistant', 'kato']),
#        list(['this', '2012', 'movie', 'is', 'eye', 'candy', 'for', 'the', 'ladies', 'this', 'movie', 'is', 'set', 'in', 'the', 'world', 'of', 'the', 'male', 'stripper']),
#        list(['this', '942', 'american', 'biographical', 'musical', 'film', 'about', 'george', 'm', 'cohan', 'known', 'as', 'the', 'man', 'who', 'owns', 'broadway']),
#        list(['this', 'action', 'film', 'features', 'aaaron', 'johnson', 'as', 'a', 'high', 'school', 'student', 'turned', 'vigilante', 'nicholas', 'cage', 'and', 'chloe', 'moretz', 'are', 'also', 'featured', 'as', 'big', 'daddy', 'and', 'hit', 'girl']),
#        list(['this', 'action', 'movie', 'follows', 'the', 'actions', 'of', 'a', 'team', 'of', 'super', 'heroes', 'including', 'magneto']),
#        list(['this', 'action', 'packed', 'futuristic', 'thriller', 'about', 'time', 'travel', 'stars', 'bruce', 'willis', 'and', 'joseph', 'gordon', 'levitt', 'as', 'a', '20', 'something', 'willis']),
#        list(['this', 'alfred', 'hitchcock', 'film', 'includes', 'a', 'motel', 'manager', 'norman', 'bates', 'in', 'an', 'infamous', 'shower', 'scene']),
#        list(['this', 'american', 'film', 'features', 'single', 'serving', 'friends', 'power', 'animals', 'project', 'mayhem', 'and', 'jack', 's', 'raging', 'bile', 'duct']),
#        list(['this', 'animated', 'sequel', 'features', 'ben', 'stiller', 'as', 'alex', 'the', 'lion', 'and', 'his', 'continuing', 'adventures', 'in', 'africa']),
#        list(['this', 'black', 'and', 'white', 'comedy', 'directed', 'by', 'mel', 'brooks', 'stars', 'gene', 'wilder', 'and', 'peter', 'boyle', 'and', 'features', 'the', 'classic', 'song', 'puttin', 'on', 'the', 'ritz']),
#        list(['this', 'children', 's', 'movie', 'is', 'about', 'a', 'young', 'boy', 'named', 'greg', 'heffley', 'who', 'enters', 'the', 'sixth', 'grade', 'and', 'tries', 'to', 'make', 'it', 'through', 'the', 'school', 'year', 'unscathed']),
#        list(['this', 'classic', '1938', 'warner', 'bros', 'gangster', 'picture', 'stars', 'james', 'cagney', 'pat', 'o', 'brien', 'humphrey', 'bogart', 'and', 'the', 'dead', 'end', 'kids']),
#        list(['this', 'computer', 'animated', 'comedy', 'features', 'the', 'voice', 'of', 'steve', 'carrell', 'as', 'the', 'villainous', 'but', 'likeable', 'gru']),
#        list(['this', 'disney', 'film', 'was', 'a', 'long', 'awaited', 'sequel', 'to', 'the', 'science', 'fiction', 'thriller', 'starring', 'jeff', 'bridges', 'in', 'the', 'world', 'of', 'living', 'computer', 'programs']),
#        list(['this', 'horror', 'movie', 'features', 'one', 'of', 'the', 'most', 'famous', 'villains', 'in', 'the', 'genre', 'who', 'kills', 'victims', 'in', 'their', 'nightmares', 'with', 'his', 'signature', 'bladed', 'hands']),
#        list(['this', 'horror', 'movie', 'takes', 'place', 'at', 'a', 'summer', 'camp', 'and', 'spawned', 'a', 'series', 'of', 'movies', 'about', 'a', 'gruesome', 'killed', 'named', 'jason']),
#        list(['this', 'is', 'one', 'of', 'the', 'most', 'famous', 'kung', 'fu', 'movies', 'of', 'all', 'time', 'about', 'two', 'warriors', 'in', 'pursuit', 'of', 'a', 'stolen', 'sword']),
#        list(['this', 'james', 'bond', 'film', 'starring', 'daniel', 'craig', 'features', 'a', 'theme', 'song', 'by', 'adele']),
#        list(['this', 'marvel', 'superhero', 'film', 'assembles', 'captain', 'america', 'iron', 'man', 'thor', 'and', 'the', 'hulk', 'to', 'battle', 'an', 'evil', 'being', 'named', 'loki']),
#        list(['this', 'modern', 'batman', 'film', 'pits', 'batman', 'against', 'bane', 'and', 'catwoman', 'in', 'a', 'besieged', 'new', 'york', 'city']),
#        list(['this', 'modern', 'crime', 'film', 'features', 'robert', 'downey', 'jr', 'as', 'a', 'bumbling', 'crook', 'caught', 'up', 'in', 'a', 'mystery', 'alongside', 'val', 'kilmer', 'as', 'private', 'investigator', 'gay', 'perry']),
#        list(['this', 'modern', 'twist', 'on', 'the', 'superhero', 'genre', 'is', 'a', 'found', 'footage', 'movie', 'about', 'a', 'group', 'of', 'teenagers', 'who', 'accidentally', 'gain', 'superpowers']),
#        list(['this', 'movie', 'about', 'gold', 'prospectors', 'in', 'mexico', 'is', 'often', 'considered', 'one', 'of', 'humphry', 'bogart', 's', 'best', 'works']),
#        list(['this', 'movie', 'features', 'scientifically', 'inaccurate', 'but', 'scary', 'and', 'intense', 'recreations', 'of', 'a', 'past', 'extinct', 'species']),
#        list(['this', 'movie', 'is', 'about', 'a', 'lone', 'avatar', 'who', 'has', 'the', 'power', 'to', 'manipulate', 'all', 'four', 'elements', 'he', 'teams', 'up', 'with', 'katara', 'who', 'is', 'a', 'waterbender']),
#        list(['this', 'movie', 'stars', 'cary', 'elwes', 'as', 'westley', 'or', 'could', 'it', 'be', 'the', 'dread', 'pirate', 'roberts']),
#        list(['this', 'stop', 'motion', 'animated', 'feature', 'directed', 'by', 'henry', 'selick', 'shows', 'the', 'adventures', 'of', 'jack', 'skellington', 'who', 'tries', 'to', 'spread', 'the', 'magic', 'of', 'christmas']),
#        list(['this', 'surreal', 'romp', 'from', '1967', 'stars', 'the', 'beatles', 'and', 'features', 'some', 'of', 'their', 'famous', 'hit', 'songs']),
#        list(['tim', 'burton', 'used', 'stop', 'motion', 'animation', 'to', 'tell', 'the', 'story', 'of', 'jack', 'skellington', 'in', 'what', '1993', 'disney', 'movie']),
#        list(['two', 'good', 'friends', 'mike', 'and', 'sully', 'team', 'up', 'to', 'scare', 'as', 'many', 'children', 'as', 'possible', 'but', 'encounter', 'something', 'that', 'no', 'one', 'has', 'ever', 'encountered', 'before', 'in', 'this', 'film']),
#        list(['werner', 'herzog', 'wrote', 'and', 'directed', 'this', 'biographical', 'documentary', 'about', 'timothy', 'treadwell', 'and', 'amie', 'huguenard', 'bear', 'activists', 'who', 'were', 'killed', 'while', 'living', 'among', 'them', 'in', 'alaska']),
#        list(['what', '1930', 'ernst', 'lubitsch', 'film', 'starring', 'jeanette', 'macdonald', 'took', 'place', 'in', 'a', 'famous', 'european', 'gambling', 'city', 'and', 'featured', 'the', 'song', 'beyond', 'the', 'blue', 'horizon']),
#        list(['what', '1934', 'jean', 'vigo', 'film', 'called', 'one', 'of', 'the', 'best', 'of', 'all', 'time', 'starred', 'michel', 'simon', 'as', 'p', 're', 'jules']),
#        list(['what', '1942', 'movie', 'garnered', 'a', 'best', 'music', 'original', 'song', 'oscar', 'win', 'to', 'irving', 'berlin', 'for', 'his', 'song', 'white', 'christmas']),
#        list(['what', '1946', 'frank', 'capra', 'movie', 'centers', 'around', 'the', 'life', 'of', 'george', 'bailey', 'in', 'bedford', 'falls']),
#        list(['what', '1957', 'king', 'vidor', 'movie', 'starring', 'audrey', 'hepburn', 'and', 'henry', 'fonda', 'centered', 'around', 'napoleon', 's', 'tumultuous', 'relations', 'with', 'russia']),
#        list(['what', '1958', 'alfred', 'hitchcock', 'film', 'based', 'on', 'a', 'novel', 'by', 'boileau', 'narcejac', 'starred', 'james', 'stewart', 'as', 'detective', 'john', 'scottie', 'ferguson']),
#        list(['what', '1965', 'cartoon', 'is', 'a', 'timeless', 'classic', 'starring', 'the', 'lovable', 'charlie', 'brown', 'and', 'his', 'dog', 'snoopy']),
#        list(['what', '1965', 'musical', 'based', 'on', 'a', 'rogers', 'and', 'hammerstein', 'musical', 'of', 'the', 'same', 'name', 'features', 'the', 'von', 'trapp', 'family', 'singers']),
#        list(['what', '1974', 'stop', 'motion', 'animated', 'tv', 'special', 'features', 'kris', 'kringle', 'running', 'into', 'the', 'heater', 'miser']),
#        list(['what', '1981', 'biopic', 'starred', 'faye', 'dunaway', 'and', 'depicted', 'the', 'abusive', 'adoptive', 'upbringing', 'of', 'christina', 'crawford']),
#        list(['what', '1983', 'harold', 'ramis', 'comedy', 'finds', 'the', 'griswold', 'family', 'cross', 'country', 'driving', 'to', 'theme', 'park', 'walley', 'world']),
#        list(['what', '1987', 'brian', 'depalma', 'film', 'features', 'kevin', 'costner', 'as', 'federal', 'agent', 'eliot', 'ness', 'out', 'to', 'stop', 'al', 'capone']),
#        list(['what', '1987', 'movie', 'featured', 'an', 'evil', 'prince', 'his', 'six', 'fingered', 'henchman', 'and', 'a', 'swordsman', 'hero', 'named', 'inigo', 'montoya']),
#        list(['what', '1989', 'comedy', 'features', 'chevy', 'chase', 'as', 'clark', 'griswold', 'and', 'beverly', 'd', 'angelo', 'as', 'his', 'wife', 'ellen']),
#        list(['what', '1990', 'crime', 'drama', 'had', 'robert', 'de', 'niro', 'playing', 'a', 'mob', 'type', 'gangster', 'named', 'james', 'conway']),
#        list(['what', '1990', 'martin', 'scorsese', 'biopic', 'centers', 'around', 'henry', 'hill', 'and', 'his', 'friends', 'as', 'they', 'work', 'their', 'way', 'up', 'through', 'the', 'mob', 'hierarchy']),
#        list(['what', '1991', 'movie', 'featured', 'jessica', 'tandy', 'in', 'her', 'best', 'supporting', 'actress', 'oscar', 'winning', 'role', 'of', 'ninny', 'threadgoode']),
#        list(['what', '1991', 'musical', 'comedy', 'centers', 'around', 'characters', 'janet', 'and', 'brad', 'as', 'they', 'become', 'game', 'show', 'contestants']),
#        list(['what', '1993', 'drama', 'film', 'directed', 'by', 'steven', 'speilberg', 'featured', 'liam', 'neeson', 'as', 'schindler', 'in', 'nazi', 'germany']),
#        list(['what', '1995', 'chick', 'flick', 'starred', 'clint', 'eastwood', 'as', 'photographer', 'robert', 'kincaid', 'and', 'meryl', 'streep', 'as', 'his', 'short', 'lived', 'love', 'interest']),
#        list(['what', '1996', 'family', 'movie', 'depicts', 'paul', 'hogan', 'as', 'sandy', 'ricks', 'and', 'elijah', 'wood', 'as', 'his', 'troubled', 'nephew']),
#        list(['what', '1999', 'movie', 'found', 'haley', 'joel', 'osment', 'as', 'cole', 'sear', 'a', 'boy', 'who', 'communicated', 'with', 'spirits']),
#        list(['what', '2005', 'ron', 'howard', 'biopic', 'tells', 'the', 'story', 'of', 'james', 'braddock', 'a', 'washed', 'up', 'boxer', 'who', 'came', 'back', 'to', 'become', 'a', 'champion']),
#        list(['what', '2007', 'biopic', 'is', 'about', 'the', 'story', 'of', 'jean', 'dominique', 'bauby', 'and', 'his', 'trouble', 'with', 'locked', 'in', 'syndrome']),
#        list(['what', '2008', 'japanese', 'animated', 'fantasy', 'film', 'written', 'and', 'directed', 'by', 'hayao', 'miyazaki', 'is', 'about', 'brunhilde', 'the', 'fish', 'girl']),
#        list(['what', '2009', 'rob', 'zombie', 'horror', 'movie', 'centers', 'around', 'character', 'laurie', 'strode', 'and', 'her', 'brother', 'michael']),
#        list(['what', '2010', 'american', 'supernatural', 'film', 'featured', 'a', 'group', 'of', 'strangers', 'including', 'arch', 'angel', 'micheal', 'fighting', 'for', 'the', 'fate', 'of', 'humanity']),
#        list(['what', '2010', 'drama', 'centered', 'on', 'the', 'efforts', 'of', 'joan', 'and', 'aileen', 'crowley', 'to', 'find', 'a', 'researcher', 'who', 'might', 'develop', 'a', 'cure', 'for', 'their', 'children', 's', 'rare', 'genetic', 'disorder']),
#        list(['what', '2010', 'movie', 'finds', 'superhero', 'alter', 'ego', 'tony', 'stark', 'once', 'again', 'battling', 'evil', 'and', 'saving', 'the', 'day']),
#        list(['what', '2010', 'romantic', 'comedy', 'features', 'anne', 'hathaway', 'as', 'maggie', 'murdock', 'and', 'jake', 'gyllenhaal', 'as', 'jamie', 'randall']),
#        list(['what', '2010', 'sequel', 'does', 'michael', 'douglas', 'reprise', 'his', 'role', 'as', 'gordon', 'gekko', 'the', 'infamous', 'broker', 'who', 'coined', 'greed', 'is', 'good']),
#        list(['what', '2010', 'thriller', 'set', 'in', '1954', 'finds', 'u', 's', 'marshal', 'teddy', 'daniels', 'investigating', 'the', 'disappearance', 'of', 'a', 'murderess', 'who', 'escaped', 'a', 'mental', 'hospital']),
#        list(['what', '2011', 'crime', 'movie', 'features', 'ryan', 'phillippe', 'as', 'louis', 'roulet', 'a', 'man', 'with', 'a', 'foolproof', 'plan', 'to', 'beat', 'the', 'system']),
#        list(['what', '2011', 'movie', 'stars', 'bradley', 'cooper', 'as', 'writer', 'eddie', 'morra', 'who', 'discovers', 'a', 'top', 'secret', 'drug']),
#        list(['what', '2011', 'thriller', 'based', 'on', 'a', 'fairy', 'tail', 'features', 'a', 'young', 'woman', 'named', 'valerie', 'and', 'her', 'love', 'peter']),
#        list(['what', '2011', 'thriller', 'centered', 'around', 'character', 'dominic', 'toretto', 'and', 'his', 'crew', 'of', 'street', 'racers', 'planning', 'a', 'massive', 'heist']),
#        list(['what', '2012', 'film', 'by', 'peter', 'jackson', 'goes', 'back', 'to', 'the', 'original', 'story', 'of', 'bilbo', 'told', 'by', 'j', 'r', 'r', 'tolkien']),
#        list(['what', '2012', 'superhero', 'film', 'starred', 'anne', 'hathaway', 'as', 'cat', 'woman', 'and', 'tom', 'hardy', 'as', 'bane']),
#        list(['what', '2012', 'thriller', 'finds', 'retired', 'cia', 'operative', 'bryan', 'mills', 'played', 'by', 'liam', 'neeson', 'and', 'his', 'wife', 'played', 'by', 'famke', 'janssen', 'taken', 'hostage']),
#        list(['what', 'action', 'adventure', 'movie', 'has', 'been', 'remade', 'multiple', 'times', 'and', 'features', 'clark', 'kent', 'and', 'his', 'alter', 'ego', 'the', 'man', 'of', 'steel']),
#        list(['what', 'action', 'film', 'directed', 'by', 'tarsem', 'singh', 'starred', 'henry', 'cavill', 'as', 'theseus', 'and', 'freida', 'pinto', 'as', 'phaedra']),
#        list(['what', 'action', 'movie', 'featuring', 'clint', 'eastwood', 'as', 'a', 'renegade', 'cop', 'harry', 'callahand', 'making', 'his', 'own', 'rules', 'delivering', 'justice', 'through', 'this', '44', 'magnum', 'revolver']),
#        list(['what', 'animated', 'classic', 'christmas', 'movie', 'features', 'snoopy', 'and', 'a', 'really', 'pathetic', 'beat', 'up', 'looking', 'christmas', 'tree']),
#        list(['what', 'animated', 'movie', 'tells', 'the', 'story', 'of', 'simba', 'who', 'returns', 'to', 'his', 'homeland', 'to', 'reclaim', 'the', 'crown', 'from', 'his', 'uncle', 'scar']),
#        list(['what', 'black', 'and', 'white', 'japanese', 'classic', 'epic', 'features', 'a', 'story', 'about', '7', 'warriors', 'facing', 'unimaginable', 'odds']),
#        list(['what', 'blockbuster', 'film', 'stars', 'liam', 'nieson', 'in', 'his', 'heart', 'stopping', 'thriller', 'which', 'takes', 'place', 'in', 'a', 'snowy', 'wasteland']),
#        list(['what', 'boxing', 'centric', 'movie', 'inspired', 'the', 'character', 'tag', 'line', 'of', 'italian', 'stallion', 'and', 'inspired', 'legions', 'of', 'fans', 'to', 'workout', 'to', 'the', 'song', 'eye', 'of', 'the', 'tiger']),
#        list(['what', 'classic', 'disney', 'film', 'takes', 'place', 'in', 'africa', 'and', 'includes', 'musical', 'pieces', 'such', 'as', 'hakkuna', 'mattata']),
#        list(['what', 'classic', 'thriller', 'about', 'an', 'enormous', 'killer', 'shark', 'spawned', 'one', 'of', 'the', 'most', 'popular', 'movie', 'themes', 'of', 'all', 'time']),
#        list(['what', 'film', 'directed', 'by', 'david', 'fincher', 'tells', 'of', 'mark', 'zuckerberg', 's', 'rise', 'to', 'power', 'and', 'the', 'creation', 'of', 'facebook']),
#        list(['what', 'film', 'introduced', 'the', 'knives', 'for', 'fingers', 'character', 'of', 'freddy', 'krueger', 'that', 'haunts', 'the', 'dreams', 'of', 'teenagers', 'eventually', 'killing', 'them']),
#        list(['what', 'intense', 'gritty', '2012', 'cop', 'drama', 'focuses', 'on', 'the', 'day', 'to', 'day', 'of', 'two', 'los', 'angelos', 'police', 'officers']),
#        list(['what', 'is', 'that', '2012', 'movie', 'that', 'stars', 'liam', 'neeson', 'as', 'zeus', 'and', 'ralph', 'fiennes', 'as', 'hades']),
#        list(['what', 'is', 'that', 'comedy', 'film', 'starring', 'jon', 'heder', 'in', 'a', 'breakout', 'role', 'as', 'an', 'awkward', 'teen', 'and', 'details', 'his', 'adventures', 'in', 'high', 'school']),
#        list(['what', 'is', 'that', 'movie', '2012', 'biographical', 'film', 'co', 'directed', 'by', 'curtis', 'hanson', 'about', 'the', 'life', 'of', 'jay', 'moriarty']),
#        list(['what', 'is', 'that', 'movie', 'about', 'the', 'american', 'cocaine', 'smuggler', 'george', 'jung', 'who', 'is', 'played', 'by', 'johnny', 'depp']),
#        list(['what', 'is', 'that', 'movie', 'starring', 'leonardo', 'di', 'caprio', 'as', 'howard', 'hughes', 'and', 'chronicles', 'his', 'life']),
#        list(['what', 'is', 'that', 'movie', 'that', 'details', 'how', 'mark', 'zuckerberg', 'created', 'facebook', 'and', 'details', 'facebook', 's', 'early', 'inception', 'at', 'harvard']),
#        list(['what', 'is', 'that', 'ron', 'howard', 'directed', 'movie', 'where', 'russell', 'crowe', 'plays', 'john', 'nash', 'a', 'very', 'brilliant', 'but', 'troubled', 'mathematician']),
#        list(['what', 'is', 'that', 'satire', 'movie', 'the', '1999', 'american', 'comedy', 'film', 'which', 'became', 'a', 'cult', 'classic', 'and', 'starring', 'ron', 'livingston', 'as', 'a', 'disgruntled', 'employee']),
#        list(['what', 'is', 'the', '1935', 'american', 'comedy', 'film', 'opera', 'singer', 'riccardo', 'baroni', 'wishes', 'to', 'be', 'just', 'as', 'good', 'as', 'lassparri', 'and', 'hires', 'his', 'best', 'friend', 'to', 'be', 'his', 'manager']),
#        list(['what', 'is', 'the', '1942', 'musical', 'film', 'staring', 'bing', 'crosby', 'and', 'fred', 'astaire', 'with', 'music', 'by', 'irving', 'berlin']),
#        list(['what', 'is', 'the', '1950', 'american', 'drama', 'film', 'which', 'stars', 'bette', 'davis', 'as', 'margo', 'channing', 'an', 'aging', 'broadway', 'actress']),
#        list(['what', 'is', 'the', '1991', 'disney', 'animated', 'movie', 'that', 'featured', 'angela', 'lansbury', 'as', 'the', 'voice', 'of', 'a', 'teapot']),
#        list(['what', 'is', 'the', '1995', 'american', 'medieval', 'movie', 'starring', 'richard', 'gere', 'as', 'lancelot', 'and', 'sean', 'connery', 'as', 'king', 'arthur']),
#        list(['what', 'is', 'the', '2004', 'horror', 'film', 'about', 'victims', 'chained', 'in', 'a', 'bathroom', 'and', 'given', 'rules', 'to', 'survive', 'by', 'a', 'serial', 'killer', 'named', 'jigsaw']),
#        list(['what', 'is', 'the', '2010', 'american', 'fantasy', 'adventure', 'movie', 'based', 'on', 'the', 'greek', 'story', 'of', 'perseus', 'starring', 'sam', 'worthington']),
#        list(['what', 'is', 'the', '2010', 'american', 'sci', 'fi', 'film', 'released', 'by', 'walt', 'disney', 'pictures', 'starring', 'jeff', 'bridges', 'and', 'had', 'a', 'soundtrack', 'by', 'french', 'band', 'daft', 'punk']),
#        list(['what', 'is', 'the', '2010', 'american', 'western', 'remake', 'by', 'the', 'coen', 'brothers', 'that', 'starred', 'jeff', 'bridges', 'as', 'us', 'marshall', 'reuben', 'rooster', 'cogburn']),
#        list(['what', 'is', 'the', '2011', 'master', 'piece', 'with', 'adam', 'sandler', 'and', 'directed', 'by', 'dennis', 'dugan', 'and', 'involves', 'hawaii']),
#        list(['what', 'is', 'the', '2012', 'blockbuster', 'hit', 'that', 'featured', 'a', 'team', 'of', 'superheros', 'that', 'banded', 'together', 'to', 'fight', 'a', 'supervillain']),
#        list(['what', 'is', 'the', 'animated', 'movie', 'from', 'disney', 'that', 'took', 'a', 'fresh', 'adventurous', 'take', 'on', 'the', 'fairy', 'tale', 'classic', 'rapunzel']),
#        list(['what', 'is', 'the', 'classic', 'cartoon', 'christmas', 'movie', 'based', 'on', 'a', 'comic', 'strip', 'about', 'a', 'boy', 'his', 'friends', 'his', 'dog', 'and', 'a', 'bird', 'named', 'woodstock']),
#        list(['what', 'is', 'the', 'cult', 'classic', 'movie', 'with', 'keanu', 'reeves', 'in', 'which', 'he', 'is', 'called', 'the', 'one']),
#        list(['what', 'is', 'the', 'disney', 'film', 'featuring', 'a', 'princess', 'aurora', 'who', 'is', 'put', 'under', 'a', 'sleeping', 'spell', 'until', 'awakened', 'by', 'a', 'kiss']),
#        list(['what', 'is', 'the', 'family', 'comedy', 'that', 'is', 'really', 'good', 'to', 'watch', 'at', 'christmas', 'time', 'that', 'had', 'the', 'newest', 'version', 'released', 'in', '2006', 'and', 'stars', 'john', 'goodman']),
#        list(['what', 'is', 'the', 'famous', 'cult', 'classic', 'movie', 'about', 'the', 'girl', 'whose', 'first', 'love', 'returns', 'in', 'the', 'form', 'of', 'a', 'pirate', 'to', 'kidnap', 'her', 'from', 'the', 'man', 'she', 'is', 'about', 'to', 'marry']),
#        list(['what', 'is', 'the', 'famous', 'cult', 'classic', 'movie', 'with', 'samuel', 'jackson', 'and', 'john', 'travolta', 'dances', 'with', 'uma', 'thurman', 'in', 'a', 'well', 'known', 'scene']),
#        list(['what', 'is', 'the', 'first', 'movie', 'in', 'a', 'series', 'starring', 'arnold', 'schwarzenegger', 'as', 'a', 'cyborg', 'sent', 'back', 'in', 'time', 'to', 'kill', 'john', 'connor', 'the', 'leader', 'of', 'a', 'future', 'resistance', 'against', 'the', 'machines']),
#        list(['what', 'is', 'the', 'fred', 'astaire', 'and', 'judy', 'garland', 'movie', 'with', 'the', 'song', 'about', 'a', 'bonnet']),
#        list(['what', 'is', 'the', 'marvel', 'comic', 'movie', 'about', 'the', 'god', 'of', 'thunder', 'who', 'comes', 'to', 'earth', 'and', 'fights', 'his', 'brother', 'loki']),
#        list(['what', 'is', 'the', 'most', 'recent', 'bond', 'film', 'called', 'with', 'the', 'new', 'bond', 'played', 'by', 'daniel', 'craig']),
#        list(['what', 'is', 'the', 'movie', 'based', 'on', 'another', 'jrr', 'tolkien', 'book', 'but', 'not', 'the', 'lord', 'of', 'the', 'rings', 'trilogy']),
#        list(['what', 'is', 'the', 'movie', 'starring', 'russell', 'crowe', 'as', 'the', 'brilliant', 'mathematician', 'john', 'nash', 'and', 'directed', 'by', 'ron', 'howard']),
#        list(['what', 'is', 'the', 'movie', 'with', 'liam', 'neeson', 'as', 'zeus', 'and', 'sam', 'worthington', 'as', 'perseus', 'battling', 'the', 'forces', 'of', 'the', 'underworld']),
#        list(['what', 'is', 'the', 'movie', 'with', 'the', 'rock', 'and', 'that', 'guy', 'who', 'plays', 'peeta', 'mellark', 'on', 'hunger', 'games']),
#        list(['what', 'is', 'the', 'name', 'of', 'that', 'superhero', 'movie', 'where', 'clark', 'kent', 'is', 'played', 'by', 'christopher', 'reeve', 'and', 'lex', 'luthor', 'is', 'played', 'by', 'gene', 'hackman']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', '80', 's', 'movie', 'about', 'mozart', 'that', 'had', 'a', 'hit', 'song', 'with', 'the', 'same', 'name']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', 'disney', 'movie', 'where', 'princess', 'jazmine', 'goes', 'on', 'a', 'magic', 'carpet', 'ride', 'with', 'the', 'lease', 'character']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', 'first', 'film', 'in', 'the', 'series', 'that', 'features', 'the', 'infamous', 'jason', 'voorhees']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', 'master', 'piece', 'moved', 'directed', 'by', 'francis', 'lawrence', 'and', 'has', 'robert', 'pattinson', 'in', 'it']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', 'movie', 'in', 'which', 'christina', 'aguilera', 'pink', 'mya', 'and', 'lil', 'kim', 'collaborated', 'for', 'the', 'lead', 'music', 'track', 'of', 'the', 'film']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', 'movie', 'in', 'which', 'gandalf', 'and', 'aragorn', 'lead', 'an', 'army', 'against', 'sauron', 's', 'army', 'so', 'frodo', 'and', 'same', 'can', 'get', 'to', 'mount', 'doom']),
#        list(['what', 'is', 'the', 'name', 'of', 'the', 'movie', 'where', 'ash', 'must', 'battle', 'an', 'army', 'of', 'the', 'dead', 'and', 'retrieve', 'the', 'necronomicon']),
#        list(['what', 'is', 'the', 'pg', '13', 'movie', 'that', 'was', 'well', 'known', 'for', 'having', 'a', 'curse', 'word', 'in', 'its', 'name']),
#        list(['what', 'is', 'the', 'reboot', 'of', 'a', 'popular', 'marvel', 'movie', 'franchise', 'with', 'james', 'mcavoy', 'as', 'a', 'young', 'professor', 'x', 'and', 'michael', 'fassbender', 'as', 'a', 'young', 'magneto']),
#        list(['what', 'is', 'the', 'sequel', 'to', 'the', 'science', 'fiction', 'movie', 'with', 'sigourney', 'weaver', 'returning', 'as', 'ellen', 'ripley']),
#        list(['what', 'is', 'the', 'super', 'popular', 'war', 'movie', 'with', 'tom', 'hanks', 'and', 'matt', 'damon', 'in', 'which', 'three', 'of', 'four', 'brothers', 'die', 'in', 'the', 'war']),
#        list(['what', 'is', 'the', 'third', 'harry', 'potter', 'movie', 'where', 'dementors', 'are', 'on', 'the', 'move', 'searching', 'for', 'the', 'escapee', 'from', 'prison', 'who', 'ends', 'up', 'in', 'the', 'end', 'being', 'harry', 's', 'godfather']),
#        list(['what', 'is', 'the', 'updated', 'version', 'of', 'romeo', 'and', 'juliet', 'where', 'a', 'man', 'and', 'woman', 'from', 'two', 'feuding', 'gangs', 'in', 'new', 'york', 'fall', 'in', 'love', 'and', 'have', 'to', 'deal', 'with', 'the', 'problems', 'it', 'causes']),
#        list(['what', 'is', 'the', 'very', 'famous', 'clint', 'eastwood', 'movie', 'about', 'two', 'bounty', 'hunters', 'who', 'try', 'to', 'beat', 'a', 'third', 'before', 'they', 'find', 'buried', 'treasure']),
#        list(['what', 'is', 'this', '2009', 'film', 'based', 'on', 'a', 'true', 'story', 'that', 'stars', 'jim', 'carrey', 'as', 'steven', 'jay', 'russell']),
#        list(['what', 'is', 'this', 'classic', 'horror', 'flick', 'that', 'stars', 'the', 'toy', 'chuckie']),
#        list(['what', 'is', 'this', 'mind', 'bending', 'film', 'directed', 'by', 'christopher', 'nolan', 'and', 'starring', 'leonardo', 'dicaprio', 'that', 'takes', 'place', 'inside', 'the', 'mind']),
#        list(['what', 'is', 'this', 'star', 'studded', 'action', 'sequel', 'that', 'teams', 'up', 'slyvester', 'stallone', 'with', 'bruce', 'willis', 'and', 'arnold', 'schwarzenegger']),
#        list(['what', 'is', 'this', 'timeless', 'classic', 'that', 'stars', 'tom', 'hanks', 'as', 'a', 'prison', 'guard']),
#        list(['what', 'jerry', 'zuker', 'film', 'starred', 'richard', 'gere', 'as', 'lancelot', 'and', 'sean', 'connery', 'as', 'king', 'arthur']),
#        list(['what', 'movie', 'based', 'on', 'the', 'book', 'by', 'charles', 'dickens', 'follows', 'the', 'story', 'of', 'ebenezer', 'scrooge', 'as', 'he', 'is', 'cold', 'and', 'eventually', 'sees', 'the', 'error', 'of', 'his', 'ways', 'and', 'reforms', 'himself']),
#        list(['what', 'movie', 'is', 'about', 'the', 'now', 'fallen', 'angel', 'gabriel', 'coming', 'to', 'save', 'mankind', 'from', 'god', 's', 'wraith']),
#        list(['what', 'movie', 'released', 'in', '2012', 'covers', 'the', 'story', 'of', 'a', 'hobbit', 'by', 'the', 'name', 'of', 'bilbo', 'baggins', 'and', 'his', 'dwarf', 'friends', 'seeking', 'to', 'reclaim', 'his', 'home']),
#        list(['what', 'movie', 'remake', 'has', 'jeff', 'bridges', 'filling', 'in', 'for', 'john', 'wayne', 'as', 'the', 'famous', 'one', 'eyed', 'rooster', 'cogburn']),
#        list(['what', 'movie', 'starring', 'sasha', 'baron', 'cohen', 'features', 'another', 'character', 'from', 'his', 'infamous', 'and', 'highly', 'controversial', 'show', 'da', 'ali', 'g', 'show']),
#        list(['what', 'pixar', 'animated', 'film', 'features', 'a', 'talking', 'dog', 'named', 'dug']),
#        list(['what', 'popular', 'animated', 'addition', 'to', 'the', 'story', 'about', 'america', 's', 'favorite', 'ogre', 'included', 'rumpelstiltskin', 'an', 'evil', 'magical', 'contract', 'writer']),
#        list(['what', 's', 'that', 'awesome', 'funny', 'movie', 'with', 'jennifer', 'anniston', 'the', 'guys', 'start', 'a', 'pyramid', 'scheme', 'and', 'almost', 'get', 'fired', 'one', 'man', 'is', 'named', 'michael', 'bolton']),
#        list(['what', 's', 'that', 'stupid', 'overrated', 'movie', 'about', 'interplanetary', 'fighting', 'there', 'are', 'jedis', 'and', 'one', 'of', 'the', 'main', 'characters', 'is', 'harrison', 'ford']),
#        list(['what', 's', 'that', 'super', 'slow', 'paced', 'movie', 'with', 'ryan', 'gostling', 'where', 'nobody', 'says', 'anything', 'the', 'whole', 'time']),
#        list(['what', 's', 'the', 'camp', 'comedy', 'musical', 'classic', 'that', 'features', 'susan', 'sarandon', 's', 'first', 'role', 'and', 'the', 'song', 'time', 'warp']),
#        list(['what', 's', 'the', 'name', 'of', 'the', 'first', 'pixar', 'movie', 'where', 'tim', 'allen', 'and', 'tom', 'hanks', 'voice', 'woody', 'and', 'buzz', 'lightyear']),
#        list(['what', 's', 'the', 'name', 'of', 'the', 'remake', 'of', 'moe', 'larry', 'and', 'curly', 'where', 'larry', 'david', 'plays', 'a', 'nun']),
#        list(['what', 's', 'the', 'one', 'with', 'that', 'guy', 'from', 'the', 'matrix', 'and', 'the', 'girl', 'from', 'titanic', 'where', 'they', 'try', 'to', 'save', 'the', 'world']),
#        list(['what', 's', 'the', 'title', 'of', 'wes', 'craven', 's', 'horror', 'film', 'where', 'serial', 'killer', 'freddy', 'krueger', 'kills', 'people', 'in', 'their', 'dreams']),
#        list(['what', 'sequel', 'to', 'an', 'animated', 'box', 'office', 'smash', 'hit', 'involves', 'a', 'colorful', 'cast', 'of', 'animals', 'that', 'are', 'masters', 'in', 'martial', 'arts']),
#        list(['what', 'stanley', 'kubric', 'masterpiece', 'is', 'hailed', 'as', 'one', 'of', 'the', 'greatest', 'science', 'fiction', 'films', 'ever', 'made']),
#        list(['what', 'stunning', 'action', 'film', 'featured', 'bane', 'as', 'a', 'charismatic', 'super', 'villain', 'trying', 'to', 'take', 'over', 'gothem']),
#        list(['what', 'timeless', 'classic', 'starring', 'clint', 'eastwood', 'does', 'he', 'carry', 'a', 'large', 'firearm', 'as', 'a', 'police', 'officer']),
#        list(['what', 'was', 'that', 'film', 'about', 'a', 'speech', 'therapist', 'helping', 'george', 'vi', 'learn', 'to', 'speak', 'without', 'a', 'stutter']),
#        list(['what', 'was', 'that', 'film', 'that', 'had', 'queequeg', 'and', 'ishmael', 'in', 'it', 'where', 'they', 'chased', 'a', 'whale']),
#        list(['what', 'was', 'the', 'name', 'of', 'the', '1975', 'mega', 'hit', 'thriller', 'in', 'which', 'a', 'great', 'white', 'shark', 'menaced', 'and', 'munched', 'on', 'citizens', 'of', 'the', 'beach', 'resort', 'town', 'of', 'amity', 'during', 'july', '4', 'weekend']),
#        list(['what', 'was', 'the', 'title', 'of', 'the', 'cult', 'favorite', 'monster', 'musical', 'spoof', 'starring', 'tim', 'curry', 'as', 'a', 'transvestite', 'alien', 'from', 'the', 'planet', 'transylvania', 'menacing', 'a', 'straight', 'laced', 'young', 'couple']),
#        list(['when', 'a', 'mad', 'man', 'calling', 'himself', 'the', 'scorpio', 'killer', 'menaces', 'the', 'city', 'tough', 'as', 'nails', 'san', 'francisco', 'police', 'inspector', 'harry', 'callahan', 'is', 'assigned', 'to', 'track', 'down', 'and', 'ferret', 'out', 'the', 'crazed', 'psychopath']),
#        list(['which', 'comedy', 'classic', 'featuring', 'billy', 'crystal', 'and', 'andre', 'the', 'giant', 'tells', 'the', 'story', 'of', 'prince', 'wesley', 'as', 'he', 'tries', 'to', 'capture', 'the', 'affections', 'and', 'save', 'the', 'life', 'of', 'princess', 'buttercup']),
#        list(['which', 'ensemble', 'film', 'follows', 'two', 'hitmen', 'to', 'return', 'a', 'briefcase', 'to', 'their', 'boss', 'marsellus', 'wallace']),
#        list(['which', 'film', 'starred', 'vanessa', 'hudgens', 'in', 'a', 'modern', 'day', 'retelling', 'of', 'beauty', 'and', 'the', 'beast']),
#        list(['which', 'film', 'stars', 'macaulay', 'culkin', 'as', 'kevin', 'mccallister', 'defending', 'his', 'home', 'from', 'a', 'pair', 'of', 'robbers']),
#        list(['which', 'francis', 'ford', 'coppola', 'directed', 'movie', 'featured', 'robert', 'deniro', 'playing', 'a', 'young', 'don', 'corleone', 'in', 'sicily']),
#        list(['which', 'movie', 'features', 'the', 'trials', 'and', 'tribulations', 'of', 'mark', 'zuckerberg', 'setting', 'up', 'his', 'digital', 'empire']),
#        list(['which', 'musical', 'set', 'in', '1950', 's', 'new', 'york', 'features', 'two', 'rival', 'gangs', 'the', 'sharks', 'and', 'the', 'jets', 'playing', 'out', 'a', 'modern', 'day', 'retelling', 'of', 'romeo', 'and', 'juliet']),
#        list(['whos', 'brain', 'did', 'dr', 'frankenstein', 'put', 'in', 'the', 'jar']),
#        list(['will', 'forte', 'plays', 'an', 'ex', 'special', 'operative', 'trying', 'to', 'stop', 'his', 'arch', 'enemy', 'dieter', 'von', 'cunth', 'from', 'destroying', 'washington', 'd', 'c']),
#        list(['young', 'traveler', 'allan', 'gray', 'discovers', 'evidence', 'of', 'the', 'supernatural', 'in', 'this', 'black', 'and', 'white', '1932', 'horror', 'film'])],
#       dtype=object)

# %% [markdown]
# # 4. Incorporating POS tags as features (15 marks)
# Use the CRF part-of-speech (POS) tagger as shown below to add POS tags to the words in the training data. Do this by altering the `preProcess` function above. Note the CRF tagger only takes strings as input so you will have to concatenate the word and POS tag together (with a special symbol, e.g. @), and you will also have to then split on this special symbol in the feature extraction function `get_features` to get the word and POS tag - modify that function so it uses the POS tag in addition to the word (currently using the word only is achieved by `feature_list.append("WORD_" + token)`. Re-run the training and testing code on your 80%/20% training/dev split from question 1 and record the results from the classification report as text in this file for comparison of the accuracy metrics against not using POS tags- try to see any improvemements across the classes.

# %%
x_train2=x_train

# %%
posttagger = CRFTagger()
posttagger.set_model_file("crf_pos.tagger")

# %%
def preProcess(addtagging):
  taggedwords=[]
  for sent3 in addtagging:
    words=[s[0] for s in sent3]
    tagged = posttagger.tag(words)
    addwords=[]
    for i in range(len(sent3)):

      addwords.append(tagged[i][0]+'@'+tagged[i][1])
    taggedwords.append(addwords)
  return taggedwords

# %%
processed = preProcess(x_train2)

# %%
for sent3 in range(len(x_train2)):
  for s in range(len(x_train2[sent3])):
    x_train2[sent3][s] = list(x_train2[sent3][s])

# %%
for sent3 in range(len(x_train2)):
  for s in range(len(x_train2[sent3])):
    x_train2[sent3][s][0]=processed[sent3][s]

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits

def get_features(tokens, idx):
    token = tokens[idx]
    token = token.split('@')
    feature_list = []

    if not token[0]:
        return feature_list
    
    # Capitalization
    if token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, token[0]) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in token[0]):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 3
    if len(token[0]) > 1:
        feature_list.append("SUF_" + token[0][-1:])
    if len(token[0]) > 2:
        feature_list.append("SUF_" + token[0][-2:])
    if len(token[0]) > 3:
        feature_list.append("SUF_" + token[0][-3:])

    feature_list.append("WORD_" + token[0])
    feature_list.append("POS_" + token[1])

        
    # print(feature_list)
    return feature_list

# %%
TAGGER_PATH = "crf_nlu.tagger"
ct = CRFTagger(feature_func=get_features)

print("training tagger...")
ct.train(x_train2, TAGGER_PATH)
print("done")
# Out:
# training tagger...
# done

# %%
x_test2 = x_test

# %%
processed2 = preProcess(x_test2)

# %%
for sent in range(len(x_test2)):
  for s in range(len(x_test2[sent])):
    x_test2[sent][s] = list(x_test2[sent][s])

# %%
for sent in range(len(x_test2)):
  for s in range(len(x_test2[sent])):
    x_test2[sent][s][0]=processed2[sent][s]

# %%
print("testing tagger...")
preds = []
x20 = []
for sent in x_test2:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    x20.extend(sent_true)
print("done")
# Out:
# testing tagger...
# done

# %%
print(classification_report(x20, preds))
print(precision_recall_fscore_support(x20, preds, average='macro'))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                   precision    recall  f1-score   support
#
#          B-Actor       0.86      0.89      0.87      1231
#          B-Award       0.78      0.61      0.69        75
# B-Character_Name       0.56      0.13      0.21       212
#       B-Director       0.85      0.69      0.76       472
#          B-Genre       0.86      0.78      0.82       805
#        B-Opinion       0.51      0.26      0.34       160
#         B-Origin       0.53      0.42      0.47       159
#           B-Plot       0.49      0.46      0.48      1221
#          B-Quote       0.57      0.17      0.26        24
#   B-Relationship       0.84      0.50      0.62       125
#     B-Soundtrack       0.00      0.00      0.00        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.88      0.88      0.88      1731
#          I-Award       0.79      0.79      0.79       202
# I-Character_Name       0.53      0.15      0.24       165
#       I-Director       0.86      0.68      0.76       456
#          I-Genre       0.79      0.75      0.77       576
#        I-Opinion       0.09      0.10      0.09        84
#         I-Origin       0.64      0.70      0.67       729
#           I-Plot       0.84      0.94      0.89     11448
#          I-Quote       0.59      0.19      0.28       176
#   I-Relationship       0.57      0.42      0.48       240
#     I-Soundtrack       0.00      0.00      0.00        41
#           I-Year       0.77      0.82      0.79        33
#                O       0.86      0.83      0.85     10223
#
#         accuracy                           0.83     31304
#        macro avg       0.64      0.52      0.56     31304
#     weighted avg       0.82      0.83      0.82     31304
#
# (0.6421432192190477, 0.5249941877713012, 0.559508696573959, None)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
#     precision    recall  f1-score   support
#
#          B-Actor       0.86      0.89      0.87      1231
#          B-Award       0.78      0.61      0.69        75
#     B-Character_Name   0.56      0.13      0.21       212
#       B-Director       0.85      0.69      0.76       472
#          B-Genre       0.86      0.78      0.82       805
#        B-Opinion       0.51      0.26      0.34       160
#         B-Origin       0.53      0.42      0.47       159
#           B-Plot       0.49      0.46      0.48      1221
#          B-Quote       0.57      0.17      0.26        24
#     B-Relationship     0.84      0.50      0.62       125
#     B-Soundtrack       0.00      0.00      0.00        13
#           B-Year       0.97      0.99      0.98       703
#          I-Actor       0.88      0.88      0.88      1731
#          I-Award       0.79      0.79      0.79       202
#     I-Character_Name   0.53      0.15      0.24       165
#       I-Director       0.86      0.68      0.76       456
#          I-Genre       0.79      0.75      0.77       576
#        I-Opinion       0.09      0.10      0.09        84
#         I-Origin       0.64      0.70      0.67       729
#           I-Plot       0.84      0.94      0.89     11448
#          I-Quote       0.59      0.19      0.28       176
#     I-Relationship     0.57      0.42      0.48       240
#     I-Soundtrack       0.00      0.00      0.00        41
#           I-Year       0.77      0.82      0.79        33
#                O       0.86      0.83      0.85     10223
#
#         accuracy                           0.83     31304
#        macro avg       0.64      0.52      0.56     31304
#     weighted avg       0.82      0.83      0.82     31304
#
#     (0.6421432192190477, 0.5249941877713012, 0.559508696573959, None)

# %% [markdown]
# # 5. Feature experimentation and other optimization for optimal macro average (30 marks).
# Experiment with different features by further adjusting the `get_features` function, and modifying it to get the best results in terms of `macro average f-score` (i.e. average f-score across all classes) on your 20% development data. Iteratively try different functions, briefly describe the method and record the results in the classification report format and make sure you describe this in your report.
#
# Feature tips: You could try more suffixes/prefixes of the current word than those currently extracted, you could use windows of the next and previous tokens (of different sizes, e.g. the previous/next N words/tags). As you try different feature functions, use the techniques you used in Q2 and Q3 to see the kind of errors you are getting for lower performing classes, in addition to the confusion matrix over classes.
#
# Model tips: After your feature engineering, for even better performance you could try optimizing the hyperparameters by adjusting the `training_opt` dictionary values, experimenting with changing the minimum document frequency, c1 and c2 regularization parameters for https://www.nltk.org/api/nltk.tag.crf.html#nltk.tag.crf.CRFTagger.__init__ e.g. changing the initialization to make the minimum feature frequency 2 (rather than the default 1) would be:
#
# `ct = CRFTagger(feature_func=get_features, training_opt={"feature.minfreq":2})`
#
# Leave the `get_features` functions in the state you used to get the highest `macro average f-score` on your 20% development set, then re-train the model on ALL the training data and print the classification report for the original test data (i.e. from the test file `trivia10k13train.bio.txt`) as your final piece of code.

# %%
_pattern = re.compile(r"\d")  # to recognize numbers/digits

def get_features2(tokens, idx):
    token = tokens[idx]
    token = token.split('@')
    feature_list = []

    if not token[0]:
        return feature_list
    
    # Capitalization
    if token[0].isupper():
        feature_list.append("CAPITALIZATION")

    # Number
    if re.search(_pattern, token[0]) is not None:
        feature_list.append("HAS_NUM")

    # Punctuation
    punc_cat = set(["Pc", "Pd", "Ps", "Pe", "Pi", "Pf", "Po"])
    if all(unicodedata.category(x) in punc_cat for x in token[0]):
        feature_list.append("PUNCTUATION")

    # Suffix up to length 6
    if len(token[0]) > 1:
        feature_list.append("SUF_" + token[0][-1:])
    if len(token[0]) > 2:
        feature_list.append("SUF_" + token[0][-2:])
    if len(token[0]) > 3:
        feature_list.append("SUF_" + token[0][-3:])
    if len(token[0]) > 4:
        feature_list.append("SUF_" + token[0][-4:])
    if len(token[0]) > 5:
        feature_list.append("SUF_" + token[0][-5:])
    if len(token[0]) > 6:
        feature_list.append("SUF_" + token[0][-6:])

    # Prefix up to length 6
    if len(token[0]) > 1:
        feature_list.append("PRE_" + token[0][:-1])
    if len(token[0]) > 2:
        feature_list.append("PRE_" + token[0][:-2])
    if len(token[0]) > 3:
        feature_list.append("PRE_" + token[0][:-3])
    if len(token[0]) > 4:
        feature_list.append("PRE_" + token[0][:-4])
    if len(token[0]) > 5:
        feature_list.append("PRE_" + token[0][:-5])
    if len(token[0]) > 6:
        feature_list.append("PRE_" + token[0][:-6])

    feature_list.append("WORD_" + token[0])
    feature_list.append("POS_" + token[1])

    # Previous word
    if idx == 0:
      print()
    else:
      feature_list.append("PREV_WORD_" + tokens[idx-1].split('@')[0])
    
    # Next word
    if idx == len(tokens)-1:
      print()
    else:
      feature_list.append("NEXT_WORD_" + tokens[idx+1].split('@')[0])
      
    # print(feature_list)
    return feature_list

# %%
TAGGER_PATH = "crf_nlu.tagger"
ct = CRFTagger(feature_func=get_features2, training_opt={"feature.minfreq":2})

print("training tagger...")
ct.train(x_train2, TAGGER_PATH)
print("done")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done

# %%
print("testing tagger...")
preds = []
x20 = []
for sent in x_test2:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    x20.extend(sent_true)
# Out:
# testing tagger...

# %%
print(classification_report(x20, preds))
print(precision_recall_fscore_support(x20, preds, average='macro'))
# Out:
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.93      1231
#          B-Award       0.78      0.68      0.73        75
# B-Character_Name       0.70      0.38      0.49       212
#       B-Director       0.89      0.77      0.83       472
#          B-Genre       0.89      0.85      0.87       805
#        B-Opinion       0.62      0.38      0.47       160
#         B-Origin       0.59      0.50      0.54       159
#           B-Plot       0.49      0.45      0.47      1221
#          B-Quote       0.62      0.21      0.31        24
#   B-Relationship       0.80      0.54      0.64       125
#     B-Soundtrack       0.75      0.23      0.35        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.94      0.93      1731
#          I-Award       0.80      0.78      0.79       202
# I-Character_Name       0.67      0.37      0.48       165
#       I-Director       0.90      0.77      0.83       456
#          I-Genre       0.83      0.77      0.80       576
#        I-Opinion       0.26      0.20      0.23        84
#         I-Origin       0.73      0.72      0.72       729
#           I-Plot       0.87      0.93      0.90     11448
#          I-Quote       0.71      0.26      0.38       176
#   I-Relationship       0.70      0.48      0.57       240
#     I-Soundtrack       1.00      0.17      0.29        41
#           I-Year       0.78      0.76      0.77        33
#                O       0.86      0.86      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.76      0.60      0.65     31304
#     weighted avg       0.85      0.85      0.85     31304
#
# (0.7632226795753958, 0.5967917536965791, 0.646755016002689, None)

# %% [markdown]
#                   precision    recall  f1-score   support
#
#          B-Actor       0.92      0.93      0.93      1231
#          B-Award       0.78      0.68      0.73        75
#     B-Character_Name   0.70      0.38      0.49       212
#       B-Director       0.89      0.77      0.83       472
#          B-Genre       0.89      0.85      0.87       805
#        B-Opinion       0.62      0.38      0.47       160
#         B-Origin       0.59      0.50      0.54       159
#           B-Plot       0.49      0.45      0.47      1221
#          B-Quote       0.62      0.21      0.31        24
#     B-Relationship     0.80      0.54      0.64       125
#     B-Soundtrack       0.75      0.23      0.35        13
#           B-Year       0.98      0.99      0.98       703
#          I-Actor       0.93      0.94      0.93      1731
#          I-Award       0.80      0.78      0.79       202
#     I-Character_Name   0.67      0.37      0.48       165
#       I-Director       0.90      0.77      0.83       456
#          I-Genre       0.83      0.77      0.80       576
#        I-Opinion       0.26      0.20      0.23        84
#         I-Origin       0.73      0.72      0.72       729
#           I-Plot       0.87      0.93      0.90     11448
#          I-Quote       0.71      0.26      0.38       176
#     I-Relationship     0.70      0.48      0.57       240
#     I-Soundtrack       1.00      0.17      0.29        41
#           I-Year       0.78      0.76      0.77        33
#                O       0.86      0.86      0.86     10223
#
#         accuracy                           0.85     31304
#        macro avg       0.76      0.60      0.65     31304
#     weighted avg       0.85      0.85      0.85     31304
#
#     (0.7632226795753958, 0.5967917536965791, 0.646755016002689, None)

# %%
def confusion_matrix_heatmap(x20, preds):
    """Function to plot a confusion matrix"""
    labels = list(set(x20))   # get the labels in the y_test
    # print(labels)
    cm = confusion_matrix(x20, preds, labels = labels)
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):
            text = ax.text(j, i, cm[i, j],
                           ha="center", va="center", color="w")

    plt.xlabel('Predicted')
    plt.ylabel('True')
    #fig.tight_layout()
    # fix for mpl bug that cuts off top/bottom of seaborn viz:
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    plt.show() # ta-da!

# %%
confusion_matrix_heatmap(x20, preds)

# %%
# Final results on original test data, using all training data, with best settings from dev set:

# prepare the test data:
raw_train_data = get_raw_data_from_bio_file("trivia10k13train.bio.txt") 
train_data = [preProcess(example) for example in raw_train_data]
print(len(train_data), "instances")
print(sum([len(sent) for sent in train_data]), "words")

raw_test_data = get_raw_data_from_bio_file("trivia10k13test.bio.txt") 
test_data = [preProcess(example) for example in raw_test_data]
print(len(test_data), "instances")
print(sum([len(sent) for sent in test_data]), "words")
# Out:
# 7816 instances
# 158823 words
# 1953 instances
# 39035 words

# %%
# Train the CRF BIO-tag tagger on all training data
TAGGER_PATH = "crf_nlu.tagger"  # path to the tagger- it will save/access the model from here
ct = CRFTagger(feature_func=get_features2, training_opt={"feature.minfreq":2})  # initialize tagger with get_features function

print("training tagger...")
ct.train(train_data, TAGGER_PATH)
print("done")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done

# %%
ct.set_model_file(TAGGER_PATH)  # load model from file

print(len(test_data), "instances")
print(sum([len(sent) for sent in test_data]), "words")

print("testing tagger on test data...")
preds = []
y_test = []
for sent in test_data:
    sent_preds = [x[1] for x in ct.tag([s[0] for s in sent])]
    sent_true = [s[1] for s in sent]
    preds.extend(sent_preds)
    y_test.extend(sent_true)
print("done")
# Out:
# 1953 instances
# 39035 words
# testing tagger on test data...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done

# %%
print(classification_report(y_test, preds))
print(precision_recall_fscore_support(y_test, preds, average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#         B@NN       0.53      0.40      0.46       948
#        B@NNP       0.60      0.25      0.35      1497
#        B@SYM       0.66      0.38      0.48      2176
#        B@VBP       1.00      0.03      0.06        94
#        B@^NN       0.90      0.71      0.79       971
#         I@NN       0.57      0.84      0.68      2331
#        I@NNP       0.69      0.91      0.78      5770
#        I@SYM       0.71      0.91      0.79      8233
#        I@VBP       0.60      0.89      0.71       827
#        I@^NN       0.69      0.92      0.79      2045
#         O@NN       0.67      0.38      0.48      2056
#        O@NNP       0.78      0.60      0.68      4415
#        O@SYM       0.68      0.44      0.53      4016
#        O@VBP       0.90      0.71      0.80      1531
#        O@^NN       0.89      0.68      0.77      2125
#
#     accuracy                           0.70     39035
#    macro avg       0.72      0.60      0.61     39035
# weighted avg       0.71      0.70      0.68     39035
#
# (0.7244290107514338, 0.6041145929759331, 0.6113963225103681, None)

# %% [markdown]
#               precision    recall  f1-score   support
#
#         B@NN       0.53      0.40      0.46       948
#        B@NNP       0.60      0.25      0.35      1497
#        B@SYM       0.66      0.38      0.48      2176
#        B@VBP       1.00      0.03      0.06        94
#        B@^NN       0.90      0.71      0.79       971
#         I@NN       0.57      0.84      0.68      2331
#        I@NNP       0.69      0.91      0.78      5770
#        I@SYM       0.71      0.91      0.79      8233
#        I@VBP       0.60      0.89      0.71       827
#        I@^NN       0.69      0.92      0.79      2045
#         O@NN       0.67      0.38      0.48      2056
#        O@NNP       0.78      0.60      0.68      4415
#        O@SYM       0.68      0.44      0.53      4016
#        O@VBP       0.90      0.71      0.80      1531
#        O@^NN       0.89      0.68      0.77      2125
#
#     accuracy                           0.70     39035
#     macro avg      0.72      0.60      0.61     39035
#     weighted avg   0.71      0.70      0.68     39035
#
#     (0.7244290107514338, 0.6041145929759331, 0.6113963225103681, None)
